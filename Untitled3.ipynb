# %%
# !scrapy startproject myproject
# Out:
# New Scrapy project 'myproject', using template directory 'C:\Users\pcagm\miniconda3\Lib\site-packages\scrapy\templates\project', created in:
#     C:\Users\pcagm\myproject
#
# You can start your first spider with:
#     cd myproject
#     scrapy genspider example example.com
