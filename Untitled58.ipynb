# %%
# divergence_rsi_5m_all_parquet_safe.py
# Runs an RSI-based divergence strategy on 5-minute candles across ALL parquet files in PARQUET_DIR.
# Includes safe parquet reader so it won’t crash in Jupyter if pyarrow/fastparquet are missing.

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from pathlib import Path

# ========= USER SETTINGS =========
PARQUET_DIR = r"C:\\Users\\pcagm\\OneDrive\\Desktop\\downloads\\parquet\\parquet"
TZ_LOCAL = "America/New_York"

REG_START = "09:30"
REG_END   = "16:00"

# Strategy params
RSI_LEN = 14
PIV_LEFT = 2
PIV_RIGHT = 2
MIN_RSI_DIFF = 0.3
TICK_SIZE = 0.01
RR = 2.0
ENTRY_BUFFER = 0.0

SAVE_DIR = Path(".")

# ========= SAFE PARQUET READER =========
def read_parquet_safe(path):
    try:
        return pd.read_parquet(path, engine="pyarrow")
    except Exception:
        try:
            return pd.read_parquet(path, engine="fastparquet")
        except Exception:
            raise ImportError(
                "❌ No usable parquet engine found. Please install one of:\n"
                "   pip install 'pyarrow>=15,<20'\n"
                "   pip install fastparquet\n"
                "or with conda:\n"
                "   conda install -c conda-forge pyarrow fastparquet"
            )

# ========= TIME HELPERS =========
def to_ny(df, col="EventAt"):
    ts = pd.to_datetime(df[col], errors="coerce")
    if ts.dt.tz is None:
        ts = ts.dt.tz_localize("UTC").dt.tz_convert(TZ_LOCAL)
    else:
        ts = ts.dt.tz_convert(TZ_LOCAL)
    return ts

# ========= INDICATORS =========
def rsi(close: pd.Series, length: int = 14) -> pd.Series:
    delta = close.diff()
    up = delta.clip(lower=0)
    down = -delta.clip(upper=0)
    roll_up = up.ewm(alpha=1/length, adjust=False).mean()
    roll_down = down.ewm(alpha=1/length, adjust=False).mean()
    rs = roll_up / roll_down
    out = 100 - (100 / (1 + rs))
    return out

# ========= PIVOT DETECTION =========
def pivot_high(high: pd.Series, left: int, right: int) -> pd.Series:
    return (high == high.rolling(left+1, min_periods=left+1).max()) \
        & (high == high[::-1].rolling(right+1, min_periods=right+1).max()[::-1])

def pivot_low(low: pd.Series, left: int, right: int) -> pd.Series:
    return (low == low.rolling(left+1, min_periods=left+1).min()) \
        & (low == low[::-1].rolling(right+1, min_periods=right+1).min()[::-1])

# ========= SIMULATION HELPERS =========
def simulate_path(df_after_entry: pd.DataFrame, side: str, entry: float, stop: float, target: float):
    for idx, row in df_after_entry.iterrows():
        lo, hi = row["Low"], row["High"]
        hit_stop = (lo <= stop) if side == "long" else (hi >= stop)
        hit_tp   = (hi >= target) if side == "long" else (lo <= target)
        if hit_stop:
            return "STOP", stop, idx
        if hit_tp:
            return "TP", target, idx
    last_idx = df_after_entry.index[-1]
    return "EOD", float(df_after_entry.loc[last_idx, "Close"]), last_idx

def pnl_one_share(side: str, entry: float, exit_px: float) -> float:
    return (exit_px - entry) if side == "long" else (entry - exit_px)

def find_trigger_fill(df_after: pd.DataFrame, side: str, trigger: float):
    for idx, row in df_after.iterrows():
        if side == "long" and row["High"] >= trigger:
            return trigger, idx
        if side == "short" and row["Low"] <= trigger:
            return trigger, idx
    return None, None

# ========= DIVERGENCE SCAN =========
def find_divergences(df5: pd.DataFrame) -> pd.DataFrame:
    ph = pivot_high(df5["High"], PIV_LEFT, PIV_RIGHT)
    pl = pivot_low(df5["Low"],  PIV_LEFT, PIV_RIGHT)

    ph_conf = ph.shift(PIV_RIGHT).fillna(False)
    pl_conf = pl.shift(PIV_RIGHT).fillna(False)

    piv_highs = df5.loc[ph_conf, ["High", "RSI"]]
    piv_lows  = df5.loc[pl_conf, ["Low",  "RSI"]]

    signals = []

    last_price, last_rsi = None, None
    for idx, row in piv_highs.iterrows():
        price, r = float(row["High"]), float(row["RSI"])
        if last_price is not None and last_rsi is not None:
            if price > last_price and r + MIN_RSI_DIFF <= last_rsi:
                pos = df5.index.get_loc(idx)
                if pos + 1 < len(df5.index):
                    entry_bar = df5.index[pos + 1]
                    signals.append({"Time": entry_bar, "Side": "short", "RefPivotTime": idx})
        last_price, last_rsi = price, r

    last_price, last_rsi = None, None
    for idx, row in piv_lows.iterrows():
        price, r = float(row["Low"]), float(row["RSI"])
        if last_price is not None and last_rsi is not None:
            if price < last_price and r - MIN_RSI_DIFF >= last_rsi:
                pos = df5.index.get_loc(idx)
                if pos + 1 < len(df5.index):
                    entry_bar = df5.index[pos + 1]
                    signals.append({"Time": entry_bar, "Side": "long", "RefPivotTime": idx})
        last_price, last_rsi = price, r

    return pd.DataFrame(signals)

# ========= CORE BACKTEST =========
def backtest_one_symbol(parquet_path: Path, symbol: str) -> pd.DataFrame:
    df = read_parquet_safe(parquet_path)
    for c in ["EventAt", "Open", "High", "Low", "Close"]:
        if c not in df.columns:
            raise ValueError(f"{symbol}: parquet missing required column: {c}")

    df["EventAt"] = to_ny(df, "EventAt")
    df = df.sort_values("EventAt").reset_index(drop=True)

    df = df.set_index("EventAt")
    ohlc = {"Open": "first", "High": "max", "Low":  "min", "Close":"last"}
    df5 = df.resample("5T", label="right", closed="right").agg(ohlc).dropna()

    tstr = df5.index.tz_convert(TZ_LOCAL).strftime("%H:%M")
    session = (tstr >= REG_START) & (tstr <= REG_END)
    df5 = df5.loc[session].copy()
    if df5.empty:
        return pd.DataFrame([])

    df5["RSI"] = rsi(df5["Close"], RSI_LEN)

    sig = find_divergences(df5)
    if sig.empty:
        return pd.DataFrame([])

    records = []
    for _, s in sig.iterrows():
        signal_time = s["Time"]
        if signal_time not in df5.index:
            continue
        sig_bar = df5.loc[signal_time]

        if s["Side"] == "long":
            trigger = float(sig_bar["High"]) + ENTRY_BUFFER
        else:
            trigger = float(sig_bar["Low"]) - ENTRY_BUFFER

        after = df5.loc[df5.index > signal_time]
        if after.empty:
            continue

        fill_px, fill_time = find_trigger_fill(after, s["Side"], trigger)
        if fill_px is None:
            # fallback: close confirmation on next bar
            next_idx = after.index[0]
            sig_close = float(sig_bar["Close"])
            next_close = float(after.iloc[0]["Close"])
            if s["Side"] == "long" and next_close > sig_close:
                fill_px, fill_time = next_close, next_idx
            elif s["Side"] == "short" and next_close < sig_close:
                fill_px, fill_time = next_close, next_idx
            else:
                continue

        ref_time = s["RefPivotTime"]
        if s["Side"] == "long":
            stop_px = float(df5.loc[ref_time, "Low"]) - TICK_SIZE
            risk = fill_px - stop_px
            if risk <= 0:
                continue
            target_px = fill_px + RR * risk
        else:
            stop_px = float(df5.loc[ref_time, "High"]) + TICK_SIZE
            risk = stop_px - fill_px
            if risk <= 0:
                continue
            target_px = fill_px - RR * risk

        after_entry = df5.loc[df5.index > fill_time]
        if after_entry.empty:
            continue

        outcome, exit_px, exit_idx = simulate_path(after_entry, s["Side"], fill_px, stop_px, target_px)
        pnl = pnl_one_share(s["Side"], fill_px, exit_px)

        records.append({
            "Date": fill_time.date(),
            "Symbol": symbol,
            "Side": s["Side"],
            "EntryTime": fill_time,
            "Entry": fill_px,
            "Stop": stop_px,
            "Target_1to2": target_px,
            "Outcome_1to2": outcome,
            "ExitPx_1to2": exit_px,
            "ExitTime_1to2": exit_idx,
            "PnL_1to2": pnl,
        })

    return pd.DataFrame(records)

# ========= BASIC METRICS =========
def calc_basic_metrics(trades_df):
    pnl = trades_df["PnL_1to2"].fillna(0.0)
    wins = (pnl > 0).sum()
    losses = (pnl < 0).sum()
    total_trades = int(wins + losses)
    total_pnl = float(pnl.sum())
    gross_pos = pnl[pnl > 0].sum()
    gross_neg = -pnl[pnl < 0].sum()
    profit_factor = float(gross_pos / gross_neg) if gross_neg > 0 else float("inf")
    winrate = (100.0 * wins / total_trades) if total_trades else 0.0
    return total_trades, total_pnl, winrate, profit_factor

# ========= RUN ALL FILES =========
def main():
    parquet_dir = Path(PARQUET_DIR)
    files = sorted(parquet_dir.glob("*.parquet"))
    if not files:
        print(f"No parquet files found in {parquet_dir}")
        return

    SAVE_DIR.mkdir(parents=True, exist_ok=True)

    all_trades = []
    for f in files:
        symbol = f.stem.upper()
        try:
            trades = backtest_one_symbol(f, symbol)
        except Exception as e:
            print(f"[SKIP] {symbol}: {e}")
            continue

        if trades.empty:
            print(f"=== RSI Divergence 5m — {symbol} ===")
            print("Trades: 0 | Total PnL: $0.00 | Win%: 0.00% | Profit Factor: 0.000")
            continue

        all_trades.append(trades)

        total_trades, total_pnl, winrate, profit_factor = calc_basic_metrics(trades)

        save_path = SAVE_DIR / f"div_rsi_trades_{symbol}_one_share_RR{int(RR)}.csv"
        trades.to_csv(save_path, index=False)

        print(f"=== RSI Divergence 5m — {symbol} ===")
        print(f"Trades: {total_trades} | Total PnL: ${total_pnl:,.2f} | Win%: {winrate:.2f}% | Profit Factor: {profit_factor:.3f}")
        print(trades.tail(10).to_string(index=False))
        print(f"Saved trades → {save_path.resolve()}\n")

    if not all_trades:
        print("\nNo trades generated for any symbols.")
        return

    overall = pd.concat(all_trades, ignore_index=True)
    o_trades, o_pnl, o_winrate, o_pf = calc_basic_metrics(overall)

    save_all = SAVE_DIR / f"div_rsi_trades_ALL_one_share_RR{int(RR)}.csv"
    overall.to_csv(save_all, index=False)

    print(f"\n=== RSI Divergence 5m — OVERALL ===")
    print(f"Trades: {o_trades} | Total PnL: ${o_pnl:,.2f} | Win%: {o_winrate:.2f}% | Profit Factor: {o_pf:.3f}")
    print(f"Saved trades → {save_all.resolve()}")

if __name__ == "__main__":
    main()
# Out:
# 2025-09-03    SPY long 2025-09-03 15:20:00-04:00 640.9050 640.690     641.3350           TP      641.335 2025-09-03 15:35:00-04:00    0.4300
# Saved trades → C:\Users\pcagm\div_rsi_trades_SPY_one_share_RR2.csv
#
# === RSI Divergence 5m — TEM ===
# Trades: 714 | Total PnL: $14.46 | Win%: 34.73% | Profit Factor: 1.054
#       Date Symbol Side                 EntryTime   Entry    Stop  Target_1to2 Outcome_1to2  ExitPx_1to2             ExitTime_1to2  PnL_1to2
# 2025-08-25    TEM long 2025-08-25 14:10:00-04:00 76.7646 76.6300      77.0338         STOP      76.6300 2025-08-25 14:20:00-04:00   -0.1346
# 2025-08-26    TEM long 2025-08-26 10:55:00-04:00 76.1900 75.1400      78.2900         STOP      75.1400 2025-08-26 14:10:00-04:00   -1.0500
# 2025-08-26    TEM long 2025-08-26 12:45:00-04:00 76.1000 75.8600      76.5800         STOP      75.8600 2025-08-26 12:50:00-04:00   -0.2400
# 2025-08-26    TEM long 2025-08-26 14:05:00-04:00 75.4900 75.2171      76.0358         STOP      75.2171 2025-08-26 14:10:00-04:00   -0.2729
# 2025-08-27    TEM long 2025-08-27 13:00:00-04:00 72.9900 72.5200      73.9300           TP      73.9300 2025-08-28 09:30:00-04:00    0.9400
# 2025-08-28    TEM long 2025-08-28 09:30:00-04:00 73.5250 73.2700      74.0350         STOP      73.2700 2025-08-28 09:35:00-04:00   -0.2550
# 2025-08-28    TEM long 2025-08-28 09:45:00-04:00 74.1500 73.2200      76.0100         STOP      73.2200 2025-08-28 10:00:00-04:00   -0.9300
# 2025-08-29    TEM long 2025-08-29 09:55:00-04:00 73.5800 73.3700      74.0000         STOP      73.3700 2025-08-29 10:00:00-04:00   -0.2100
# 2025-09-02    TEM long 2025-09-02 09:55:00-04:00 74.7400 73.5700      77.0800         STOP      73.5700 2025-09-02 10:25:00-04:00   -1.1700
# 2025-09-04    TEM long 2025-09-04 10:40:00-04:00 74.3000 73.5900      75.7200           TP      75.7200 2025-09-04 12:55:00-04:00    1.4200
# Saved trades → C:\Users\pcagm\div_rsi_trades_TEM_one_share_RR2.csv
#
# === RSI Divergence 5m — TSLA ===
# Trades: 5293 | Total PnL: $878.01 | Win%: 36.65% | Profit Factor: 1.109
#       Date Symbol Side                 EntryTime    Entry     Stop  Target_1to2 Outcome_1to2  ExitPx_1to2             ExitTime_1to2  PnL_1to2
# 2025-08-26   TSLA long 2025-08-26 12:30:00-04:00 345.5900 344.3600     348.0500           TP     348.0500 2025-08-26 14:45:00-04:00    2.4600
# 2025-08-28   TSLA long 2025-08-28 10:05:00-04:00 350.8186 349.9247     352.6064         STOP     349.9247 2025-08-28 10:10:00-04:00   -0.8939
# 2025-08-28   TSLA long 2025-08-28 12:15:00-04:00 342.3600 341.1600     344.7600           TP     344.7600 2025-08-28 13:55:00-04:00    2.4000
# 2025-09-03   TSLA long 2025-09-03 10:30:00-04:00 336.1100 335.6900     336.9500           TP     336.9500 2025-09-03 10:35:00-04:00    0.8400
# 2025-08-29   TSLA long 2025-08-29 15:50:00-04:00 333.7250 333.4230     334.3290         STOP     333.4230 2025-08-29 15:55:00-04:00   -0.3020
# 2025-09-02   TSLA long 2025-09-02 09:55:00-04:00 332.4200 330.4300     336.4000         STOP     330.4300 2025-09-02 10:05:00-04:00   -1.9900
# 2025-09-02   TSLA long 2025-09-02 14:55:00-04:00 329.0300 328.0000     331.0900           TP     331.0900 2025-09-03 09:30:00-04:00    2.0600
# 2025-09-03   TSLA long 2025-09-03 15:25:00-04:00 335.6700 334.8300     337.3500         STOP     334.8300 2025-09-03 16:00:00-04:00   -0.8400
# 2025-09-04   TSLA long 2025-09-04 15:15:00-04:00 337.2900 334.2200     343.4300          EOD     338.4999 2025-09-04 16:00:00-04:00    1.2099
# 2025-09-04   TSLA long 2025-09-04 10:35:00-04:00 334.4400 332.9900     337.3400         STOP     332.9900 2025-09-04 10:45:00-04:00   -1.4500
# Saved trades → C:\Users\pcagm\div_rsi_trades_TSLA_one_share_RR2.csv
#
# === RSI Divergence 5m — TSM ===
# Trades: 5910 | Total PnL: $65.72 | Win%: 35.45% | Profit Factor: 1.070
#       Date Symbol Side                 EntryTime    Entry     Stop  Target_1to2 Outcome_1to2  ExitPx_1to2             ExitTime_1to2  PnL_1to2
# 2025-08-19    TSM long 2025-08-19 12:35:00-04:00 236.8600 236.3400     237.9000         STOP     236.3400 2025-08-19 12:45:00-04:00   -0.5200
# 2025-08-19    TSM long 2025-08-19 13:40:00-04:00 236.0690 235.4800     237.2470         STOP     235.4800 2025-08-19 13:45:00-04:00   -0.5890
# 2025-08-25    TSM long 2025-08-25 10:40:00-04:00 235.6900 235.3550     236.3600         STOP     235.3550 2025-08-25 10:45:00-04:00   -0.3350
# 2025-08-21    TSM long 2025-08-21 12:55:00-04:00 227.7400 227.4000     228.4200         STOP     227.4000 2025-08-21 13:00:00-04:00   -0.3400
# 2025-08-21    TSM long 2025-08-21 13:50:00-04:00 227.5408 226.8300     228.9624         STOP     226.8300 2025-08-22 09:30:00-04:00   -0.7108
# 2025-08-29    TSM long 2025-08-29 10:35:00-04:00 232.5500 231.1300     235.3900         STOP     231.1300 2025-08-29 13:15:00-04:00   -1.4200
# 2025-08-29    TSM long 2025-08-29 13:40:00-04:00 231.7650 231.4000     232.4950         STOP     231.4000 2025-08-29 14:00:00-04:00   -0.3650
# 2025-08-29    TSM long 2025-08-29 15:55:00-04:00 231.3100 231.0500     231.8300         STOP     231.0500 2025-08-29 16:00:00-04:00   -0.2600
# 2025-09-02    TSM long 2025-09-02 13:30:00-04:00 227.6100 227.1400     228.5500           TP     228.5500 2025-09-02 15:50:00-04:00    0.9400
# 2025-09-03    TSM long 2025-09-03 13:15:00-04:00 230.9500 230.6006     231.6488         STOP     230.6006 2025-09-03 13:40:00-04:00   -0.3494
# Saved trades → C:\Users\pcagm\div_rsi_trades_TSM_one_share_RR2.csv
#
#
# === RSI Divergence 5m — OVERALL ===
# Trades: 98302 | Total PnL: $7,914.74 | Win%: 36.15% | Profit Factor: 1.129
# Saved trades → C:\Users\pcagm\div_rsi_trades_ALL_one_share_RR2.csv
