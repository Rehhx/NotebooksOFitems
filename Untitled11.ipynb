# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# Load the CSV file
file_path = r"C:\Users\pcagm\Downloads\split_file_4.csv"
df = pd.read_csv(file_path)

# Convert Date column to datetime format
df["Date"] = pd.to_datetime(df["Date"], errors='coerce')

# Filter token IDs and dates where wasRekt = 1 and volume is empty
rekt_data = df[(df["wasRekt"] == 1) & (df["volume"].isna())][["id", "Date"]].dropna()

# Initialize Selenium WebDriver
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)

historical_data = []

for index, row in rekt_data.iterrows():
    try:
        token_id = row["id"]
        date_str = row["Date"]
        date_obj = pd.to_datetime(date_str, errors='coerce')
        if pd.isna(date_obj):
            print(f"Skipping {token_id} due to invalid date format")
            continue

        max_years_back = 7 * 365  # Maximum search range in days (7 years)
        max_years_forward = (pd.Timestamp.today() - date_obj).days  # Days until current date
        
        # Backward search intervals
        backward_intervals = [90, 180, 365, 730, 1095]  # 3 months, 6 months, 1 year, 2 years, 3 years
        while backward_intervals[-1] < max_years_back:
            backward_intervals.append(backward_intervals[-1] + 90)  # 3-month intervals after 3 years

        # Forward search intervals
        forward_intervals = [1, 3, 9, 27, 60, 120, 180]  # 1 day, 3 days, 9 days, 27 days, 2 months, 4 months, 6 months
        while forward_intervals[-1] < max_years_forward:
            forward_intervals.append(forward_intervals[-1] + 90)  # 3-month intervals after 6 months

        data_found = False

        # Backward search
        for days_back in backward_intervals:
            if data_found:
                break
            start_date = (date_obj - pd.Timedelta(days=days_back)).strftime("%Y-%m-%d")
            end_date = (date_obj - pd.Timedelta(days=days_back - 1)).strftime("%Y-%m-%d")
            url = f"https://www.coingecko.com/en/coins/{token_id}/historical_data?start={start_date}&end={end_date}"
            driver.get(url)
            print(f"Opened: {url}")
            time.sleep(5)

            try:
                rows = driver.find_elements(By.CSS_SELECTOR, "table tbody tr")
                if rows:
                    row = rows[0]  # Only grab the first available row
                    cols = row.find_elements(By.TAG_NAME, "td")
                    if len(cols) >= 4:
                        date = cols[0].text
                        market_cap = cols[1].text
                        volume = cols[2].text
                        open_price = cols[3].text
                        close_price = cols[4].text if len(cols) > 4 else "N/A"
                        historical_data.append([token_id, date, market_cap, volume, open_price, close_price])
                        print(f"{token_id} - {date}: Market Cap={market_cap}, Volume={volume}, Open={open_price}, Close={close_price}")
                        data_found = True
            except:
                print(f"No historical data found for {token_id} on {start_date}")

        # Forward search if no data found
        if not data_found:
            for days_forward in forward_intervals:
                start_date = (date_obj + pd.Timedelta(days=days_forward)).strftime("%Y-%m-%d")
                end_date = (date_obj + pd.Timedelta(days=days_forward + 1)).strftime("%Y-%m-%d")
                url = f"https://www.coingecko.com/en/coins/{token_id}/historical_data?start={start_date}&end={end_date}"
                driver.get(url)
                print(f"Opened: {url}")
                time.sleep(5)

                try:
                    rows = driver.find_elements(By.CSS_SELECTOR, "table tbody tr")
                    if rows:
                        row = rows[0]
                        cols = row.find_elements(By.TAG_NAME, "td")
                        if len(cols) >= 4:
                            date = cols[0].text
                            market_cap = cols[1].text
                            volume = cols[2].text
                            open_price = cols[3].text
                            close_price = cols[4].text if len(cols) > 4 else "N/A"
                            historical_data.append([token_id, date, market_cap, volume, open_price, close_price])
                            print(f"{token_id} - {date}: Market Cap={market_cap}, Volume={volume}, Open={open_price}, Close={close_price}")
                            data_found = True
                            break
                except:
                    print(f"No historical data found for {token_id} on {start_date}")
    
    except Exception as e:
        print(f"Error fetching historical data for {token_id}: {e}")

# Convert to DataFrame and save
historical_df = pd.DataFrame(historical_data, columns=["id", "Date", "market_cap", "volume", "open", "close"])
historical_df.to_csv("historical_data_split_file_4.csv", index=False)
print("Historical data saved to historical_data_split_file_4.csv")

driver.quit()
# Out:
# Opened: https://www.coingecko.com/en/coins/respect-the-pump/historical_data?start=2020-10-07&end=2020-10-08
# Opened: https://www.coingecko.com/en/coins/respect-the-pump/historical_data?start=2020-07-09&end=2020-07-10
# Opened: https://www.coingecko.com/en/coins/respect-the-pump/historical_data?start=2020-01-06&end=2020-01-07
# Opened: https://www.coingecko.com/en/coins/respect-the-pump/historical_data?start=2019-01-06&end=2019-01-07
# Opened: https://www.coingecko.com/en/coins/respect-the-pump/historical_data?start=2018-01-06&end=2018-01-07
# Opened: https://www.coingecko.com/en/coins/respect-the-pump/historical_data?start=2017-10-08&end=2017-10-09
# Opened: https://www.coingecko.com/en/coins/respect-the-pump/historical_data?start=2017-07-10&end=2017-07-11
# Opened: https://www.coingecko.com/en/coins/respect-the-pump/historical_data?start=
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2017-06-10&end=2017-06-11
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2017-03-12&end=2017-03-13
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2016-12-12&end=2016-12-13
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2016-09-13&end=2016-09-14
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2016-06-15&end=2016-06-16
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2016-03-17&end=2016-03-18
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2015-12-18&end=2015-12-19
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2015-09-19&end=2015-09-20
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2015-06-21&end=2015-06-22
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2015-03-23&end=2015-03-24
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2014-12-23&end=2014-12-24
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2014-09-24&end=2014-09-25
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2014-06-26&end=2014-06-27
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2014-03-28&end=2014-03-29
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2021-06-05&end=2021-06-06
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2021-06-07&end=2021-06-08
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2021-06-13&end=2021-06-14
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2021-07-01&end=2021-07-02
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2021-08-03&end=2021-08-04
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2021-10-02&end=2021-10-03
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2021-12-01&end=2021-12-02
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2022-03-01&end=2022-03-02
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2022-05-30&end=2022-05-31
# woop - 2022-05-31: Market Cap=$0.000000000000000000, Volume=$12,117.94, Open=$0.140579, Close=$0.144144
# Historical data saved to historical_data_split_file_4.csv

# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# Load the CSV file
file_path = r"C:\Users\pcagm\Downloads\Untitled spreadsheet - historical_data_split_file_4.csv"
df = pd.read_csv(file_path)

# Print column names to debug column name mismatches
print("Available columns in dataset:", df.columns.tolist())

# Ensure column names match dataset
if "Token ID" in df.columns:
    df.rename(columns={"Token ID": "id"}, inplace=True)

# Convert Date column to datetime format
df["Date"] = pd.to_datetime(df["Date"], errors='coerce')

# Initialize Selenium WebDriver
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)

highest_volume_data = []

for index, row in df.iterrows():
    try:
        token_id = row["id"]
        date_obj = row["Date"]
        if pd.isna(date_obj):
            print(f"Skipping {token_id} due to invalid date format")
            continue

        # Define search range (90 days before and after the given date)
        start_date = (date_obj - pd.Timedelta(days=90)).strftime("%Y-%m-%d")
        end_date = (date_obj + pd.Timedelta(days=90)).strftime("%Y-%m-%d")

        # Construct the historical data URL with dynamic dates
        url = f"https://www.coingecko.com/en/coins/{token_id}/historical_data?start={start_date}&end={end_date}"
        driver.get(url)
        print(f"Opened: {url}")
        time.sleep(5)  # Allow data to load

        try:
            rows = driver.find_elements(By.CSS_SELECTOR, "table tbody tr")
            highest_volume = 0
            highest_volume_entry = None
            seven_days_before_entry = None

            for row in rows:
                cols = row.find_elements(By.TAG_NAME, "td")
                if len(cols) >= 4:
                    date = cols[0].text
                    market_cap = cols[1].text
                    volume = float(cols[2].text.replace('$', '').replace(',', '')) if cols[2].text else 0
                    open_price = cols[3].text
                    close_price = cols[4].text if len(cols) > 4 else "N/A"
                    
                    if volume > highest_volume:
                        highest_volume = volume
                        highest_volume_entry = [token_id, date, market_cap, volume, open_price, close_price]
                        
                        # Look for the data 7 days before the highest volume date
                        seven_days_before_date = (pd.to_datetime(date) - pd.Timedelta(days=7)).strftime("%Y-%m-%d")
                        for prev_row in rows:
                            prev_cols = prev_row.find_elements(By.TAG_NAME, "td")
                            if len(prev_cols) >= 4 and prev_cols[0].text == seven_days_before_date:
                                seven_days_before_entry = [token_id, prev_cols[0].text, prev_cols[1].text, prev_cols[2].text, prev_cols[3].text, prev_cols[4].text]
                                break
            
            if highest_volume_entry:
                highest_volume_data.append(highest_volume_entry)
                print(f"{token_id} - Highest Volume within 90 days: {highest_volume_entry}")
                if seven_days_before_entry:
                    highest_volume_data.append(seven_days_before_entry)
                    print(f"{token_id} - 7 Days Before Highest Volume: {seven_days_before_entry}")
        except:
            print(f"No historical data found for {token_id} in the given range")
    
    except Exception as e:
        print(f"Error fetching historical data for {token_id}: {e}")

# Convert to DataFrame and save
highest_volume_df = pd.DataFrame(highest_volume_data, columns=["id", "Date", "market_cap", "volume", "open", "close"])
highest_volume_df.to_csv("highest_volume_historical_data.csv", index=False)
print("Highest volume data within 90 days saved to highest_volume_historical_data.csv")

driver.quit()
# Out:
# Available columns in dataset: ['id', 'Date', 'market_cap', 'volume', 'open', 'close']
# Opened: https://www.coingecko.com/en/coins/respect-the-pump/historical_data?start=2024-09-17&end=2025-03-16
# respect-the-pump - Highest Volume within 90 days: ['respect-the-pump', '2025-03-03', '$7,259.05', 1899.84, '$0.00000730', '$0.00000581']
# respect-the-pump - 7 Days Before Highest Volume: ['respect-the-pump', '2025-02-24', '$7,666.17', '$15.75', '$0.00000766', '$0.00000688']
# Opened: https://www.coingecko.com/en/coins/rick-the-npc/historical_data?start=2024-11-08&end=2025-05-07
# rick-the-npc - Highest Volume within 90 days: ['rick-the-npc', '2025-02-23', '$533,734', 70222.0, '$0.00053469', '$0.00035392']
# rick-the-npc - 7 Days Before Highest Volume: ['rick-the-npc', '2025-02-16', '$132,124', '$1,300.27', '$0.00013213', '$0.00012082']
# Opened: https://www.coingecko.com/en/coins/roaring-kitty-solana/historical_data?start=2024-04-23&end=2024-10-20
# roaring-kitty-solana - Highest Volume within 90 days: ['roaring-kitty-solana', '2024-10-16', '$0.000000000000000000', 944954.0, '$0.00287920', '$0.00287525']
# roaring-kitty-solana - 7 Days Before Highest Volume: ['roaring-kitty-solana', '2024-10-09', '$0.000000000000000000', '$651,169', '$0.00246585', '$0.00213149']
# Opened: https://www.coingecko.com/en/coins/rocketx/historical_data?start=2021-01-15&end=2021-07-14
# rocketx - Highest Volume within 90 days: ['rocketx', '2021-07-14', '$590,570', 40194.0, '$0.02278288', '$0.02354049']
# rocketx - 7 Days Before Highest Volume: ['rocketx', '2021-07-07', '$716,281', '$1,755.86', '$0.04221871', '$0.04304355']
# Opened: https://www.coingecko.com/en/coins/rok/historical_data?start=2024-05-27&end=2024-11-23
# rok - Highest Volume within 90 days: ['rok', '2024-11-10', '$81,673', 8162.23, '$0.00008252', '$0.00008147']
# rok - 7 Days Before Highest Volume: ['rok', '2024-11-15', '$68,023', '$178.65', '$0.00006829', '$0.00007108']
# Opened: https://www.coingecko.com/en/coins/rush-2/historical_data?start=2023-11-08&end=2024-05-06
# rush-2 - Highest Volume within 90 days: ['rush-2', '2024-02-05', '$0.000000000000000000', 839.41, '$0.00004343', '$0.00004744']
# rush-2 - 7 Days Before Highest Volume: ['rush-2', '2024-02-02', '$0.000000000000000000', '$467.48', '$0.00004860', '$0.00004708']
# Opened: https://www.coingecko.com/en/coins/saga-2/historical_data?start=2024-01-10&end=2024-07-08
# saga-2 - Highest Volume within 90 days: ['saga-2', '2024-07-08', '$114,295,136', 122597539.0, '$1.18', '$1.27']
# saga-2 - 7 Days Before Highest Volume: ['saga-2', '2024-07-01', '$129,800,731', '$25,119,421', '$1.35', '$1.35']
# Opened: https://www.coingecko.com/en/coins/salvor/historical_data?start=2023-08-23&end=2024-02-19
# salvor - Highest Volume within 90 days: ['salvor', '2024-02-14', '$0.000000000000000000', 67701.0, '$0.02488615', '$0.02731894']
# salvor - 7 Days Before Highest Volume: ['salvor', '2024-02-07', '$0.000000000000000000', '$72.63', '$0.00795938', '$0.00841709']
# Opened: https://www.coingecko.com/en/coins/samurai-cat/historical_data?start=2024-04-07&end=2024-10-04
# samurai-cat - Highest Volume within 90 days: ['samurai-cat', '2024-09-20', '$25,283', 1437.8, '$0.00002528', '$0.00002522']
# samurai-cat - 7 Days Before Highest Volume: ['samurai-cat', '2024-09-21', '$25,232', '$587.48', '$0.00002522', '$0.00002598']
# Opened: https://www.coingecko.com/en/coins/sangkara/historical_data?start=2022-03-04&end=2022-08-31
# sangkara - Highest Volume within 90 days: ['sangkara', '2022-08-24', '$0.000000000000000000', 401375.0, '$0.00007296', '$0.00007112']
# sangkara - 7 Days Before Highest Volume: ['sangkara', '2022-08-17', '$0.000000000000000000', '$253,958', '$0.00008955', '$0.00008387']
# Opened: https://www.coingecko.com/en/coins/santawifhat/historical_data?start=2024-10-14&end=2025-04-12
# santawifhat - Highest Volume within 90 days: ['santawifhat', '2025-03-03', '$43,966', 2311.24, '$0.00004401', '$0.00003507']
# santawifhat - 7 Days Before Highest Volume: ['santawifhat', '2025-02-24', '$35,596', '$1.26', '$0.00003565', '$0.00003020']
# Opened: https://www.coingecko.com/en/coins/satori-network/historical_data?start=2024-10-26&end=2025-04-24
# satori-network - Highest Volume within 90 days: ['satori-network', '2025-02-26', '$4,067,362', 30610.0, '$12.79', '$12.77']
# satori-network - 7 Days Before Highest Volume: ['satori-network', '2025-02-19', '$4,385,012', '$10,293.44', '$14.23', '$14.16']
# Opened: https://www.coingecko.com/en/coins/save-baby-doge/historical_data?start=2021-04-23&end=2021-10-20
# save-baby-doge - Highest Volume within 90 days: ['save-baby-doge', '2021-10-09', '$0.000000000000000000', 237.57, '$0.000000000182276', '$0.000000000182987']
# save-baby-doge - 7 Days Before Highest Volume: ['save-baby-doge', '2021-10-02', '$0.000000000000000000', '$50.24', '$0.000000000180739', '$0.000000000181396']
# Opened: https://www.coingecko.com/en/coins/scallop-2/historical_data?start=2023-12-13&end=2024-06-10
# scallop-2 - Highest Volume within 90 days: ['scallop-2', '2024-06-04', '$17,830,749', 9801572.0, '$0.591485', '$0.615147']
# scallop-2 - 7 Days Before Highest Volume: ['scallop-2', '2024-05-28', '$16,999,677', '$9,025,730', '$0.563300', '$0.542840']
# Opened: https://www.coingecko.com/en/coins/script-network/historical_data?start=2023-09-30&end=2024-03-28
# script-network - Highest Volume within 90 days: ['script-network', '2024-03-09', '$7,282,641', 5095193.0, '$0.03160114', '$0.04185801']
# script-network - 7 Days Before Highest Volume: ['script-network', '2024-03-18', '$11,564,083', '$2,213,810', '$0.04779729', '$0.04781694']
# Opened: https://www.coingecko.com/en/coins/settled-ethxy-token/historical_data?start=2023-11-15&end=2024-05-13
# settled-ethxy-token - Highest Volume within 90 days: ['settled-ethxy-token', '2024-04-30', '$0.000000000000000000', 2981406.0, '$1.27', '$0.996499']
# settled-ethxy-token - 7 Days Before Highest Volume: ['settled-ethxy-token', '2024-04-24', '$0.000000000000000000', '$756,236', '$0.971843', '$0.945748']
# Opened: https://www.coingecko.com/en/coins/sfortuna-token/historical_data?start=2024-06-20&end=2024-12-17
# sfortuna-token - Highest Volume within 90 days: ['sfortuna-token', '2024-11-30', '$0.000000000000000000', 11190.82, '$0.02206077', '$0.02179553']
# sfortuna-token - 7 Days Before Highest Volume: ['sfortuna-token', '2024-12-03', '$0.000000000000000000', '$487.51', '$0.02642640', '$0.01988875']
# Opened: https://www.coingecko.com/en/coins/shibabitcoin-2/historical_data?start=2024-05-02&end=2024-10-29
# shibabitcoin-2 - Highest Volume within 90 days: ['shibabitcoin-2', '2024-10-29', '$0.000000000000000000', 44353216.0, '$1.014', '$0.998796']
# shibabitcoin-2 - 7 Days Before Highest Volume: ['shibabitcoin-2', '2024-10-22', '$0.000000000000000000', '$32,485,206', '$1.11', '$1.11']
# Opened: https://www.coingecko.com/en/coins/shimmersea-lum/historical_data?start=2023-10-23&end=2024-04-20
# shimmersea-lum - Highest Volume within 90 days: ['shimmersea-lum', '2024-04-02', '$0.000000000000000000', 70019.0, '$0.733589', '$0.699282']
# shimmersea-lum - 7 Days Before Highest Volume: ['shimmersea-lum', '2024-04-08', '$0.000000000000000000', '$17,930.94', '$0.582436', '$0.591768']
# Opened: https://www.coingecko.com/en/coins/shitcoin-on-ton/historical_data?start=2024-05-12&end=2024-11-08
# shitcoin-on-ton - Highest Volume within 90 days: ['shitcoin-on-ton', '2024-10-29', '$335,312', 77213.0, '$0.00463778', '$0.00475261']
# shitcoin-on-ton - 7 Days Before Highest Volume: ['shitcoin-on-ton', '2024-10-22', '$349,269', '$51,903', '$0.00483083', '$0.00482779']
# Opened: https://www.coingecko.com/en/coins/sigma-2/historical_data?start=2024-08-19&end=2025-02-15
# sigma-2 - Highest Volume within 90 days: ['sigma-2', '2025-01-30', '$127,531', 3235.6, '$0.00012738', '$0.00012928']
# sigma-2 - 7 Days Before Highest Volume: ['sigma-2', '2025-01-27', '$162,874', '$2,986.93', '$0.00016249', '$0.00015158']
# Opened: https://www.coingecko.com/en/coins/sin-city/historical_data?start=2021-10-18&end=2022-04-16
# sin-city - Highest Volume within 90 days: ['sin-city', '2022-03-28', '$8,809,383', 1287110.0, '$0.072898', '$0.071412']
# sin-city - 7 Days Before Highest Volume: ['sin-city', '2022-03-29', '$8,647,001', '$639,451', '$0.071412', '$0.066824']
# Opened: https://www.coingecko.com/en/coins/sixpack-token-sixp/historical_data?start=2024-12-04&end=2025-06-02
# sixpack-token-sixp - Highest Volume within 90 days: ['sixpack-token-sixp', '2025-03-04', '$5,344,797', 79309.0, '$0.220151', 'N/A']
# sixpack-token-sixp - 7 Days Before Highest Volume: ['sixpack-token-sixp', '2025-02-25', '$4,417,912', '$11,509.97', '$0.197705', '$0.200527']
# Opened: https://www.coingecko.com/en/coins/sleepless-ai/historical_data?start=2023-11-02&end=2024-04-30
# sleepless-ai - Highest Volume within 90 days: ['sleepless-ai', '2024-04-15', '$129,478,948', 89969011.0, '$0.994225', '$0.914998']
# sleepless-ai - 7 Days Before Highest Volume: ['sleepless-ai', '2024-04-11', '$189,389,710', '$45,159,094', '$1.46', '$1.41']
# Opened: https://www.coingecko.com/en/coins/slothana/historical_data?start=2024-03-13&end=2024-09-09
# slothana - Highest Volume within 90 days: ['slothana', '2024-09-07', '$10,576,499', 3684082.0, '$0.00570228', '$0.00584962']
# slothana - 7 Days Before Highest Volume: ['slothana', '2024-08-31', '$11,290,981', '$3,127,019', '$0.00610336', '$0.00609246']
# Opened: https://www.coingecko.com/en/coins/slurp-2/historical_data?start=2024-09-01&end=2025-02-28
# slurp-2 - Highest Volume within 90 days: ['slurp-2', '2025-02-10', '$16,026.65', 198.48, '$0.00001608', '$0.00001582']
# slurp-2 - 7 Days Before Highest Volume: ['slurp-2', '2025-02-14', '$14,750.94', '$11.28', '$0.00001474', '$0.00001518']
# Opened: https://www.coingecko.com/en/coins/smarthub/historical_data?start=2024-07-11&end=2025-01-07
# smarthub - Highest Volume within 90 days: ['smarthub', '2024-11-29', '$0.000000000000000000', 1013.67, '$0.01380816', '$0.01327076']
# smarthub - 7 Days Before Highest Volume: ['smarthub', '2024-12-31', '$0.000000000000000000', '$39.31', '$0.01202730', '$0.01149280']
# Opened: https://www.coingecko.com/en/coins/smoothy/historical_data?start=2021-01-27&end=2021-07-26
# smoothy - Highest Volume within 90 days: ['smoothy', '2021-07-07', '$1,578,424', 913844.0, '$0.297816', '$0.304068']
# smoothy - 7 Days Before Highest Volume: ['smoothy', '2021-07-09', '$1,521,100', '$736,870', '$0.286586', '$0.287629']
# Opened: https://www.coingecko.com/en/coins/snake-3/historical_data?start=2024-08-11&end=2025-02-07
# snake-3 - Highest Volume within 90 days: ['snake-3', '2025-01-29', '$0.000000000000000000', 39327.0, '$626.82', '$579.88']
# snake-3 - 7 Days Before Highest Volume: ['snake-3', '2025-01-22', '$0.000000000000000000', '$1,408.67', '$746.43', '$809.12']
# Opened: https://www.coingecko.com/en/coins/snook/historical_data?start=2021-06-18&end=2021-12-15
# snook - Highest Volume within 90 days: ['snook', '2021-11-26', '$5,321,113', 291043.0, '$1.28', '$1.12']
# snook - 7 Days Before Highest Volume: ['snook', '2021-11-26', '$5,321,113', '$291,043', '$1.28', '$1.12']
# Opened: https://www.coingecko.com/en/coins/solana-swap/historical_data?start=2024-09-08&end=2025-03-07
# solana-swap - Highest Volume within 90 days: ['solana-swap', '2025-03-04', '$0.000000000000000000', 11717349.0, '$0.178783', 'N/A']
# solana-swap - 7 Days Before Highest Volume: ['solana-swap', '2025-02-25', '$0.000000000000000000', '$6,991,862', '$0.495993', '$0.523694']
# Opened: https://www.coingecko.com/en/coins/soldragon/historical_data?start=2023-12-03&end=2024-05-31
# soldragon - Highest Volume within 90 days: ['soldragon', '2024-05-24', '$0.000000000000000000', 11052.71, '$0.00099488', '$0.00087691']
# soldragon - 7 Days Before Highest Volume: ['soldragon', '2024-05-17', '$0.000000000000000000', '$5,725.41', '$0.00099112', '$0.00094799']
# Opened: https://www.coingecko.com/en/coins/solmedia/historical_data?start=2024-01-16&end=2024-07-14
# solmedia - Highest Volume within 90 days: ['solmedia', '2024-07-06', '$0.000000000000000000', 43711.0, '$0.00589204', '$0.00606663']
# solmedia - 7 Days Before Highest Volume: ['solmedia', '2024-06-29', '$0.000000000000000000', '$22,295', '$0.00877986', '$0.00841455']
# Opened: https://www.coingecko.com/en/coins/sonic-the-goat/historical_data?start=2024-03-17&end=2024-09-13
# sonic-the-goat - Highest Volume within 90 days: ['sonic-the-goat', '2024-09-10', '$321,667', 12599.46, '$0.000000350820', '$0.000000336613']
# sonic-the-goat - 7 Days Before Highest Volume: ['sonic-the-goat', '2024-09-03', '$358,146', '$89.08', '$0.000000390664', '$0.000000370650']
# Opened: https://www.coingecko.com/en/coins/sora-chameleon/historical_data?start=2024-06-26&end=2024-12-23
# sora-chameleon - Highest Volume within 90 days: ['sora-chameleon', '2024-11-11', '$0.000000000000000000', 2163.75, '$528.01', '$734.06']
# Opened: https://www.coingecko.com/en/coins/space-id/historical_data?start=2022-12-23&end=2023-06-21
# space-id - Highest Volume within 90 days: ['space-id', '2023-06-11', '$76,788,564', 84811021.0, '$0.268216', '$0.264650']
# space-id - 7 Days Before Highest Volume: ['space-id', '2023-06-04', '$131,429,451', '$19,903,670', '$0.459723', '$0.464557']
# Opened: https://www.coingecko.com/en/coins/spherium/historical_data?start=2021-06-30&end=2021-12-27
# spherium - Highest Volume within 90 days: ['spherium', '2021-12-26', '$2,237,313', 49797.0, '$0.103151', '$0.101781']
# spherium - 7 Days Before Highest Volume: ['spherium', '2021-12-19', '$2,256,882', '$15,329.34', '$0.104109', '$0.106609']
# Opened: https://www.coingecko.com/en/coins/spiraldao-coil/historical_data?start=2023-03-19&end=2023-09-15
# spiraldao-coil - Highest Volume within 90 days: ['spiraldao-coil', '2023-09-13', '$0.000000000000000000', 71379.0, '$1.56', '$1.57']
# spiraldao-coil - 7 Days Before Highest Volume: ['spiraldao-coil', '2023-09-06', '$0.000000000000000000', '$878.71', '$1.58', '$1.58']
# Opened: https://www.coingecko.com/en/coins/sports-analyst-ai/historical_data?start=2024-11-13&end=2025-05-12
# sports-analyst-ai - Highest Volume within 90 days: ['sports-analyst-ai', '2025-02-18', '$674,813', 61306.0, '$0.052970', '$0.04071781']
# sports-analyst-ai - 7 Days Before Highest Volume: ['sports-analyst-ai', '2025-02-14', '$261,113', '$4,286.74', '$0.02867643', '$0.03638201']
# Opened: https://www.coingecko.com/en/coins/sportsology-game/historical_data?start=2024-04-09&end=2024-10-06
# sportsology-game - Highest Volume within 90 days: ['sportsology-game', '2024-09-17', '$225,504', 131978.0, '$0.01524622', '$0.01392620']
# sportsology-game - 7 Days Before Highest Volume: ['sportsology-game', '2024-09-27', '$187,956', '$24,821', '$0.01270419', '$0.01349121']
# Opened: https://www.coingecko.com/en/coins/stage-0/historical_data?start=2024-05-20&end=2024-11-16
# stage-0 - Highest Volume within 90 days: ['stage-0', '2024-11-16', '$0.000000000000000000', 27393.0, '$0.00053711', '$0.00050240']
# stage-0 - 7 Days Before Highest Volume: ['stage-0', '2024-11-09', '$0.000000000000000000', '$25.16', '$0.00058743', '$0.00059088']
# Opened: https://www.coingecko.com/en/coins/statter-network/historical_data?start=2024-02-11&end=2024-08-09
# statter-network - Highest Volume within 90 days: ['statter-network', '2024-08-07', '$0.000000000000000000', 5347600.0, '$0.664062', '$0.677349']
# statter-network - 7 Days Before Highest Volume: ['statter-network', '2024-07-31', '$0.000000000000000000', '$2,654,452', '$0.573670', '$0.565045']
# Opened: https://www.coingecko.com/en/coins/stonefish-ai/historical_data?start=2024-11-18&end=2025-05-17
# stonefish-ai - Highest Volume within 90 days: ['stonefish-ai', '2025-02-19', '$62,883', 4688.37, '$0.00000671', '$0.00000570']
# stonefish-ai - 7 Days Before Highest Volume: ['stonefish-ai', '2025-02-13', '$156,680', '$2,362.47', '$0.00001678', '$0.00001547']
# Opened: https://www.coingecko.com/en/coins/storm-trade/historical_data?start=2024-09-08&end=2025-03-07
# storm-trade - Highest Volume within 90 days: ['storm-trade', '2025-02-27', '$3,272,400', 1151855.0, '$0.01833136', '$0.01813462']
# storm-trade - 7 Days Before Highest Volume: ['storm-trade', '2025-02-20', '$3,187,883', '$964,741', '$0.01812759', '$0.01860124']
# Opened: https://www.coingecko.com/en/coins/strawberry-ai/historical_data?start=2024-05-18&end=2024-11-14
# strawberry-ai - Highest Volume within 90 days: ['strawberry-ai', '2024-11-14', '$17,397,146', 650474.0, '$0.173480', '$0.171110']
# strawberry-ai - 7 Days Before Highest Volume: ['strawberry-ai', '2024-11-07', '$14,615,666', '$296,898', '$0.146144', '$0.142767']
# Opened: https://www.coingecko.com/en/coins/subquery-network/historical_data?start=2024-02-11&end=2024-08-09
# subquery-network - Highest Volume within 90 days: ['subquery-network', '2024-08-01', '$7,565,190', 200658.0, '$0.00665291', '$0.00665884']
# subquery-network - 7 Days Before Highest Volume: ['subquery-network', '2024-07-25', '$10,846,026', '$52,467', '$0.00954105', '$0.00933914']
# Opened: https://www.coingecko.com/en/coins/sudeng/historical_data?start=2024-08-15&end=2025-02-11
# sudeng - Highest Volume within 90 days: ['sudeng', '2025-02-04', '$54,754,495', 43293816.0, '$0.00547384', '$0.00501981']
# sudeng - 7 Days Before Highest Volume: ['sudeng', '2025-01-28', '$72,444,850', '$35,676,901', '$0.00727990', '$0.00651218']
# Opened: https://www.coingecko.com/en/coins/sui-chad/historical_data?start=2024-11-19&end=2025-05-18
# sui-chad - Highest Volume within 90 days: ['sui-chad', '2025-02-18', '$152,969', 1216.63, '$0.00001530', '$0.00001373']
# sui-chad - 7 Days Before Highest Volume: ['sui-chad', '2025-02-14', '$163,394', '$42.02', '$0.00001626', '$0.00001666']
# Opened: https://www.coingecko.com/en/coins/sunny-on-tron/historical_data?start=2024-08-11&end=2025-02-07
# sunny-on-tron - Highest Volume within 90 days: ['sunny-on-tron', '2025-01-21', '$63,202', 2189.61, '$0.00006320', '$0.00006099']
# Opened: https://www.coingecko.com/en/coins/super-athletes-token/historical_data?start=2022-10-06&end=2023-04-04
# super-athletes-token - Highest Volume within 90 days: ['super-athletes-token', '2023-03-19', '$0.000000000000000000', 87749.0, '$0.00663039', '$0.00528794']
# super-athletes-token - 7 Days Before Highest Volume: ['super-athletes-token', '2023-03-28', '$0.000000000000000000', '$17,955.08', '$0.00429518', '$0.00418420']
# Opened: https://www.coingecko.com/en/coins/super-sushi-samurai/historical_data?start=2024-03-11&end=2024-09-07
# super-sushi-samurai - Highest Volume within 90 days: ['super-sushi-samurai', '2024-08-30', '$0.000000000000000000', 23599.0, '$0.000000003118', '$0.000000003112']
# super-sushi-samurai - 7 Days Before Highest Volume: ['super-sushi-samurai', '2024-08-23', '$0.000000000000000000', '$2,399.35', '$0.000000003283', '$0.000000003452']
# Opened: https://www.coingecko.com/en/coins/supercells-2/historical_data?start=2024-06-01&end=2024-11-28
# supercells-2 - Highest Volume within 90 days: ['supercells-2', '2024-11-19', '$0.000000000000000000', 782140.0, '$0.136564', '$0.138179']
# supercells-2 - 7 Days Before Highest Volume: ['supercells-2', '2024-11-12', '$0.000000000000000000', '$208,127', '$0.104822', '$0.111107']
# Opened: https://www.coingecko.com/en/coins/swapbased-coin/historical_data?start=2024-05-03&end=2024-10-30
# swapbased-coin - Highest Volume within 90 days: ['swapbased-coin', '2024-10-28', '$0.000000000000000000', 1241.16, '$0.00234679', '$0.00241490']
# swapbased-coin - 7 Days Before Highest Volume: ['swapbased-coin', '2024-10-21', '$0.000000000000000000', '$400.67', '$0.00344453', '$0.00327756']
# Opened: https://www.coingecko.com/en/coins/swords-and-dungeons-gold/historical_data?start=2024-08-19&end=2025-02-15
# swords-and-dungeons-gold - Highest Volume within 90 days: ['swords-and-dungeons-gold', '2025-02-01', '$0.000000000000000000', 74217.0, '$0.02151045', '$0.02039688']
# swords-and-dungeons-gold - 7 Days Before Highest Volume: ['swords-and-dungeons-gold', '2025-01-30', '$0.000000000000000000', '$71,904', '$0.02039950', '$0.02128871']
# Opened: https://www.coingecko.com/en/coins/take-the-l/historical_data?start=2024-10-20&end=2025-04-18
# take-the-l - Highest Volume within 90 days: ['take-the-l', '2025-02-06', '$11,635.48', 55.68, '$0.00001175', '$0.00001126']
# take-the-l - 7 Days Before Highest Volume: ['take-the-l', '2025-02-15', '$10,780.99', '$3.06', '$0.00001097', '$0.00001009']
# Opened: https://www.coingecko.com/en/coins/tamadoge/historical_data?start=2022-08-26&end=2023-02-22
# tamadoge - Highest Volume within 90 days: ['tamadoge', '2023-02-03', '$22,559,779', 2630168.0, '$0.02173890', '$0.02078501']
# tamadoge - 7 Days Before Highest Volume: ['tamadoge', '2023-02-11', '$19,772,255', '$1,086,095', '$0.01882990', '$0.01908093']
# Opened: https://www.coingecko.com/en/coins/tate-stop/historical_data?start=2024-04-04&end=2024-10-01
# tate-stop - Highest Volume within 90 days: ['tate-stop', '2024-09-11', '$70,962', 1300.11, '$0.00002729', '$0.00002711']
# tate-stop - 7 Days Before Highest Volume: ['tate-stop', '2024-09-10', '$70,962', '$1,300.11', '$0.00002729', '$0.00002729']
# Opened: https://www.coingecko.com/en/coins/teddy-bear/historical_data?start=2023-08-25&end=2024-02-21
# teddy-bear - Highest Volume within 90 days: ['teddy-bear', '2024-02-08', '$0.000000000000000000', 1664637.0, '$0.000000030381', '$0.000000033328']
# teddy-bear - 7 Days Before Highest Volume: ['teddy-bear', '2024-02-02', '$0.000000000000000000', '$1,093,187', '$0.000000026471', '$0.000000022765']
# Opened: https://www.coingecko.com/en/coins/terminal-of-fun/historical_data?start=2024-07-27&end=2025-01-23
# terminal-of-fun - Highest Volume within 90 days: ['terminal-of-fun', '2025-01-05', '$500,060', 1060696.0, '$0.00051350', '$0.00040765']
# terminal-of-fun - 7 Days Before Highest Volume: ['terminal-of-fun', '2025-01-07', '$305,205', '$638,681', '$0.00031364', '$0.00025002']
# Opened: https://www.coingecko.com/en/coins/the-big-debate/historical_data?start=2024-04-24&end=2024-10-21
# the-big-debate - Highest Volume within 90 days: ['the-big-debate', '2024-09-08', '$0.000000000000000000', 13214.06, '$0.000000410108', '$0.000000379624']
# Opened: https://www.coingecko.com/en/coins/the-cat-is-blue/historical_data?start=2024-02-21&end=2024-08-19
# the-cat-is-blue - Highest Volume within 90 days: ['the-cat-is-blue', '2024-08-02', '$0.000000000000000000', 1590.46, '$0.00001259', '$0.00000913']
# the-cat-is-blue - 7 Days Before Highest Volume: ['the-cat-is-blue', '2024-07-29', '$0.000000000000000000', '$745.05', '$0.00001203', '$0.00001196']
# Opened: https://www.coingecko.com/en/coins/the-doge-nft/historical_data?start=2021-06-08&end=2021-12-05
# the-doge-nft - Highest Volume within 90 days: ['the-doge-nft', '2021-11-23', '$87,703,682', 53955499.0, '$0.01941025', '$0.01646307']
# the-doge-nft - 7 Days Before Highest Volume: ['the-doge-nft', '2021-11-16', '$88,593,622', '$12,145,875', '$0.01969190', '$0.02793514']
# Opened: https://www.coingecko.com/en/coins/the-graph/historical_data?start=2020-10-04&end=2021-04-02
# the-graph - Highest Volume within 90 days: ['the-graph', '2021-03-29', '$2,218,790,270', 733381121.0, '$1.81', '$1.77']
# the-graph - 7 Days Before Highest Volume: ['the-graph', '2021-03-22', '$2,076,698,108', '$285,022,750', '$1.70', '$1.56']
# Opened: https://www.coingecko.com/en/coins/the-land-elf-crossing/historical_data?start=2024-02-20&end=2024-08-18
# the-land-elf-crossing - Highest Volume within 90 days: ['the-land-elf-crossing', '2024-08-18', '$0.000000000000000000', 125062.0, '$0.01471750', '$0.01419692']
# the-land-elf-crossing - 7 Days Before Highest Volume: ['the-land-elf-crossing', '2024-08-11', '$0.000000000000000000', '$100,618', '$0.01487180', '$0.01467742']
# Opened: https://www.coingecko.com/en/coins/the-new-genesis/historical_data?start=2024-11-23&end=2025-05-22
# the-new-genesis - Highest Volume within 90 days: ['the-new-genesis', '2025-02-24', '$14,472.23', 7549.02, '$0.00001503', '$0.00001174']
# the-new-genesis - 7 Days Before Highest Volume: ['the-new-genesis', '2025-02-17', '$27,862', '$89.69', '$0.00002902', '$0.00002596']
# Opened: https://www.coingecko.com/en/coins/the-other-party/historical_data?start=2023-09-13&end=2024-03-11
# the-other-party - Highest Volume within 90 days: ['the-other-party', '2024-02-28', '$213,192', 9808.51, '$0.000000059987', '$0.000000063818']
# the-other-party - 7 Days Before Highest Volume: ['the-other-party', '2024-02-21', '$256,413', '$1,580.03', '$0.000000072211', '$0.000000073665']
# Opened: https://www.coingecko.com/en/coins/titanx/historical_data?start=2023-08-11&end=2024-02-07
# titanx - Highest Volume within 90 days: ['titanx', '2024-02-03', '$0.000000000000000000', 3650337.0, '$0.00000146', '$0.00000127']
# titanx - 7 Days Before Highest Volume: ['titanx', '2024-01-27', '$0.000000000000000000', '$1,144,293', '$0.000000994253', '$0.000000985661']
# Opened: https://www.coingecko.com/en/coins/tokocrypto/historical_data?start=2021-01-07&end=2021-07-06
# tokocrypto - Highest Volume within 90 days: ['tokocrypto', '2021-06-23', '$98,795,785', 23141830.0, '$1.32', '$1.47']
# tokocrypto - 7 Days Before Highest Volume: ['tokocrypto', '2021-06-17', '$137,442,840', '$17,409,468', '$1.84', '$1.83']
# Opened: https://www.coingecko.com/en/coins/ton-fish-memecoin/historical_data?start=2023-11-15&end=2024-05-13
# ton-fish-memecoin - Highest Volume within 90 days: ['ton-fish-memecoin', '2024-05-11', '$18,968,069', 2357256.0, '$0.000000063136', '$0.000000060710']
# ton-fish-memecoin - 7 Days Before Highest Volume: ['ton-fish-memecoin', '2024-05-04', '$13,434,014', '$620,761', '$0.000000044360', '$0.000000041712']
# Opened: https://www.coingecko.com/en/coins/ton-kong/historical_data?start=2024-02-15&end=2024-08-13
# ton-kong - Highest Volume within 90 days: ['ton-kong', '2024-08-10', '$0.000000000000000000', 2592.58, '$0.00000313', '$0.00000325']
# ton-kong - 7 Days Before Highest Volume: ['ton-kong', '2024-08-03', '$0.000000000000000000', '$226.22', '$0.00000285', '$0.00000261']
# Opened: https://www.coingecko.com/en/coins/ton-tiger/historical_data?start=2024-06-15&end=2024-12-12
# ton-tiger - Highest Volume within 90 days: ['ton-tiger', '2024-12-08', '$0.000000000000000000', 2043.87, '$0.00016182', '$0.00014698']
# ton-tiger - 7 Days Before Highest Volume: ['ton-tiger', '2024-12-01', '$0.000000000000000000', '$872.21', '$0.00015719', '$0.00015557']
# Opened: https://www.coingecko.com/en/coins/tonhydra/historical_data?start=2024-04-24&end=2024-10-21
# tonhydra - Highest Volume within 90 days: ['tonhydra', '2024-10-08', '$0.000000000000000000', 182586.0, '$5.17', '$4.87']
# tonhydra - 7 Days Before Highest Volume: ['tonhydra', '2024-10-06', '$0.000000000000000000', '$55,461', '$5.49', '$5.50']
# Opened: https://www.coingecko.com/en/coins/toucan-protocol-base-carbon-tonne/historical_data?start=2021-09-02&end=2022-03-01
# toucan-protocol-base-carbon-tonne - Highest Volume within 90 days: ['toucan-protocol-base-carbon-tonne', '2022-02-11', '$78,540,292', 4658550.0, '$4.49', '$4.36']
# toucan-protocol-base-carbon-tonne - 7 Days Before Highest Volume: ['toucan-protocol-base-carbon-tonne', '2022-02-16', '$74,787,087', '$1,336,187', '$4.23', '$4.42']
# Opened: https://www.coingecko.com/en/coins/toucan-protocol-nature-carbon-tonne/historical_data?start=2022-02-27&end=2022-08-26
# toucan-protocol-nature-carbon-tonne - Highest Volume within 90 days: ['toucan-protocol-nature-carbon-tonne', '2022-08-24', '$0.000000000000000000', 27704.0, '$2.13', '$2.13']
# toucan-protocol-nature-carbon-tonne - 7 Days Before Highest Volume: ['toucan-protocol-nature-carbon-tonne', '2022-08-17', '$0.000000000000000000', '$2.52', '$2.31', '$2.32']
# Opened: https://www.coingecko.com/en/coins/trace-network-labs/historical_data?start=2021-12-28&end=2022-06-26
# trace-network-labs - Highest Volume within 90 days: ['trace-network-labs', '2022-06-07', '$0.000000000000000000', 21368.0, '$0.055990', '$0.059550']
# trace-network-labs - 7 Days Before Highest Volume: ['trace-network-labs', '2022-06-09', '$0.000000000000000000', '$9,828.82', '$0.057854', '$0.057762']
# Opened: https://www.coingecko.com/en/coins/treeplanting/historical_data?start=2024-05-24&end=2024-11-20
# treeplanting - Highest Volume within 90 days: ['treeplanting', '2024-11-07', '$0.000000000000000000', 1010.37, '$0.00003419', '$0.00003858']
# treeplanting - 7 Days Before Highest Volume: ['treeplanting', '2024-11-10', '$0.000000000000000000', '$68.56', '$0.00004133', '$0.00004063']
# Opened: https://www.coingecko.com/en/coins/tryton/historical_data?start=2024-09-27&end=2025-03-26
# tryton - Highest Volume within 90 days: ['tryton', '2025-03-03', '$0.000000000000000000', 3346.72, '$0.00085880', '$0.00076078']
# tryton - 7 Days Before Highest Volume: ['tryton', '2025-02-24', '$0.000000000000000000', '$564.63', '$0.00155515', '$0.00131342']
# Opened: https://www.coingecko.com/en/coins/unifarm/historical_data?start=2021-02-16&end=2021-08-15
# unifarm - Highest Volume within 90 days: ['unifarm', '2021-08-11', '$2,701,456', 31467.0, '$0.069508', '$0.070048']
# unifarm - 7 Days Before Highest Volume: ['unifarm', '2021-08-04', '$2,576,416', '$8,639.06', '$0.066193', '$0.071212']
# Opened: https://www.coingecko.com/en/coins/uno-re/historical_data?start=2021-01-28&end=2021-07-27
# uno-re - Highest Volume within 90 days: ['uno-re', '2021-07-23', '$0.000000000000000000', 504144.0, '$0.122750', '$0.134621']
# uno-re - 7 Days Before Highest Volume: ['uno-re', '2021-07-16', '$0.000000000000000000', '$95,297', '$0.127614', '$0.121287']
# Opened: https://www.coingecko.com/en/coins/vibe-cat-2/historical_data?start=2024-09-05&end=2025-03-04
# vibe-cat-2 - Highest Volume within 90 days: ['vibe-cat-2', '2025-02-13', '$2,019,591', 148443.0, '$0.00205628', '$0.00170852']
# vibe-cat-2 - 7 Days Before Highest Volume: ['vibe-cat-2', '2025-02-14', '$1,678,429', '$66,725', '$0.00170852', '$0.00197034']
# Opened: https://www.coingecko.com/en/coins/victoria-vr/historical_data?start=2021-11-08&end=2022-05-07
# victoria-vr - Highest Volume within 90 days: ['victoria-vr', '2022-04-25', '$119,829,516', 16951604.0, '$0.132776', '$0.131505']
# victoria-vr - 7 Days Before Highest Volume: ['victoria-vr', '2022-04-18', '$138,579,206', '$12,925,979', '$0.153423', '$0.154585']
# Opened: https://www.coingecko.com/en/coins/viking-elon/historical_data?start=2022-02-20&end=2022-08-19
# viking-elon - Highest Volume within 90 days: ['viking-elon', '2022-08-03', '$0.000000000000000000', 9703.42, '$0.000000021128', '$0.000000021023']
# viking-elon - 7 Days Before Highest Volume: ['viking-elon', '2022-08-06', '$0.000000000000000000', '$9,035.24', '$0.000000021027', '$0.000000021076']
# Opened: https://www.coingecko.com/en/coins/vine/historical_data?start=2024-11-09&end=2025-05-08
# vine - Highest Volume within 90 days: ['vine', '2025-02-23', '$42,423,911', 212709750.0, '$0.04232746', '$0.03740142']
# vine - 7 Days Before Highest Volume: ['vine', '2025-02-16', '$56,608,074', '$75,343,621', '$0.056630', '$0.055671']
# Opened: https://www.coingecko.com/en/coins/vitality/historical_data?start=2021-09-18&end=2022-03-17
# vitality - Highest Volume within 90 days: ['vitality', '2022-03-04', '$0.000000000000000000', 17005.12, '$0.00018013', '$0.00017776']
# vitality - 7 Days Before Highest Volume: ['vitality', '2022-03-02', '$0.000000000000000000', '$225.99', '$0.00024036', '$0.00024384']
# Opened: https://www.coingecko.com/en/coins/water-on-sui/historical_data?start=2024-07-28&end=2025-01-24
# water-on-sui - Highest Volume within 90 days: ['water-on-sui', '2025-01-21', '$81,621', 2179.63, '$0.00000816', '$0.00000837']
# water-on-sui - 7 Days Before Highest Volume: ['water-on-sui', '2025-01-14', '$80,936', '$86.42', '$0.00000809', '$0.00000782']
# Opened: https://www.coingecko.com/en/coins/wateract/historical_data?start=2024-02-17&end=2024-08-15
# wateract - Highest Volume within 90 days: ['wateract', '2024-08-10', '$0.000000000000000000', 53615.0, '$2.40', '$2.40']
# wateract - 7 Days Before Highest Volume: ['wateract', '2024-08-03', '$0.000000000000000000', '$38,112', '$2.39', '$2.39']
# Opened: https://www.coingecko.com/en/coins/weecoins-premium/historical_data?start=2024-05-15&end=2024-11-11
# weecoins-premium - Highest Volume within 90 days: ['weecoins-premium', '2024-10-26', '$0.000000000000000000', 6318.85, '$0.03383271', '$0.03385874']
# weecoins-premium - 7 Days Before Highest Volume: ['weecoins-premium', '2024-11-03', '$0.000000000000000000', '$4,768.13', '$0.03389045', '$0.03389262']
# Opened: https://www.coingecko.com/en/coins/welsh-corgi/historical_data?start=2024-01-22&end=2024-07-20
# welsh-corgi - Highest Volume within 90 days: ['welsh-corgi', '2024-07-14', '$0.000000000000000000', 2202.09, '$0.01410557', '$0.01224833']
# welsh-corgi - 7 Days Before Highest Volume: ['welsh-corgi', '2024-07-07', '$0.000000000000000000', '$77.04', '$0.01177950', '$0.01177950']
# Opened: https://www.coingecko.com/en/coins/why/historical_data?start=2024-01-31&end=2024-07-29
# why - Highest Volume within 90 days: ['why', '2024-07-22', '$97,900,307', 3628057.0, '$0.000000233579', '$0.000000221206']
# why - 7 Days Before Highest Volume: ['why', '2024-07-15', '$62,628,347', '$795,097', '$0.000000148804', '$0.000000180570']
# Opened: https://www.coingecko.com/en/coins/wine-shares/historical_data?start=2021-11-12&end=2022-05-11
# wine-shares - Highest Volume within 90 days: ['wine-shares', '2022-05-04', '$0.000000000000000000', 231759.0, '$296.19', '$312.32']
# wine-shares - 7 Days Before Highest Volume: ['wine-shares', '2022-04-27', '$0.000000000000000000', '$66,961', '$240.03', '$254.26']
# Opened: https://www.coingecko.com/en/coins/wojak-mask/historical_data?start=2024-03-10&end=2024-09-06
# wojak-mask - Highest Volume within 90 days: ['wojak-mask', '2024-08-25', '$0.000000000000000000', 14902.47, '$0.000000487583', '$0.000000438476']
# wojak-mask - 7 Days Before Highest Volume: ['wojak-mask', '2024-08-18', '$0.000000000000000000', '$11,794.88', '$0.000000462779', '$0.000000432833']
# Opened: https://www.coingecko.com/en/coins/wonderland/historical_data?start=2021-07-24&end=2022-01-20
# wonderland - Highest Volume within 90 days: ['wonderland', '2022-01-18', '$1,107,475,496', 162073331.0, '$1,268.85', '$1,383.16']
# wonderland - 7 Days Before Highest Volume: ['wonderland', '2022-01-11', '$145,108,570', '$66,430,999', '$2,062.25', '$2,147.58']
# Opened: https://www.coingecko.com/en/coins/wonderman-nation/historical_data?start=2022-03-06&end=2022-09-02
# wonderman-nation - Highest Volume within 90 days: ['wonderman-nation', '2022-08-20', '$554,759', 6959561.0, '$0.02983283', '$0.03024997']
# wonderman-nation - 7 Days Before Highest Volume: ['wonderman-nation', '2022-08-20', '$554,759', '$6,959,561', '$0.02983283', '$0.03024997']
# Opened: https://www.coingecko.com/en/coins/woop/historical_data?start=2022-03-02&end=2022-08-29
# woop - Highest Volume within 90 days: ['woop', '2022-08-27', '$0.000000000000000000', 2584.39, '$0.01222933', '$0.01177969']
# woop - 7 Days Before Highest Volume: ['woop', '2022-08-20', '$0.000000000000000000', '$648.94', '$0.01437402', '$0.01410275']
# Highest volume data within 90 days saved to highest_volume_historical_data.csv
