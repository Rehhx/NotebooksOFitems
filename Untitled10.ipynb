# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# Load the CSV file
file_path = r"C:\Users\pcagm\Downloads\split_file_3.csv"
df = pd.read_csv(file_path)

# Convert Date column to datetime format
df["Date"] = pd.to_datetime(df["Date"], errors='coerce')

# Filter token IDs and dates where wasRekt = 1 and volume is empty
rekt_data = df[(df["wasRekt"] == 1) & (df["volume"].isna())][["id", "Date"]].dropna()

# Initialize Selenium WebDriver
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)

historical_data = []

for index, row in rekt_data.iterrows():
    try:
        token_id = row["id"]
        date_str = row["Date"]
        date_obj = pd.to_datetime(date_str, errors='coerce')
        if pd.isna(date_obj):
            print(f"Skipping {token_id} due to invalid date format")
            continue

        max_years_back = 7 * 365  # Maximum search range in days (7 years)
        max_years_forward = (pd.Timestamp.today() - date_obj).days  # Days until current date
        
        # Backward search intervals
        backward_intervals = [90, 180, 365, 730, 1095]  # 3 months, 6 months, 1 year, 2 years, 3 years
        while backward_intervals[-1] < max_years_back:
            backward_intervals.append(backward_intervals[-1] + 90)  # 3-month intervals after 3 years

        # Forward search intervals
        forward_intervals = [1, 3, 9, 27, 60, 120, 180]  # 1 day, 3 days, 9 days, 27 days, 2 months, 4 months, 6 months
        while forward_intervals[-1] < max_years_forward:
            forward_intervals.append(forward_intervals[-1] + 90)  # 3-month intervals after 6 months

        data_found = False

        # Backward search
        for days_back in backward_intervals:
            if data_found:
                break
            start_date = (date_obj - pd.Timedelta(days=days_back)).strftime("%Y-%m-%d")
            end_date = (date_obj - pd.Timedelta(days=days_back - 1)).strftime("%Y-%m-%d")
            url = f"https://www.coingecko.com/en/coins/{token_id}/historical_data?start={start_date}&end={end_date}"
            driver.get(url)
            print(f"Opened: {url}")
            time.sleep(5)

            try:
                rows = driver.find_elements(By.CSS_SELECTOR, "table tbody tr")
                if rows:
                    row = rows[0]  # Only grab the first available row
                    cols = row.find_elements(By.TAG_NAME, "td")
                    if len(cols) >= 4:
                        date = cols[0].text
                        market_cap = cols[1].text
                        volume = cols[2].text
                        open_price = cols[3].text
                        close_price = cols[4].text if len(cols) > 4 else "N/A"
                        historical_data.append([token_id, date, market_cap, volume, open_price, close_price])
                        print(f"{token_id} - {date}: Market Cap={market_cap}, Volume={volume}, Open={open_price}, Close={close_price}")
                        data_found = True
            except:
                print(f"No historical data found for {token_id} on {start_date}")

        # Forward search if no data found
        if not data_found:
            for days_forward in forward_intervals:
                start_date = (date_obj + pd.Timedelta(days=days_forward)).strftime("%Y-%m-%d")
                end_date = (date_obj + pd.Timedelta(days=days_forward + 1)).strftime("%Y-%m-%d")
                url = f"https://www.coingecko.com/en/coins/{token_id}/historical_data?start={start_date}&end={end_date}"
                driver.get(url)
                print(f"Opened: {url}")
                time.sleep(5)

                try:
                    rows = driver.find_elements(By.CSS_SELECTOR, "table tbody tr")
                    if rows:
                        row = rows[0]
                        cols = row.find_elements(By.TAG_NAME, "td")
                        if len(cols) >= 4:
                            date = cols[0].text
                            market_cap = cols[1].text
                            volume = cols[2].text
                            open_price = cols[3].text
                            close_price = cols[4].text if len(cols) > 4 else "N/A"
                            historical_data.append([token_id, date, market_cap, volume, open_price, close_price])
                            print(f"{token_id} - {date}: Market Cap={market_cap}, Volume={volume}, Open={open_price}, Close={close_price}")
                            data_found = True
                            break
                except:
                    print(f"No historical data found for {token_id} on {start_date}")
    
    except Exception as e:
        print(f"Error fetching historical data for {token_id}: {e}")

# Convert to DataFrame and save
historical_df = pd.DataFrame(historical_data, columns=["id", "Date", "market_cap", "volume", "open", "close"])
historical_df.to_csv("historical_data_split_file_3.csv", index=False)
print("Historical data saved to historical_data_split_file_3.csv")

driver.quit()
# Out:
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2024-02-08&end=2024-02-09
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2023-11-10&end=2023-11-11
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2023-05-09&end=2023-05-10
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2022-05-09&end=2022-05-10
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2021-05-09&end=2021-05-10
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2021-02-08&end=2021-02-09
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2020-11-10&end=2020-11-11
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2020-08-12&end=2020-08-13
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2020-05-14&end=2020-05-15
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2020-02-14&end=2020-02-15
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2019-11-16&end=2019-11-17
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2019-08-18&end=2019-08-19
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2019-05-20&end=2019-05-21
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2019-02-19&end=2019-02-20
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=
for row in rows:
                cols = row.find_elements(By.TAG_NAME, "td")
                if len(cols) >= 4:
                    date = cols[0].text
                    market_cap = cols[1].text
                    volume = float(cols[2].text.replace('$', '').replace(',', '')) if cols[2].text else 0
                    open_price = cols[3].text
                    close_price = cols[4].text if len(cols) > 4 else "N/A"
                    
                    if volume > highest_volume:
                        highest_volume = volume
                        highest_volume_entry = [token_id, date, market_cap, volume, open_price, close_price]
                        
                        # Look for the data 7 days before the highest volume date
                        seven_days_before_date = (pd.to_datetime(date) - pd.Timedelta(days=7)).strftime("%Y-%m-%d")
                        for prev_row in rows:
                            prev_cols = prev_row.find_elements(By.TAG_NAME, "td")
                            if len(prev_cols) >= 4 and prev_cols[0].text == seven_days_before_date:
                                seven_days_before_entry = [token_id, prev_cols[0].text, prev_cols[1].text, prev_cols[2].text, prev_cols[3].text, prev_cols[4].text]
                                break
            
            if highest_volume_entry:
                highest_volume_data.append(highest_volume_entry)
                print(f"{token_id} - Highest Volume within 90 days: {highest_volume_entry}")
                if seven_days_before_entry:
                    highest_volume_data.append(seven_days_before_entry)
                    print(f"{token_id} - 7 Days Before Highest Volume: {seven_days_before_entry}")
        except:
            print(f"No historical data found for {token_id} in the given range")
    
    except Exception as e:
        print(f"Error fetching historical data for {token_id}: {e}")

# Convert to DataFrame and save
highest_volume_df = pd.DataFrame(highest_volume_data, columns=["id", "Date", "market_cap", "volume", "open", "close"])
highest_volume_df.to_csv("highest_volume_historical_data_split_file_3.csv", index=False)
print("Highest volume data within 90 days saved to highest_volume_historical_data_split_file_3.csv")

driver.quit()
# Out:
# Opened: https://www.coingecko.com/en/coins/lifeform/historical_data?start=2024-02-18&end=2024-08-16
# lifeform - Highest Volume within 90 days: ['lifeform', '2024-08-07', '$4,860,980', 1008707.0, '$0.04015845', '$0.02944942']
# lifeform - 7 Days Before Highest Volume: ['lifeform', '2024-07-31', '$3,928,961', '$438,298', '$0.03274134', '$0.03200989']
# Opened: https://www.coingecko.com/en/coins/lil-bub-on-sol/historical_data?start=2024-05-13&end=2024-11-09
# lil-bub-on-sol - Highest Volume within 90 days: ['lil-bub-on-sol', '2024-10-22', '$400,514', 56325.0, '$0.00039934', '$0.00020338']
# lil-bub-on-sol - 7 Days Before Highest Volume: ['lil-bub-on-sol', '2024-10-23', '$203,506', '$36,171', '$0.00020338', '$0.00015382']
# Opened: https://www.coingecko.com/en/coins/linda-2/historical_data?start=2023-11-11&end=2024-05-09
# linda-2 - Highest Volume within 90 days: ['linda-2', '2024-04-25', '$5,797,626', 446743.0, '$0.00006138', '$0.00005367']
# linda-2 - 7 Days Before Highest Volume: ['linda-2', '2024-04-25', '$5,797,626', '$446,743', '$0.00006138', '$0.00005367']
# Opened: https://www.coingecko.com/en/coins/linkpool/historical_data?start=2020-12-30&end=2021-06-28
# linkpool - Highest Volume within 90 days: ['linkpool', '2021-06-25', '$0.000000000000000000', 465389.0, '$2.80', '$2.61']
# linkpool - 7 Days Before Highest Volume: ['linkpool', '2021-06-18', '$0.000000000000000000', '$278,952', '$3.79', '$3.50']
# Opened: https://www.coingecko.com/en/coins/lodestar/historical_data?start=2022-10-25&end=2023-04-23
# lodestar - Highest Volume within 90 days: ['lodestar', '2023-04-16', '$4,814,057', 1102895.0, '$2.30', '$1.92']
# lodestar - 7 Days Before Highest Volume: ['lodestar', '2023-04-09', '$2,098,692', '$214,175', '$1.30', '$1.77']
# Opened: https://www.coingecko.com/en/coins/lokr/historical_data?start=2021-01-07&end=2021-07-06
# lokr - Highest Volume within 90 days: ['lokr', '2021-06-18', '$1,822,327', 137705.0, '$0.133478', '$0.124703']
# lokr - 7 Days Before Highest Volume: ['lokr', '2021-06-17', '$1,838,315', '$112,768', '$0.135425', '$0.133478']
# Opened: https://www.coingecko.com/en/coins/lol-3/historical_data?start=2024-07-27&end=2025-01-23
# lol-3 - Highest Volume within 90 days: ['lol-3', '2025-01-23', '$7,881,821', 1001625.0, '$0.00803732', '$0.00672639']
# lol-3 - 7 Days Before Highest Volume: ['lol-3', '2025-01-16', '$4,174,986', '$80,352', '$0.00427174', '$0.00454363']
# Opened: https://www.coingecko.com/en/coins/lrt-squared/historical_data?start=2024-09-04&end=2025-03-03
# lrt-squared - Highest Volume within 90 days: ['lrt-squared', '2025-02-15', '$13,486,358', 684509.0, '$1,098.90', '$1,035.54']
# lrt-squared - 7 Days Before Highest Volume: ['lrt-squared', '2025-02-12', '$6,161,152', '$21,222', '$1,081.68', '$1,098.33']
# Opened: https://www.coingecko.com/en/coins/luckybird/historical_data?start=2023-07-03&end=2023-12-30
# luckybird - Highest Volume within 90 days: ['luckybird', '2023-12-11', '$0.000000000000000000', 1002656.0, '$1.11', '$1.18']
# luckybird - 7 Days Before Highest Volume: ['luckybird', '2023-12-18', '$0.000000000000000000', '$575,001', '$1.16', '$1.12']
# Opened: https://www.coingecko.com/en/coins/lumichill/historical_data?start=2024-05-11&end=2024-11-07
# lumichill - Highest Volume within 90 days: ['lumichill', '2024-10-31', '$0.000000000000000000', 274095.0, '$0.000000017599', '$0.000000017916']
# lumichill - 7 Days Before Highest Volume: ['lumichill', '2024-10-24', '$0.000000000000000000', '$27,705', '$0.000000017845', '$0.000000018371']
# Opened: https://www.coingecko.com/en/coins/magnet-2/historical_data?start=2024-09-30&end=2025-03-29
# magnet-2 - Highest Volume within 90 days: ['magnet-2', '2025-02-13', '$133,675', 35578.0, '$0.00013368', '$0.00013286']
# magnet-2 - 7 Days Before Highest Volume: ['magnet-2', '2025-02-14', '$132,839', '$1,015.34', '$0.00013286', '$0.00013161']
# Opened: https://www.coingecko.com/en/coins/magnificent-7777/historical_data?start=2024-09-13&end=2025-03-12
# magnificent-7777 - Highest Volume within 90 days: ['magnificent-7777', '2025-02-25', '$8,828.64', 170.74, '$0.00113511', '$0.00095036']
# magnificent-7777 - 7 Days Before Highest Volume: ['magnificent-7777', '2025-02-25', '$8,828.64', '$170.74', '$0.00113511', '$0.00095036']
# Opened: https://www.coingecko.com/en/coins/maximus-lucky/historical_data?start=2022-08-09&end=2023-02-05
# maximus-lucky - Highest Volume within 90 days: ['maximus-lucky', '2023-01-23', '$0.000000000000000000', 32161.0, '$0.02225616', '$0.02306030']
# maximus-lucky - 7 Days Before Highest Volume: ['maximus-lucky', '2023-01-28', '$0.000000000000000000', '$4,853.44', '$0.02511307', '$0.02392393']
# Opened: https://www.coingecko.com/en/coins/maxx-2/historical_data?start=2024-10-28&end=2025-04-26
# maxx-2 - Highest Volume within 90 days: ['maxx-2', '2025-02-22', '$25,700', 1638.65, '$0.00002568', '$0.00002588']
# maxx-2 - 7 Days Before Highest Volume: ['maxx-2', '2025-02-15', '$29,993', '$659.87', '$0.00003019', '$0.00002998']
# Opened: https://www.coingecko.com/en/coins/mcfinance/historical_data?start=2021-06-18&end=2021-12-15
# mcfinance - Highest Volume within 90 days: ['mcfinance', '2021-11-26', '$0.000000000000000000', 117145.0, '$0.056945', '$0.055980']
# mcfinance - 7 Days Before Highest Volume: ['mcfinance', '2021-11-28', '$0.000000000000000000', '$48,407', '$0.059028', '$0.060937']
# Opened: https://www.coingecko.com/en/coins/mcoin-2/historical_data?start=2024-06-22&end=2024-12-19
# mcoin-2 - Highest Volume within 90 days: ['mcoin-2', '2024-11-30', '$185,816', 155103.0, '$0.00018684', '$0.00017958']
# mcoin-2 - 7 Days Before Highest Volume: ['mcoin-2', '2024-12-10', '$161,355', '$135,822', '$0.00016121', '$0.00015257']
# Opened: https://www.coingecko.com/en/coins/medicle/historical_data?start=2023-06-15&end=2023-12-12
# medicle - Highest Volume within 90 days: ['medicle', '2023-12-01', '$0.000000000000000000', 408185.0, '$0.362563', '$0.364544']
# medicle - 7 Days Before Highest Volume: ['medicle', '2023-11-24', '$0.000000000000000000', '$382,004', '$0.373777', '$0.374435']
# Opened: https://www.coingecko.com/en/coins/melo/historical_data?start=2024-08-09&end=2025-02-05
# melo - Highest Volume within 90 days: ['melo', '2025-01-17', '$343,133', 89234.0, '$0.000000815643', '$0.000000715594']
# melo - 7 Days Before Highest Volume: ['melo', '2025-01-17', '$343,133', '$89,234', '$0.000000815643', '$0.000000715594']
# Opened: https://www.coingecko.com/en/coins/melon/historical_data?start=2023-08-28&end=2024-02-24
# melon - Highest Volume within 90 days: ['melon', '2024-01-27', '$0.000000000000000000', 641.74, '$0.00034920', '$0.00033848']
# melon - 7 Days Before Highest Volume: ['melon', '2024-02-01', '$0.000000000000000000', '$40.85', '$0.00034462', '$0.00033817']
# Opened: https://www.coingecko.com/en/coins/merchdao/historical_data?start=2020-12-29&end=2021-06-27
# merchdao - Highest Volume within 90 days: ['merchdao', '2021-06-14', '$0.000000000000000000', 547719.0, '$0.196173', '$0.164170']
# merchdao - 7 Days Before Highest Volume: ['merchdao', '2021-06-08', '$0.000000000000000000', '$220,689', '$0.134958', '$0.123506']
# Opened: https://www.coingecko.com/en/coins/mercurial/historical_data?start=2021-03-02&end=2021-08-29
# mercurial - Highest Volume within 90 days: ['mercurial', '2021-08-18', '$29,363,965', 4960021.0, '$0.527645', '$0.540629']
# mercurial - 7 Days Before Highest Volume: ['mercurial', '2021-08-11', '$24,991,751', '$511,041', '$0.454349', '$0.466150']
# Opened: https://www.coingecko.com/en/coins/meshchain-coin/historical_data?start=2024-10-28&end=2025-04-26
# meshchain-coin - Highest Volume within 90 days: ['meshchain-coin', '2025-03-03', '$0.000000000000000000', 1871902.0, '$0.293912', '$0.300971']
# meshchain-coin - 7 Days Before Highest Volume: ['meshchain-coin', '2025-02-24', '$0.000000000000000000', '$35,135', '$0.259006', '$0.285661']
# Opened: https://www.coingecko.com/en/coins/metablox/historical_data?start=2023-09-12&end=2024-03-10
# metablox - Highest Volume within 90 days: ['metablox', '2024-02-20', '$0.000000000000000000', 41892.0, '$0.04459165', '$0.04002928']
# metablox - 7 Days Before Highest Volume: ['metablox', '2024-02-27', '$0.000000000000000000', '$5,772.61', '$0.03663182', '$0.03231710']
# Opened: https://www.coingecko.com/en/coins/metars-genesis/historical_data?start=2022-06-15&end=2022-12-12
# metars-genesis - Highest Volume within 90 days: ['metars-genesis', '2022-11-25', '$7,087,900', 685214.0, '$0.799422', '$0.785268']
# metars-genesis - 7 Days Before Highest Volume: ['metars-genesis', '2022-11-23', '$7,196,116', '$680,295', '$0.813382', '$0.825752']
# Opened: https://www.coingecko.com/en/coins/mikeneko/historical_data?start=2023-12-31&end=2024-06-28
# mikeneko - Highest Volume within 90 days: ['mikeneko', '2024-06-19', '$0.000000000000000000', 732.34, '$0.00018216', '$0.00014717']
# mikeneko - 7 Days Before Highest Volume: ['mikeneko', '2024-06-12', '$0.000000000000000000', '$72.92', '$0.00023512', '$0.00022725']
# Opened: https://www.coingecko.com/en/coins/mintswaptoken/historical_data?start=2024-07-05&end=2025-01-01
# mintswaptoken - Highest Volume within 90 days: ['mintswaptoken', '2024-12-17', '$339,754', 5334.25, '$0.00645704', '$0.00627169']
# mintswaptoken - 7 Days Before Highest Volume: ['mintswaptoken', '2024-12-13', '$327,886', '$1,456.77', '$0.00628578', '$0.00630038']
# Opened: https://www.coingecko.com/en/coins/monbasecoin/historical_data?start=2024-01-13&end=2024-07-11
# monbasecoin - Highest Volume within 90 days: ['monbasecoin', '2024-07-04', '$0.000000000000000000', 86023.0, '$0.03122679', '$0.03006103']
# monbasecoin - 7 Days Before Highest Volume: ['monbasecoin', '2024-06-27', '$0.000000000000000000', '$42,289', '$0.03845710', '$0.03845710']
# Opened: https://www.coingecko.com/en/coins/monkey-2/historical_data?start=2024-01-10&end=2024-07-08
# monkey-2 - Highest Volume within 90 days: ['monkey-2', '2024-07-08', '$693,577', 248803.0, '$0.000000001815', '$0.000000002034']
# monkey-2 - 7 Days Before Highest Volume: ['monkey-2', '2024-07-01', '$538,004', '$96,340', '$0.000000001408', '$0.000000001448']
# Opened: https://www.coingecko.com/en/coins/moon-the-cat/historical_data?start=2024-08-04&end=2025-01-31
# moon-the-cat - Highest Volume within 90 days: ['moon-the-cat', '2025-01-15', '$12,139.79', 1326.16, '$0.00001270', '$0.00001306']
# moon-the-cat - 7 Days Before Highest Volume: ['moon-the-cat', '2025-01-13', '$12,296.93', '$278.97', '$0.00001281', '$0.00001215']
# Opened: https://www.coingecko.com/en/coins/morpheus-token/historical_data?start=2021-07-17&end=2022-01-13
# morpheus-token - Highest Volume within 90 days: ['morpheus-token', '2022-01-13', '$0.000000000000000000', 827284.0, '$0.597908', '$1.021']
# morpheus-token - 7 Days Before Highest Volume: ['morpheus-token', '2022-01-06', '$0.000000000000000000', '$47,845', '$0.275147', '$0.301893']
# Opened: https://www.coingecko.com/en/coins/morpho-degen/historical_data?start=2024-10-29&end=2025-04-27
# Opened: https://www.coingecko.com/en/coins/mother-iggy/historical_data?start=2024-05-09&end=2024-11-05
# mother-iggy - Highest Volume within 90 days: ['mother-iggy', '2024-10-28', '$66,862,380', 11607059.0, '$0.067684', '$0.067021']
# mother-iggy - 7 Days Before Highest Volume: ['mother-iggy', '2024-10-21', '$68,547,491', '$10,510,796', '$0.069569', '$0.062408']
# Opened: https://www.coingecko.com/en/coins/movement/historical_data?start=2024-10-08&end=2025-04-06
# movement - Highest Volume within 90 days: ['movement', '2025-02-22', '$1,159,347,386', 185498798.0, '$0.483064', '$0.497282']
# movement - 7 Days Before Highest Volume: ['movement', '2025-02-15', '$1,397,198,783', '$175,160,488', '$0.581766', '$0.557493']
# Opened: https://www.coingecko.com/en/coins/movemovecoin/historical_data?start=2024-05-25&end=2024-11-21
# movemovecoin - Highest Volume within 90 days: ['movemovecoin', '2024-11-07', '$0.000000000000000000', 146753.0, '$0.00035930', '$0.00032836']
# movemovecoin - 7 Days Before Highest Volume: ['movemovecoin', '2024-11-08', '$0.000000000000000000', '$9,198.19', '$0.00032836', '$0.00036383']
# Opened: https://www.coingecko.com/en/coins/mozaic/historical_data?start=2023-07-27&end=2024-01-23
# mozaic - Highest Volume within 90 days: ['mozaic', '2024-01-23', '$9,995,478', 753056.0, '$0.128600', '$0.133725']
# mozaic - 7 Days Before Highest Volume: ['mozaic', '2024-01-16', '$12,353,962', '$189,697', '$0.160687', '$0.160414']
# Opened: https://www.coingecko.com/en/coins/mpx6900/historical_data?start=2024-07-23&end=2025-01-19
# mpx6900 - Highest Volume within 90 days: ['mpx6900', '2025-01-19', '$795,375', 88118.0, '$0.00079554', '$0.00069456']
# mpx6900 - 7 Days Before Highest Volume: ['mpx6900', '2025-01-12', '$447,270', '$8,054.42', '$0.00044736', '$0.00044587']
# Opened: https://www.coingecko.com/en/coins/multipad/historical_data?start=2021-06-30&end=2021-12-27
# multipad - Highest Volume within 90 days: ['multipad', '2021-12-18', '$957,778', 325517.0, '$0.03941619', '$0.03589118']
# multipad - 7 Days Before Highest Volume: ['multipad', '2021-12-11', '$1,067,592', '$86,039', '$0.04339759', '$0.04219707']
# Opened: https://www.coingecko.com/en/coins/my-master-war/historical_data?start=2021-07-10&end=2022-01-06
# my-master-war - Highest Volume within 90 days: ['my-master-war', '2021-12-20', '$8,263,349', 1052695.0, '$1.29', '$1.062']
# my-master-war - 7 Days Before Highest Volume: ['my-master-war', '2021-12-29', '$3,310,751', '$379,010', '$0.480915', '$0.429038']
# Opened: https://www.coingecko.com/en/coins/mystery-2/historical_data?start=2024-11-09&end=2025-05-08
# mystery-2 - Highest Volume within 90 days: ['mystery-2', '2025-02-23', '$7,542,282', 8503324.0, '$0.000000017928', '$0.000000014969']
# mystery-2 - 7 Days Before Highest Volume: ['mystery-2', '2025-02-16', '$2,394,006', '$250,388', '$0.000000005691', '$0.000000005852']
# Opened: https://www.coingecko.com/en/coins/nemo-sum/historical_data?start=2024-04-09&end=2024-10-06
# nemo-sum - Highest Volume within 90 days: ['nemo-sum', '2024-09-21', '$3,967,607', 186686.0, '$0.00410551', '$0.00428751']
# nemo-sum - 7 Days Before Highest Volume: ['nemo-sum', '2024-09-21', '$3,967,607', '$186,686', '$0.00410551', '$0.00428751']
# Opened: https://www.coingecko.com/en/coins/newmoney-ai/historical_data?start=2024-11-06&end=2025-05-05
# newmoney-ai - Highest Volume within 90 days: ['newmoney-ai', '2025-02-20', '$269,913', 11862.52, '$0.00029175', '$0.00029872']
# newmoney-ai - 7 Days Before Highest Volume: ['newmoney-ai', '2025-02-13', '$403,242', '$597.09', '$0.00043587', '$0.00036003']
# Opened: https://www.coingecko.com/en/coins/nftb/historical_data?start=2021-03-31&end=2021-09-27
# nftb - Highest Volume within 90 days: ['nftb', '2021-09-27', '$20,058,672', 2940766.0, '$0.170672', '$0.179022']
# nftb - 7 Days Before Highest Volume: ['nftb', '2021-09-20', '$14,004,802', '$651,321', '$0.119117', '$0.106061']
# Opened: https://www.coingecko.com/en/coins/nftrade/historical_data?start=2021-07-02&end=2021-12-29
# nftrade - Highest Volume within 90 days: ['nftrade', '2021-12-10', '$0.000000000000000000', 976679.0, '$0.916032', '$0.905454']
# nftrade - 7 Days Before Highest Volume: ['nftrade', '2021-12-20', '$0.000000000000000000', '$174,861', '$0.971302', '$0.869704']
# Opened: https://www.coingecko.com/en/coins/nobiko-coin/historical_data?start=2024-02-18&end=2024-08-16
# nobiko-coin - Highest Volume within 90 days: ['nobiko-coin', '2024-07-30', '$5,242,591', 373234.0, '$0.00525105', '$0.00482491']
# nobiko-coin - 7 Days Before Highest Volume: ['nobiko-coin', '2024-07-30', '$5,242,591', '$373,234', '$0.00525105', '$0.00482491']
# Opened: https://www.coingecko.com/en/coins/nutflex/historical_data?start=2024-02-08&end=2024-08-06
# nutflex - Highest Volume within 90 days: ['nutflex', '2024-07-22', '$0.000000000000000000', 153254.0, '$0.00064190', '$0.00075533']
# nutflex - 7 Days Before Highest Volume: ['nutflex', '2024-07-20', '$0.000000000000000000', '$21,494', '$0.00034021', '$0.00041834']
# Opened: https://www.coingecko.com/en/coins/onetokenburn/historical_data?start=2024-05-17&end=2024-11-13
# onetokenburn - Highest Volume within 90 days: ['onetokenburn', '2024-10-27', '$66,333', 1783.49, '$0.124174', '$0.125589']
# onetokenburn - 7 Days Before Highest Volume: ['onetokenburn', '2024-11-05', '$63,679', '$50.04', '$0.119136', '$0.119467']
# Opened: https://www.coingecko.com/en/coins/openfabric/historical_data?start=2023-07-31&end=2024-01-27
# openfabric - Highest Volume within 90 days: ['openfabric', '2024-01-16', '$9,558,975', 1312206.0, '$0.185188', '$0.177278']
# openfabric - 7 Days Before Highest Volume: ['openfabric', '2024-01-09', '$8,560,337', '$597,584', '$0.166485', '$0.173777']
# Opened: https://www.coingecko.com/en/coins/orange-2/historical_data?start=2024-05-07&end=2024-11-03
# orange-2 - Highest Volume within 90 days: ['orange-2', '2024-11-01', '$0.000000000000000000', 10255.34, '$0.00402945', '$0.00402172']
# orange-2 - 7 Days Before Highest Volume: ['orange-2', '2024-10-25', '$0.000000000000000000', '$2,737.78', '$0.00367198', '$0.00376254']
# Opened: https://www.coingecko.com/en/coins/orbit-protocol/historical_data?start=2024-01-25&end=2024-07-23
# orbit-protocol - Highest Volume within 90 days: ['orbit-protocol', '2024-07-15', '$0.000000000000000000', 40513.0, '$0.02404211', '$0.02677776']
# orbit-protocol - 7 Days Before Highest Volume: ['orbit-protocol', '2024-07-08', '$0.000000000000000000', '$4,929.31', '$0.01974774', '$0.01972986']
# Opened: https://www.coingecko.com/en/coins/osmosis-allarb/historical_data?start=2024-09-23&end=2025-03-22
# osmosis-allarb - Highest Volume within 90 days: ['osmosis-allarb', '2025-03-03', '$70,726', 8452.22, '$0.462642', '$0.392823']
# osmosis-allarb - 7 Days Before Highest Volume: ['osmosis-allarb', '2025-02-24', '$74,318', '$1,853.82', '$0.479562', '$0.411455']
# Opened: https://www.coingecko.com/en/coins/palmpay/historical_data?start=2022-09-27&end=2023-03-26
# palmpay - Highest Volume within 90 days: ['palmpay', '2023-03-14', '$0.000000000000000000', 45224.0, '$0.164901', '$0.161926']
# palmpay - 7 Days Before Highest Volume: ['palmpay', '2023-03-07', '$0.000000000000000000', '$44,116', '$0.200639', '$0.184126']
# Opened: https://www.coingecko.com/en/coins/papa-on-sol/historical_data?start=2023-12-24&end=2024-06-21
# papa-on-sol - Highest Volume within 90 days: ['papa-on-sol', '2024-06-10', '$0.000000000000000000', 300.01, '$0.00001009', '$0.00000995']
# papa-on-sol - 7 Days Before Highest Volume: ['papa-on-sol', '2024-06-03', '$0.000000000000000000', '$46.18', '$0.00000952', '$0.00000955']
# Opened: https://www.coingecko.com/en/coins/parasol-finance/historical_data?start=2022-01-07&end=2022-07-06
# parasol-finance - Highest Volume within 90 days: ['parasol-finance', '2022-06-23', '$256,452', 143142.0, '$0.04571362', '$0.04585414']
# parasol-finance - 7 Days Before Highest Volume: ['parasol-finance', '2022-06-17', '$252,269', '$587.21', '$0.04531577', '$0.04895968']
# Opened: https://www.coingecko.com/en/coins/paraverse/historical_data?start=2023-08-13&end=2024-02-09
# paraverse - Highest Volume within 90 days: ['paraverse', '2024-02-07', '$0.000000000000000000', 8817.93, '$0.000000030099', '$0.000000030083']
# paraverse - 7 Days Before Highest Volume: ['paraverse', '2024-01-31', '$0.000000000000000000', '$0.000000013127', '$0.000000030074', '$0.000000030074']
# Opened: https://www.coingecko.com/en/coins/patex/historical_data?start=2024-01-15&end=2024-07-13
# patex - Highest Volume within 90 days: ['patex', '2024-07-05', '$0.000000000000000000', 694248.0, '$1.88', '$1.83']
# patex - 7 Days Before Highest Volume: ['patex', '2024-06-28', '$0.000000000000000000', '$440,261', '$2.13', '$2.04']
# Opened: https://www.coingecko.com/en/coins/pepe-token/historical_data?start=2023-07-19&end=2024-01-15
# pepe-token - Highest Volume within 90 days: ['pepe-token', '2024-01-14', '$1,657,906', 863467.0, '$0.00180111', '$0.00198752']
# pepe-token - 7 Days Before Highest Volume: ['pepe-token', '2024-01-07', '$1,531,258', '$749,337', '$0.00169316', '$0.00192205']
# Opened: https://www.coingecko.com/en/coins/perpy-finance/historical_data?start=2023-03-09&end=2023-09-05
# perpy-finance - Highest Volume within 90 days: ['perpy-finance', '2023-08-21', '$1,800,737', 206054.0, '$0.00604278', '$0.00516006']
# perpy-finance - 7 Days Before Highest Volume: ['perpy-finance', '2023-08-17', '$1,329,744', '$46,226', '$0.00445382', '$0.00441714']
# Opened: https://www.coingecko.com/en/coins/petroleum-oil/historical_data?start=2022-11-21&end=2023-05-20
# petroleum-oil - Highest Volume within 90 days: ['petroleum-oil', '2023-05-03', '$0.000000000000000000', 876.72, '$0.652221', '$0.648872']
# petroleum-oil - 7 Days Before Highest Volume: ['petroleum-oil', '2023-05-04', '$0.000000000000000000', '$1.40', '$0.648872', '$0.647319']
# Opened: https://www.coingecko.com/en/coins/phuture/historical_data?start=2021-03-07&end=2021-09-03
# phuture - Highest Volume within 90 days: ['phuture', '2021-08-26', '$1,652,822', 198997.0, '$0.283692', '$0.295337']
# phuture - 7 Days Before Highest Volume: ['phuture', '2021-08-19', '$1,229,282', '$20,916', '$0.216475', '$0.215377']
# Opened: https://www.coingecko.com/en/coins/pink-elements/historical_data?start=2024-04-12&end=2024-10-09
# pink-elements - Highest Volume within 90 days: ['pink-elements', '2024-10-02', '$0.000000000000000000', 1181.21, '$0.00259234', '$0.00252791']
# pink-elements - 7 Days Before Highest Volume: ['pink-elements', '2024-09-25', '$0.000000000000000000', '$597.40', '$0.00269861', '$0.00263048']
# Opened: https://www.coingecko.com/en/coins/pipi-the-cat/historical_data?start=2023-10-17&end=2024-04-14
# pipi-the-cat - Highest Volume within 90 days: ['pipi-the-cat', '2024-04-03', '$0.000000000000000000', 29979.0, '$0.269058', '$0.241486']
# pipi-the-cat - 7 Days Before Highest Volume: ['pipi-the-cat', '2024-03-27', '$0.000000000000000000', '$3,546.34', '$0.180163', '$0.203195']
# Opened: https://www.coingecko.com/en/coins/planktos/historical_data?start=2024-02-03&end=2024-08-01
# planktos - Highest Volume within 90 days: ['planktos', '2024-07-23', '$0.000000000000000000', 36996.0, '$0.00013356', '$0.00011548']
# planktos - 7 Days Before Highest Volume: ['planktos', '2024-07-16', '$0.000000000000000000', '$1,182.15', '$0.00006696', '$0.00006834']
# Opened: https://www.coingecko.com/en/coins/polychain-monsters/historical_data?start=2021-01-05&end=2021-07-04
# polychain-monsters - Highest Volume within 90 days: ['polychain-monsters', '2021-06-24', '$6,401,670', 716844.0, '$3.94', '$3.95']
# polychain-monsters - 7 Days Before Highest Volume: ['polychain-monsters', '2021-06-17', '$9,152,976', '$261,923', '$5.61', '$5.46']
# Opened: https://www.coingecko.com/en/coins/polygod/historical_data?start=2021-10-17&end=2022-04-15
# polygod - Highest Volume within 90 days: ['polygod', '2022-04-03', '$0.000000000000000000', 9755.74, '$0.059765', '$0.060802']
# polygod - 7 Days Before Highest Volume: ['polygod', '2022-03-27', '$0.000000000000000000', '$6,733.53', '$0.052143', '$0.054930']
# Opened: https://www.coingecko.com/en/coins/polylastic/historical_data?start=2021-02-11&end=2021-08-10
# polylastic - Highest Volume within 90 days: ['polylastic', '2021-08-09', '$5,570,875', 2149286.0, '$0.00060308', '$0.00056453']
# polylastic - 7 Days Before Highest Volume: ['polylastic', '2021-08-02', '$3,903,299', '$163,520', '$0.00042428', '$0.00037389']
# Opened: https://www.coingecko.com/en/coins/popeye/historical_data?start=2024-10-16&end=2025-04-14
# popeye - Highest Volume within 90 days: ['popeye', '2025-02-28', '$111,348', 4670.38, '$0.00011145', '$0.00012079']
# popeye - 7 Days Before Highest Volume: ['popeye', '2025-02-21', '$95,633', '$288.75', '$0.00009566', '$0.00008711']
# Opened: https://www.coingecko.com/en/coins/psyoptions/historical_data?start=2022-01-09&end=2022-07-08
# psyoptions - Highest Volume within 90 days: ['psyoptions', '2022-07-01', '$0.000000000000000000', 622780.0, '$0.04595630', '$0.04909180']
# psyoptions - 7 Days Before Highest Volume: ['psyoptions', '2022-06-24', '$0.000000000000000000', '$430,475', '$0.04622128', '$0.04639475']
# Opened: https://www.coingecko.com/en/coins/public-meme-token/historical_data?start=2023-12-17&end=2024-06-14
# public-meme-token - Highest Volume within 90 days: ['public-meme-token', '2024-05-28', '$1,405,474', 613732.0, '$0.054375', '$0.054163']
# public-meme-token - 7 Days Before Highest Volume: ['public-meme-token', '2024-05-29', '$1,401,331', '$488,526', '$0.054163', '$0.054552']
# Opened: https://www.coingecko.com/en/coins/pudgy-cat/historical_data?start=2023-01-16&end=2023-07-15
# pudgy-cat - Highest Volume within 90 days: ['pudgy-cat', '2023-07-12', '$0.000000000000000000', 135.56, '$0.000000000223429', '$0.000000000220394']
# pudgy-cat - 7 Days Before Highest Volume: ['pudgy-cat', '2023-07-05', '$0.000000000000000000', '$90.98', '$0.000000000215979', '$0.000000000215979']
# Opened: https://www.coingecko.com/en/coins/pulse-token/historical_data?start=2021-10-02&end=2022-03-31
# pulse-token - Highest Volume within 90 days: ['pulse-token', '2022-03-28', '$0.000000000000000000', 8449.06, '$0.094508', '$0.094494']
# pulse-token - 7 Days Before Highest Volume: ['pulse-token', '2022-03-21', '$0.000000000000000000', '$400.51', '$0.083487', '$0.082869']
# Opened: https://www.coingecko.com/en/coins/pulsechain/historical_data?start=2023-03-12&end=2023-09-08
# pulsechain - Highest Volume within 90 days: ['pulsechain', '2023-08-26', '$0.000000000000000000', 490588.0, '$0.00005960', '$0.00005888']
# pulsechain - 7 Days Before Highest Volume: ['pulsechain', '2023-08-20', '$0.000000000000000000', '$348,064', '$0.00004640', '$0.00004588']
# Opened: https://www.coingecko.com/en/coins/pulseln/historical_data?start=2023-06-29&end=2023-12-26
# pulseln - Highest Volume within 90 days: ['pulseln', '2023-12-08', '$0.000000000000000000', 18379.84, '$0.00450503', '$0.00618832']
# pulseln - 7 Days Before Highest Volume: ['pulseln', '2023-12-08', '$0.000000000000000000', '$18,379.84', '$0.00450503', '$0.00618832']
# Opened: https://www.coingecko.com/en/coins/push/historical_data?start=2024-06-24&end=2024-12-21
# push - Highest Volume within 90 days: ['push', '2024-12-10', '$9,974.08', 2400.48, '$0.00000997', '$0.00000992']
# push - 7 Days Before Highest Volume: ['push', '2024-12-03', '$10,336.52', '$11.13', '$0.00001035', '$0.00001110']
# Opened: https://www.coingecko.com/en/coins/rage-fan/historical_data?start=2021-01-01&end=2021-06-30
# rage-fan - Highest Volume within 90 days: ['rage-fan', '2021-06-14', '$1,098,271', 300788.0, '$0.01977859', '$0.01946619']
# rage-fan - 7 Days Before Highest Volume: ['rage-fan', '2021-06-11', '$1,063,364', '$231,818', '$0.01887162', '$0.02015235']
# Opened: https://www.coingecko.com/en/coins/rainbow-token/historical_data?start=2022-01-06&end=2022-07-05
# rainbow-token - Highest Volume within 90 days: ['rainbow-token', '2022-06-20', '$11,124,295', 74398.0, '$0.168215', '$0.171358']
# rainbow-token - 7 Days Before Highest Volume: ['rainbow-token', '2022-06-16', '$9,234,225', '$20,881', '$0.139982', '$0.118272']
# Opened: https://www.coingecko.com/en/coins/raze-network/historical_data?start=2021-01-29&end=2021-07-28
# raze-network - Highest Volume within 90 days: ['raze-network', '2021-07-27', '$2,560,136', 1121993.0, '$0.075129', '$0.077630']
# raze-network - 7 Days Before Highest Volume: ['raze-network', '2021-07-20', '$2,746,956', '$747,669', '$0.081997', '$0.079249']
# Opened: https://www.coingecko.com/en/coins/reaper-token/historical_data?start=2021-08-01&end=2022-01-28
# reaper-token - Highest Volume within 90 days: ['reaper-token', '2022-01-13', '$0.000000000000000000', 1094906.0, '$0.050080', '$0.053462']
# reaper-token - 7 Days Before Highest Volume: ['reaper-token', '2022-01-10', '$0.000000000000000000', '$60,231', '$0.02099479', '$0.01774941']
# Opened: https://www.coingecko.com/en/coins/releap/historical_data?start=2023-06-17&end=2023-12-14
# releap - Highest Volume within 90 days: ['releap', '2023-11-25', '$0.000000000000000000', 80708.0, '$0.00257384', '$0.00314721']
# releap - 7 Days Before Highest Volume: ['releap', '2023-11-27', '$0.000000000000000000', '$8,259.51', '$0.00268202', '$0.00240124']
# Opened: https://www.coingecko.com/en/coins/reploy/historical_data?start=2024-09-25&end=2025-03-24
# reploy - Highest Volume within 90 days: ['reploy', '2025-02-13', '$28,676,668', 7128877.0, '$2.87', '$2.47']
# reploy - 7 Days Before Highest Volume: ['reploy', '2025-02-19', '$24,191,232', '$3,433,932', '$2.42', '$2.26']
# Highest volume data within 90 days saved to highest_volume_historical_data_split_file_3.csv
