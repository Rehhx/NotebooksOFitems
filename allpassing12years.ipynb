# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def scrape_passing_year(year):
    url = f"https://www.sports-reference.com/cfb/years/{year}-passing.html"
    print(f"Scraping {year}...")
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")

        table = soup.find("table", id="passing_standard")
        if not table:
            print(f"[!] Table not found for {year}. Skipping.")
            return

        tbody = table.find("tbody")
        first_valid_row = next(row for row in tbody.find_all("tr") if row.find_all("td"))
        columns = [td['data-stat'] for td in first_valid_row.find_all("td")]

        data = []
        for row in tbody.find_all("tr"):
            if row.get("class") and "thead" in row.get("class"):
                continue
            tds = row.find_all("td")
            if not tds:
                continue
            values = [td.get_text(strip=True) for td in tds]
            data.append(values)

        df = pd.DataFrame(data, columns=columns)

        for col in df.columns:
            if df[col].dtype == object:
                df[col] = pd.to_numeric(df[col].str.replace(',', ''), errors='ignore')

        df.to_csv(f"cfb_{year}_passing.csv", index=False)
        print(f"✅ Saved: cfb_{year}_passing.csv")

        time.sleep(1.5)  # Respectful delay
    except Exception as e:
        print(f"[!] Error for {year}: {e}")

if __name__ == "__main__":
    for year in range(2024, 2011, -1):  # From 2024 to 2012
        scrape_passing_year(year)
# Out:
# Scraping 2024...
# ✅ Saved: cfb_2024_passing.csv
# Scraping 2023...
# ✅ Saved: cfb_2023_passing.csv
# Scraping 2022...
# ✅ Saved: cfb_2022_passing.csv
# Scraping 2021...
# ✅ Saved: cfb_2021_passing.csv
# Scraping 2020...
# ✅ Saved: cfb_2020_passing.csv
# Scraping 2019...
# ✅ Saved: cfb_2019_passing.csv
# Scraping 2018...
# ✅ Saved: cfb_2018_passing.csv
# Scraping 2017...
# ✅ Saved: cfb_2017_passing.csv
# Scraping 2016...
# ✅ Saved: cfb_2016_passing.csv
# Scraping 2015...
# ✅ Saved: cfb_2015_passing.csv
# Scraping 2014...
# ✅ Saved: cfb_2014_passing.csv
# Scraping 2013...
# ✅ Saved: cfb_2013_passing.csv
# Scraping 2012...
# ✅ Saved: cfb_2012_passing.csv
