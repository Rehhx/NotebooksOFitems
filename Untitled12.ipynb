# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# Load the CSV file
file_path = r"C:\Users\pcagm\Downloads\split_file_5.csv"
df = pd.read_csv(file_path)

# Convert Date column to datetime format
df["Date"] = pd.to_datetime(df["Date"], errors='coerce')

# Filter token IDs and dates where wasRekt = 1 and volume is empty
rekt_data = df[(df["wasRekt"] == 1) & (df["volume"].isna())][["id", "Date"]].dropna()

# Initialize Selenium WebDriver
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)

historical_data = []

for index, row in rekt_data.iterrows():
    try:
        token_id = row["id"]
        date_str = row["Date"]
        date_obj = pd.to_datetime(date_str, errors='coerce')
        if pd.isna(date_obj):
            print(f"Skipping {token_id} due to invalid date format")
            continue

        max_years_back = 7 * 365  # Maximum search range in days (7 years)
        max_years_forward = (pd.Timestamp.today() - date_obj).days  # Days until current date
        
        # Backward search intervals
        backward_intervals = [90, 180, 365, 730, 1095]  # 3 months, 6 months, 1 year, 2 years, 3 years
        while backward_intervals[-1] < max_years_back:
            backward_intervals.append(backward_intervals[-1] + 90)  # 3-month intervals after 3 years

        # Forward search intervals
        forward_intervals = [1, 3, 9, 27, 60, 120, 180]  # 1 day, 3 days, 9 days, 27 days, 2 months, 4 months, 6 months
        while forward_intervals[-1] < max_years_forward:
            forward_intervals.append(forward_intervals[-1] + 90)  # 3-month intervals after 6 months

        data_found = False

        # Backward search
        for days_back in backward_intervals:
            if data_found:
                break
            start_date = (date_obj - pd.Timedelta(days=days_back)).strftime("%Y-%m-%d")
            end_date = (date_obj - pd.Timedelta(days=days_back - 1)).strftime("%Y-%m-%d")
            url = f"https://www.coingecko.com/en/coins/{token_id}/historical_data?start={start_date}&end={end_date}"
            driver.get(url)
            print(f"Opened: {url}")
            time.sleep(5)

            try:
                rows = driver.find_elements(By.CSS_SELECTOR, "table tbody tr")
                if rows:
                    row = rows[0]  # Only grab the first available row
                    cols = row.find_elements(By.TAG_NAME, "td")
                    if len(cols) >= 4:
                        date = cols[0].text
                        market_cap = cols[1].text
                        volume = cols[2].text
                        open_price = cols[3].text
                        close_price = cols[4].text if len(cols) > 4 else "N/A"
                        historical_data.append([token_id, date, market_cap, volume, open_price, close_price])
                        print(f"{token_id} - {date}: Market Cap={market_cap}, Volume={volume}, Open={open_price}, Close={close_price}")
                        data_found = True
            except:
                print(f"No historical data found for {token_id} on {start_date}")

        # Forward search if no data found
        if not data_found:
            for days_forward in forward_intervals:
                start_date = (date_obj + pd.Timedelta(days=days_forward)).strftime("%Y-%m-%d")
                end_date = (date_obj + pd.Timedelta(days=days_forward + 1)).strftime("%Y-%m-%d")
                url = f"https://www.coingecko.com/en/coins/{token_id}/historical_data?start={start_date}&end={end_date}"
                driver.get(url)
                print(f"Opened: {url}")
                time.sleep(5)

                try:
                    rows = driver.find_elements(By.CSS_SELECTOR, "table tbody tr")
                    if rows:
                        row = rows[0]
                        cols = row.find_elements(By.TAG_NAME, "td")
                        if len(cols) >= 4:
                            date = cols[0].text
                            market_cap = cols[1].text
                            volume = cols[2].text
                            open_price = cols[3].text
                            close_price = cols[4].text if len(cols) > 4 else "N/A"
                            historical_data.append([token_id, date, market_cap, volume, open_price, close_price])
                            print(f"{token_id} - {date}: Market Cap={market_cap}, Volume={volume}, Open={open_price}, Close={close_price}")
                            data_found = True
                            break
                except:
                    print(f"No historical data found for {token_id} on {start_date}")
    
    except Exception as e:
        print(f"Error fetching historical data for {token_id}: {e}")

# Convert to DataFrame and save
historical_df = pd.DataFrame(historical_data, columns=["id", "Date", "market_cap", "volume", "open", "close"])
historical_df.to_csv("historical_data_split_file_5.csv", index=False)
print("Historical data saved to historical_data_split_file_5.csv")

driver.quit()
# Out:
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2021-09-28&end=2021-09-29
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2021-06-30&end=2021-07-01
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2020-12-27&end=2020-12-28
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2019-12-28&end=2019-12-29
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2018-12-28&end=2018-12-29
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2018-09-29&end=2018-09-30
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2018-07-01&end=2018-07-02
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2018-04-02&end=2018-04-03
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2018-01-02&end=2018-01-03
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2017-10-04&end=2017-10-05
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2017-07-06&end=2017-07-07
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2017-04-07&end=2017-04-08
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2016-04-30&end=2016-05-01
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2023-07-09&end=2023-07-10
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2023-07-11&end=2023-07-12
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2023-07-17&end=2023-07-18
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2023-08-04&end=2023-08-05
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2023-09-06&end=2023-09-07
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2023-11-05&end=2023-11-06
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2024-01-04&end=2024-01-05
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2024-04-03&end=2024-04-04
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2024-07-02&end=2024-07-03
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2024-09-30&end=2024-10-01
# zksync-erc20-bridged-dai-zksync - 2024-10-01: Market Cap=$634,089, Volume=$46,126, Open=$1.001, Close=$0.999837
# Historical data saved to historical_data_split_file_5.csv

# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# Load the CSV file
file_path = r"C:\Users\pcagm\Downloads\Untitled spreadsheet - historical_data_split_file_5.csv"
df = pd.read_csv(file_path)

# Convert Date column to datetime format
df["Date"] = pd.to_datetime(df["Date"], errors='coerce')

# Initialize Selenium WebDriver
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)

highest_volume_data = []

for index, row in df.iterrows():
    try:
        token_id = row["id"]
        date_obj = row["Date"]
        if pd.isna(date_obj):
            print(f"Skipping {token_id} due to invalid date format")
            continue

        # Define search range (90 days before and after the given date)
        start_date = (date_obj - pd.Timedelta(days=90)).strftime("%Y-%m-%d")
        end_date = (date_obj + pd.Timedelta(days=90)).strftime("%Y-%m-%d")

        # Construct the historical data URL with dynamic dates
        url = f"https://www.coingecko.com/en/coins/{token_id}/historical_data?start={start_date}&end={end_date}"
        driver.get(url)
        print(f"Opened: {url}")
        time.sleep(5)  # Allow data to load

        try:
            rows = driver.find_elements(By.CSS_SELECTOR, "table tbody tr")
            highest_volume = 0
            highest_volume_entry = None
            previous_day_entry = None

            for row in rows:
                cols = row.find_elements(By.TAG_NAME, "td")
                if len(cols) >= 4:
                    date = cols[0].text
                    market_cap = cols[1].text
                    volume = float(cols[2].text.replace('$', '').replace(',', '')) if cols[2].text else 0
                    open_price = cols[3].text
                    close_price = cols[4].text if len(cols) > 4 else "N/A"
                    
                    if volume > highest_volume:
                        highest_volume = volume
                        highest_volume_entry = [token_id, date, market_cap, volume, open_price, close_price]
                        
                        # Look for the previous day data
                        previous_day_date = (pd.to_datetime(date) - pd.Timedelta(days=1)).strftime("%Y-%m-%d")
                        for prev_row in rows:
                            prev_cols = prev_row.find_elements(By.TAG_NAME, "td")
                            if len(prev_cols) >= 4 and prev_cols[0].text == previous_day_date:
                                previous_day_entry = [token_id, prev_cols[0].text, prev_cols[1].text, prev_cols[2].text, prev_cols[3].text, prev_cols[4].text]
                                break
            
            if highest_volume_entry:
                highest_volume_data.append(highest_volume_entry)
                print(f"{token_id} - Highest Volume within 90 days: {highest_volume_entry}")
                if previous_day_entry:
                    highest_volume_data.append(previous_day_entry)
                    print(f"{token_id} - Previous Day of Highest Volume: {previous_day_entry}")
        except:
            print(f"No historical data found for {token_id} in the given range")
    
    except Exception as e:
        print(f"Error fetching historical data for {token_id}: {e}")

# Convert to DataFrame and save
highest_volume_df = pd.DataFrame(highest_volume_data, columns=["id", "Date", "market_cap", "volume", "open", "close"])
highest_volume_df.to_csv("highest_volume_historical_data_split_file_5.csv", index=False)
print("Highest volume data within 90 days saved to highest_volume_historical_data_split_file_5.csv")

driver.quit()
# Out:
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2024-09-13&end=2025-03-12
# wpphmrmbdtrsj2p0eb69i - Highest Volume within 90 days: ['wpphmrmbdtrsj2p0eb69i', '2025-02-22', '$211,862', 9226.0, '$0.00021242', '$0.00021623']
# wpphmrmbdtrsj2p0eb69i - Previous Day of Highest Volume: ['wpphmrmbdtrsj2p0eb69i', '2025-02-21', '$222,083', '$2,097.43', '$0.00022120', '$0.00021242']
# Opened: https://www.coingecko.com/en/coins/x-protocol/historical_data?start=2021-09-14&end=2022-03-13
# x-protocol - Highest Volume within 90 days: ['x-protocol', '2022-03-08', '$0.000000000000000000', 651698.0, '$0.415752', '$0.356227']
# x-protocol - Previous Day of Highest Volume: ['x-protocol', '2022-03-07', '$0.000000000000000000', '$36,198', '$0.239747', '$0.415752']
# Opened: https://www.coingecko.com/en/coins/xcad-network/historical_data?start=2021-03-05&end=2021-09-01
# xcad-network - Highest Volume within 90 days: ['xcad-network', '2021-08-26', '$19,951,814', 5422720.0, '$1.32', '$1.16']
# xcad-network - Previous Day of Highest Volume: ['xcad-network', '2021-08-25', '$17,028,267', '$3,015,060', '$1.41', '$1.32']
# Opened: https://www.coingecko.com/en/coins/xlink-bridged-btc-stacks/historical_data?start=2023-11-19&end=2024-05-17
# xlink-bridged-btc-stacks - Highest Volume within 90 days: ['xlink-bridged-btc-stacks', '2024-05-02', '$0.000000000000000000', 4209815.0, '$58,497', '$58,417']
# xlink-bridged-btc-stacks - Previous Day of Highest Volume: ['xlink-bridged-btc-stacks', '2024-05-01', '$0.000000000000000000', '$4,044,551', '$61,793', '$58,497']
# Opened: https://www.coingecko.com/en/coins/yolo-games/historical_data?start=2024-04-11&end=2024-10-08
# yolo-games - Highest Volume within 90 days: ['yolo-games', '2024-09-26', '$0.000000000000000000', 131888.0, '$0.00221437', '$0.00223541']
# yolo-games - Previous Day of Highest Volume: ['yolo-games', '2024-09-25', '$0.000000000000000000', '$22,710', '$0.00244342', '$0.00221437']
# Opened: https://www.coingecko.com/en/coins/you-looked/historical_data?start=2023-11-10&end=2024-05-08
# you-looked - Highest Volume within 90 days: ['you-looked', '2024-05-05', '$0.000000000000000000', 403527.0, '$0.00395329', '$0.00317057']
# you-looked - Previous Day of Highest Volume: ['you-looked', '2024-05-04', '$0.000000000000000000', '$291,374', '$0.00379258', '$0.00395329']
# Opened: https://www.coingecko.com/en/coins/zetachain/historical_data?start=2023-11-12&end=2024-05-10
# zetachain - Highest Volume within 90 days: ['zetachain', '2024-05-04', '$373,065,764', 235034824.0, '$1.58', '$1.64']
# zetachain - Previous Day of Highest Volume: ['zetachain', '2024-05-03', '$309,820,885', '$52,038,958', '$1.31', '$1.58']
# Opened: https://www.coingecko.com/en/coins/zircuit-bridged-usdt-zircuit/historical_data?start=2024-11-16&end=2025-05-15
# zircuit-bridged-usdt-zircuit - Highest Volume within 90 days: ['zircuit-bridged-usdt-zircuit', '2025-02-26', '$0.000000000000000000', 354875.0, '$0.999053', '$0.998581']
# zircuit-bridged-usdt-zircuit - Previous Day of Highest Volume: ['zircuit-bridged-usdt-zircuit', '2025-02-25', '$0.000000000000000000', '$231,759', '$1.002', '$0.999053']
# Opened: https://www.coingecko.com/en/coins/zksync/historical_data?start=2024-04-16&end=2024-10-13
# zksync - Highest Volume within 90 days: ['zksync', '2024-10-08', '$483,615,905', 143806256.0, '$0.131556', '$0.127157']
# zksync - Previous Day of Highest Volume: ['zksync', '2024-10-07', '$473,570,963', '$82,635,304', '$0.128819', '$0.131556']
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2024-07-03&end=2024-12-30
# zksync-erc20-bridged-dai-zksync - Highest Volume within 90 days: ['zksync-erc20-bridged-dai-zksync', '2024-12-28', '$477,884', 100352.0, '$1.000', '$0.999960']
# zksync-erc20-bridged-dai-zksync - Previous Day of Highest Volume: ['zksync-erc20-bridged-dai-zksync', '2024-12-27', '$477,458', '$36,641', '$1.000', '$1.000']
# Highest volume data within 90 days saved to highest_volume_historical_data_split_file_5.csv

# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# Load the CSV file
file_path = r"C:\Users\pcagm\Downloads\Untitled spreadsheet - historical_data_split_file_5.csv"
df = pd.read_csv(file_path)

# Convert Date column to datetime format
df["Date"] = pd.to_datetime(df["Date"], errors='coerce')

# Initialize Selenium WebDriver
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)

highest_volume_data = []

for index, row in df.iterrows():
    try:
        token_id = row["id"]
        date_obj = row["Date"]
        if pd.isna(date_obj):
            print(f"Skipping {token_id} due to invalid date format")
            continue

        # Define search range (90 days before and after the given date)
        start_date = (date_obj - pd.Timedelta(days=90)).strftime("%Y-%m-%d")
        end_date = (date_obj + pd.Timedelta(days=90)).strftime("%Y-%m-%d")

        # Construct the historical data URL with dynamic dates
        url = f"https://www.coingecko.com/en/coins/{token_id}/historical_data?start={start_date}&end={end_date}"
        driver.get(url)
        print(f"Opened: {url}")
        time.sleep(5)  # Allow data to load

        try:
            rows = driver.find_elements(By.CSS_SELECTOR, "table tbody tr")
            highest_volume = 0
            highest_volume_entry = None
            seven_days_before_entry = None

            for row in rows:
                cols = row.find_elements(By.TAG_NAME, "td")
                if len(cols) >= 4:
                    date = cols[0].text
                    market_cap = cols[1].text
                    volume = float(cols[2].text.replace('$', '').replace(',', '')) if cols[2].text else 0
                    open_price = cols[3].text
                    close_price = cols[4].text if len(cols) > 4 else "N/A"
                    
                    if volume > highest_volume:
                        highest_volume = volume
                        highest_volume_entry = [token_id, date, market_cap, volume, open_price, close_price]
                        
                        # Look for the data 7 days before the highest volume date
                        seven_days_before_date = (pd.to_datetime(date) - pd.Timedelta(days=7)).strftime("%Y-%m-%d")
                        for prev_row in rows:
                            prev_cols = prev_row.find_elements(By.TAG_NAME, "td")
                            if len(prev_cols) >= 4 and prev_cols[0].text == seven_days_before_date:
                                seven_days_before_entry = [token_id, prev_cols[0].text, prev_cols[1].text, prev_cols[2].text, prev_cols[3].text, prev_cols[4].text]
                                break
            
            if highest_volume_entry:
                highest_volume_data.append(highest_volume_entry)
                print(f"{token_id} - Highest Volume within 90 days: {highest_volume_entry}")
                if seven_days_before_entry:
                    highest_volume_data.append(seven_days_before_entry)
                    print(f"{token_id} - 7 Days Before Highest Volume: {seven_days_before_entry}")
        except:
            print(f"No historical data found for {token_id} in the given range")
    
    except Exception as e:
        print(f"Error fetching historical data for {token_id}: {e}")

# Convert to DataFrame and save
highest_volume_df = pd.DataFrame(highest_volume_data, columns=["id", "Date", "market_cap", "volume", "open", "close"])
highest_volume_df.to_csv("highest_volume_historical_data_split_file_5.csv", index=False)
print("Highest volume data within 90 days saved to highest_volume_historical_data_split_file_5.csv")

driver.quit()
# Out:
# Opened: https://www.coingecko.com/en/coins/wpphmrmbdtrsj2p0eb69i/historical_data?start=2024-09-13&end=2025-03-12
# wpphmrmbdtrsj2p0eb69i - Highest Volume within 90 days: ['wpphmrmbdtrsj2p0eb69i', '2025-02-22', '$211,862', 9226.0, '$0.00021242', '$0.00021623']
# wpphmrmbdtrsj2p0eb69i - 7 Days Before Highest Volume: ['wpphmrmbdtrsj2p0eb69i', '2025-02-15', '$290,198', '$8,454.08', '$0.00029028', '$0.00028211']
# Opened: https://www.coingecko.com/en/coins/x-protocol/historical_data?start=2021-09-14&end=2022-03-13
# x-protocol - Highest Volume within 90 days: ['x-protocol', '2022-03-08', '$0.000000000000000000', 651698.0, '$0.415752', '$0.356227']
# x-protocol - 7 Days Before Highest Volume: ['x-protocol', '2022-03-01', '$0.000000000000000000', '$62,412', '$0.227501', '$0.226734']
# Opened: https://www.coingecko.com/en/coins/xcad-network/historical_data?start=2021-03-05&end=2021-09-01
# xcad-network - Highest Volume within 90 days: ['xcad-network', '2021-08-26', '$19,951,814', 5422720.0, '$1.32', '$1.16']
# xcad-network - 7 Days Before Highest Volume: ['xcad-network', '2021-08-19', '$15,626,310', '$3,434,744', '$1.30', '$1.31']
# Opened: https://www.coingecko.com/en/coins/xlink-bridged-btc-stacks/historical_data?start=2023-11-19&end=2024-05-17
# xlink-bridged-btc-stacks - Highest Volume within 90 days: ['xlink-bridged-btc-stacks', '2024-05-02', '$0.000000000000000000', 4209815.0, '$58,497', '$58,417']
# xlink-bridged-btc-stacks - 7 Days Before Highest Volume: ['xlink-bridged-btc-stacks', '2024-04-28', '$0.000000000000000000', '$1,843,823', '$63,583', '$61,793']
# Opened: https://www.coingecko.com/en/coins/yolo-games/historical_data?start=2024-04-11&end=2024-10-08
# yolo-games - Highest Volume within 90 days: ['yolo-games', '2024-09-26', '$0.000000000000000000', 131888.0, '$0.00221437', '$0.00223541']
# yolo-games - 7 Days Before Highest Volume: ['yolo-games', '2024-09-19', '$0.000000000000000000', '$3,750.84', '$0.00221442', '$0.00229379']
# Opened: https://www.coingecko.com/en/coins/you-looked/historical_data?start=2023-11-10&end=2024-05-08
# you-looked - Highest Volume within 90 days: ['you-looked', '2024-05-05', '$0.000000000000000000', 403527.0, '$0.00395329', '$0.00317057']
# you-looked - 7 Days Before Highest Volume: ['you-looked', '2024-04-28', '$0.000000000000000000', '$178,445', '$0.00191679', '$0.00178991']
# Opened: https://www.coingecko.com/en/coins/zetachain/historical_data?start=2023-11-12&end=2024-05-10
# zetachain - Highest Volume within 90 days: ['zetachain', '2024-05-04', '$373,065,764', 235034824.0, '$1.58', '$1.64']
# zetachain - 7 Days Before Highest Volume: ['zetachain', '2024-04-27', '$276,210,003', '$11,946,419', '$1.17', '$1.19']
# Opened: https://www.coingecko.com/en/coins/zircuit-bridged-usdt-zircuit/historical_data?start=2024-11-16&end=2025-05-15
# zircuit-bridged-usdt-zircuit - Highest Volume within 90 days: ['zircuit-bridged-usdt-zircuit', '2025-02-26', '$0.000000000000000000', 354875.0, '$0.999053', '$0.998581']
# zircuit-bridged-usdt-zircuit - 7 Days Before Highest Volume: ['zircuit-bridged-usdt-zircuit', '2025-02-24', '$0.000000000000000000', '$72,349', '$0.999890', '$1.002']
# Opened: https://www.coingecko.com/en/coins/zksync/historical_data?start=2024-04-16&end=2024-10-13
# zksync - Highest Volume within 90 days: ['zksync', '2024-10-08', '$483,615,905', 143806256.0, '$0.131556', '$0.127157']
# zksync - 7 Days Before Highest Volume: ['zksync', '2024-10-01', '$500,503,202', '$125,916,150', '$0.136191', '$0.122120']
# Opened: https://www.coingecko.com/en/coins/zksync-erc20-bridged-dai-zksync/historical_data?start=2024-07-03&end=2024-12-30
# zksync-erc20-bridged-dai-zksync - Highest Volume within 90 days: ['zksync-erc20-bridged-dai-zksync', '2024-12-28', '$477,884', 100352.0, '$1.000', '$0.999960']
# zksync-erc20-bridged-dai-zksync - 7 Days Before Highest Volume: ['zksync-erc20-bridged-dai-zksync', '2024-12-21', '$477,604', '$30,098', '$0.999844', '$1.002']
# Highest volume data within 90 days saved to highest_volume_historical_data_split_file_5.csv
