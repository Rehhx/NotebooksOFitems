# %%
import pandas as pd

# Data for the 6 cities
data = {
    'City': ['Houston', 'Atlanta', 'New Orleans', 'New York City', 'San Francisco', 'Seattle'],
    'State': ['Texas', 'Georgia', 'Louisiana', 'New York', 'California', 'Washington'],
    'Tax_Type': [
        'Gross Receipts (Franchise Tax)',
        'Corporate Income Tax',
        'Corporate Income Tax',
        'Corporate Income Tax',
        'Corporate Income Tax',
        'Gross Receipts (B&O Tax)'
    ],
    'Rate (%)': [
        0.331,   # Texas E-Z rate (up to $20M revenue)
        5.75,    # Georgia
        5.5,     # Louisiana
        7.25,    # New York (highest bracket)
        8.84,    # California
        1.5      # Washington B&O Tax for services
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#             City       State                        Tax_Type  Rate (%)
# 0        Houston       Texas  Gross Receipts (Franchise Tax)     0.331
# 1        Atlanta     Georgia            Corporate Income Tax     5.750
# 2    New Orleans   Louisiana            Corporate Income Tax     5.500
# 3  New York City    New York            Corporate Income Tax     7.250
# 4  San Francisco  California            Corporate Income Tax     8.840
# 5        Seattle  Washington        Gross Receipts (B&O Tax)     1.500
