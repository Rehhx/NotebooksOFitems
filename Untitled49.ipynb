# %%
# === pip (optional, once) ===
# import sys
# !{sys.executable} -m pip install "psycopg[binary]" pandas numpy pyarrow

import warnings
warnings.filterwarnings("ignore")

import math
from pathlib import Path
from typing import List, Optional, Tuple

import numpy as np
import pandas as pd
import psycopg

# =============================
# DB & RUN SETTINGS (EDIT ME)
# =============================

CONN_STR   = "host=24.128.195.68 port=8812 dbname=qdb user=admin password=quest"
TABLE      = "equities_candles"
INTERVAL   = "1m"                 # rows to read from DB (e.g., '1m', '5m', etc.)
BATCH_SIZE = 20                   # process tickers in groups of 20
MAX_SYMBOLS: Optional[int] = None # None = all symbols; or set an int to cap

# Optional date window to limit rows pulled from DB (UTC timestamps in QuestDB)
# e.g. START_DATE = "2016-01-01"; END_DATE = "2025-09-01"
START_DATE: Optional[str] = None
END_DATE:   Optional[str] = None

# Save CSVs to here
SAVE_DIR = Path(".")
SAVE_DIR.mkdir(parents=True, exist_ok=True)

# =============================
# STRATEGY PARAMETERS (same as before)
# =============================

TZ_LOCAL = "America/New_York"

REG_START = "09:30"   # session start
OR_END    = "09:45"   # end of first 15-min bar (exclusive)
REG_END   = "16:00"   # session end

STOP_FIRST_IF_BOTH_HIT = True

# =============================
# Helpers
# =============================

def to_ny(df: pd.DataFrame, col: str = "EventAt") -> pd.Series:
    """
    Robustly parse timestamps from DB:
    - If tz-naive: assume UTC → convert to New York
    - If tz-aware: convert to New York
    """
    ts = pd.to_datetime(df[col], errors="coerce", utc=True)  # DB should be UTC; force-interpret as UTC
    # If it already has tz, pandas keeps it; utc=True yields tz-aware UTC
    return ts.dt.tz_convert(TZ_LOCAL)

def first_breakout_close(df_after_or: pd.DataFrame, orh: float, orl: float) -> Tuple[Optional[str], Optional[int]]:
    """Return ('long'/'short', idx) for first bar *closing* outside the OR."""
    above = df_after_or["Close"] > orh
    below = df_after_or["Close"] < orl
    i_long  = df_after_or.index[above].min()  if above.any() else None
    i_short = df_after_or.index[below].min()  if below.any() else None
    if i_long is None and i_short is None:
        return None, None
    if i_long is not None and (i_short is None or i_long <= i_short):
        return "long", i_long
    return "short", i_short

def first_retest_touch(df_after_breakout_close: pd.DataFrame, level: float) -> Optional[int]:
    """First bar that *touches* the level after the breakout close."""
    touched = (df_after_breakout_close["Low"] <= level) & (df_after_breakout_close["High"] >= level)
    if not touched.any():
        return None
    return int(df_after_breakout_close.index[touched].min())

def simulate_path(after_entry_df: pd.DataFrame, side: str, entry: float, stop: float, target: float,
                  stop_first: bool=True) -> Tuple[str, float, int]:
    """
    Walk forward bar-by-bar after the entry.
    Returns outcome ('TP'/'STOP'/'EOD'), exit_price, exit_idx.
    """
    for idx, row in after_entry_df.iterrows():
        lo, hi = row["Low"], row["High"]
        hit_stop = (lo <= stop) if side == "long" else (hi >= stop)
        hit_tp   = (hi >= target) if side == "long" else (lo <= target)
        if hit_stop and hit_tp:
            return (("STOP", stop, idx) if stop_first else ("TP", target, idx))
        if hit_stop:
            return "STOP", stop, idx
        if hit_tp:
            return "TP", target, idx
    # neither hit by session end → exit at last close
    last_idx = int(after_entry_df.index[-1])
    return "EOD", float(after_entry_df.loc[last_idx, "Close"]), last_idx

def pnl_one_share(side: str, entry: float, exit_px: float) -> float:
    return (exit_px - entry) if side == "long" else (entry - exit_px)

def calc_metrics(trades_df: pd.DataFrame) -> Tuple[int, float, float, float]:
    pnl = trades_df["PnL_1to2"].fillna(0.0)
    wins = int((pnl > 0).sum())
    losses = int((pnl < 0).sum())
    total_trades = int(wins + losses)
    total_pnl = float(pnl.sum())
    gross_pos = float(pnl[pnl > 0].sum())
    gross_neg = float(-pnl[pnl < 0].sum())
    profit_factor = (gross_pos / gross_neg) if gross_neg > 0 else float("inf")
    winrate = (100.0 * wins / total_trades) if total_trades else 0.0
    return total_trades, total_pnl, winrate, float(profit_factor)

# =============================
# DB loaders
# =============================

def fetch_all_symbols(conn) -> List[str]:
    q = f"""
        SELECT DISTINCT symbol
        FROM {TABLE}
        WHERE interval = %s
        ORDER BY symbol
    """
    df = pd.read_sql(q, conn, params=(INTERVAL,))
    syms = df["symbol"].dropna().astype(str).tolist()
    if MAX_SYMBOLS is not None:
        syms = syms[:MAX_SYMBOLS]
    return syms

def fetch_symbol_data(conn, symbol: str) -> pd.DataFrame:
    """
    Pull one symbol’s rows from QuestDB for the chosen INTERVAL and optional date window.
    """
    base = f"""
        SELECT event_at, open, high, low, close, volume
        FROM {TABLE}
        WHERE symbol = %s
          AND interval = %s
    """
    params: List[object] = [symbol, INTERVAL]

    if START_DATE and END_DATE:
        base += " AND event_at >= %s AND event_at < %s"
        params.extend([START_DATE, END_DATE])
    elif START_DATE:
        base += " AND event_at >= %s"
        params.append(START_DATE)
    elif END_DATE:
        base += " AND event_at < %s"
        params.append(END_DATE)

    base += " ORDER BY event_at"

    df = pd.read_sql(base, conn, params=tuple(params))

    if df.empty:
        return df

    # Normalize column names to match backtest logic
    df = df.rename(columns={
        "event_at": "EventAt",
        "open": "Open",
        "high": "High",
        "low": "Low",
        "close": "Close",
        "volume": "Volume",
    })

    # Convert to NY time and add handy columns
    df["EventAt"] = to_ny(df, "EventAt")
    df = df.sort_values("EventAt").reset_index(drop=True)
    df["date"] = df["EventAt"].dt.date
    df["t"]    = df["EventAt"].dt.strftime("%H:%M")

    # keep only regular session
    session = (df["t"] >= REG_START) & (df["t"] <= REG_END)
    return df.loc[session].copy()

# =============================
# Core backtest on a DataFrame (unchanged logic, now fed from DB)
# =============================

def backtest_df(df: pd.DataFrame, symbol: str) -> pd.DataFrame:
    if df.empty:
        return pd.DataFrame()

    for c in ["EventAt", "Open", "High", "Low", "Close", "date", "t"]:
        if c not in df.columns:
            raise ValueError(f"{symbol}: missing required column {c}")

    records = []

    for d, day in df.groupby("date"):
        # Opening range: first 15-minute bar [09:30, 09:45)
        or_mask = (day["t"] >= REG_START) & (day["t"] < OR_END)
        if not or_mask.any():
            continue
        orh = float(day.loc[or_mask, "High"].max())
        orl = float(day.loc[or_mask, "Low"].min())
        or_width = orh - orl
        if or_width <= 0:
            continue

        # After OR (09:45+)
        after_or = day.loc[day["t"] >= OR_END]
        if after_or.empty:
            continue

        # 1) first confirmed breakout by CLOSE
        side, brk_idx = first_breakout_close(after_or, orh, orl)
        if side is None:
            continue

        # 2) retest entry at broken level
        broken_level = orh if side == "long" else orl
        after_breakout_close = after_or.loc[after_or.index > brk_idx]
        if after_breakout_close.empty:
            continue

        retest_idx = first_retest_touch(after_breakout_close, broken_level)
        if retest_idx is None:
            continue

        entry_time = day.loc[retest_idx, "EventAt"]
        entry      = broken_level
        stop       = orl if side == "long" else orh
        target     = entry + ( 2 * or_width if side == "long" else -2 * or_width)

        after_entry = day.loc[day.index > retest_idx]
        if after_entry.empty:
            records.append({
                "Date": d, "Symbol": symbol, "Side": side,
                "ORH": orh, "ORL": orl, "OR_Width": or_width,
                "EntryTime": entry_time, "Entry": entry, "Stop": stop, "Target_1to2": target,
                "Outcome_1to2": "EOD", "ExitPx_1to2": entry, "ExitTime_1to2": entry_time,
                "PnL_1to2": 0.0,
            })
            continue

        outcome, exit_px, exit_idx = simulate_path(
            after_entry, side, entry, stop, target, stop_first=STOP_FIRST_IF_BOTH_HIT
        )
        pnl = pnl_one_share(side, entry, exit_px)

        records.append({
            "Date": d, "Symbol": symbol, "Side": side,
            "ORH": orh, "ORL": orl, "OR_Width": or_width,
            "EntryTime": entry_time, "Entry": entry, "Stop": stop, "Target_1to2": target,
            "Outcome_1to2": outcome, "ExitPx_1to2": exit_px,
            "ExitTime_1to2": day.loc[exit_idx, "EventAt"] if exit_idx in day.index else None,
            "PnL_1to2": pnl,
        })

    return pd.DataFrame(records)

# =============================
# Batch runner
# =============================

def chunked(seq: List[str], n: int) -> List[List[str]]:
    return [seq[i:i+n] for i in range(0, len(seq), n)]

def main():
    try:
        conn = psycopg.connect(CONN_STR)
    except Exception as e:
        print(f"DB connection failed: {e}")
        return

    with conn:
        symbols = fetch_all_symbols(conn)
        if not symbols:
            print(f"No symbols found for interval='{INTERVAL}'.")
            return

        batches = chunked(symbols, BATCH_SIZE)
        all_trades = []

        print(f"Found {len(symbols)} symbols for interval '{INTERVAL}'. Processing in {len(batches)} batch(es) of {BATCH_SIZE}...")

        for bi, batch in enumerate(batches, start=1):
            print(f"\n=== Batch {bi}/{len(batches)} ({len(batch)} symbols) ===")

            for symbol in batch:
                try:
                    df = fetch_symbol_data(conn, symbol)
                    if df.empty:
                        print(f"=== ORB 15m Retest — {symbol} (1 share, RR 1:2) ===")
                        print("Trades: 0 | Total PnL: $0.00 | Win%: 0.00% | Profit Factor: 0.000")
                        continue

                    trades = backtest_df(df, symbol)

                    if trades.empty:
                        print(f"=== ORB 15m Retest — {symbol} (1 share, RR 1:2) ===")
                        print("Trades: 0 | Total PnL: $0.00 | Win%: 0.00% | Profit Factor: 0.000")
                        continue

                    all_trades.append(trades)

                    # Per-symbol metrics + print in required format
                    total_trades, total_pnl, winrate, profit_factor = calc_metrics(trades)

                    save_path = SAVE_DIR / f"orb_trades_{symbol}_one_share_RR1to2.csv"
                    trades.to_csv(save_path, index=False)

                    print(f"=== ORB 15m Retest — {symbol} (1 share, RR 1:2) ===")
                    print(f"Trades: {total_trades} | Total PnL: ${total_pnl:,.2f} | Win%: {winrate:.2f}% | Profit Factor: {profit_factor:.3f}")
                    print(f"Saved trades → {save_path.resolve()}")

                except Exception as e:
                    print(f"[SKIP] {symbol}: {e}")

        # ===== OVERALL roll-up =====
        if not all_trades:
            print("\nNo trades generated for any symbols.")
            return

        overall = pd.concat(all_trades, ignore_index=True)
        o_trades, o_pnl, o_winrate, o_pf = calc_metrics(overall)

        save_all = SAVE_DIR / "orb_trades_ALL_one_share_RR1to2.csv"
        overall.to_csv(save_all, index=False)

        print(f"\n=== ORB 15m Retest — OVERALL (1 share, RR 1:2) ===")
        print(f"Trades: {o_trades} | Total PnL: ${o_pnl:,.2f} | Win%: {o_winrate:.2f}% | Profit Factor: {o_pf:.3f}")
        print(f"Saved trades → {save_all.resolve()}")

if __name__ == "__main__":
    main()
5 bujn
# Out:
# Found 291 symbols for interval '1m'. Processing in 15 batch(es) of 20...
#
# === Batch 1/15 (20 symbols) ===
# === ORB 15m Retest — $RVX (1 share, RR 1:2) ===
# Trades: 3832 | Total PnL: $-33.07 | Win%: 37.34% | Profit Factor: 0.972
# Saved trades → C:\Users\pcagm\orb_trades_$RVX_one_share_RR1to2.csv
# === ORB 15m Retest — $VIX (1 share, RR 1:2) ===
# Trades: 3910 | Total PnL: $-119.71 | Win%: 35.83% | Profit Factor: 0.886
# Saved trades → C:\Users\pcagm\orb_trades_$VIX_one_share_RR1to2.csv
# === ORB 15m Retest — $VXD (1 share, RR 1:2) ===
# Trades: 3594 | Total PnL: $-1,007.50 | Win%: 36.34% | Profit Factor: 0.549
# Saved trades → C:\Users\pcagm\orb_trades_$VXD_one_share_RR1to2.csv
# === ORB 15m Retest — $VXN (1 share, RR 1:2) ===
# Trades: 3725 | Total PnL: $-64.63 | Win%: 40.19% | Profit Factor: 0.942
# Saved trades → C:\Users\pcagm\orb_trades_$VXN_one_share_RR1to2.csv
# [SKIP] /ES: Cannot save file into a non-existent directory: 'orb_trades_'
# [SKIP] /NQ: Cannot save file into a non-existent directory: 'orb_trades_'
# [SKIP] /RTY: Cannot save file into a non-existent directory: 'orb_trades_'
# [SKIP] /YM: Cannot save file into a non-existent directory: 'orb_trades_'
# === ORB 15m Retest — AAPL (1 share, RR 1:2) ===
# Trades: 2250 | Total PnL: $46.74 | Win%: 45.11% | Profit Factor: 1.031
# Saved trades → C:\Users\pcagm\orb_trades_AAPL_one_share_RR1to2.csv
# === ORB 15m Retest — AAT (1 share, RR 1:2) ===
# Trades: 2 | Total PnL: $-0.31 | Win%: 0.00% | Profit Factor: 0.000
# Saved trades → C:\Users\pcagm\orb_trades_AAT_one_share_RR1to2.csv
# === ORB 15m Retest — ABBV (1 share, RR 1:2) ===
# Trades: 2232 | Total PnL: $-83.40 | Win%: 45.21% | Profit Factor: 0.911
# Saved trades → C:\Users\pcagm\orb_trades_ABBV_one_share_RR1to2.csv
# === ORB 15m Retest — ABNB (1 share, RR 1:2) ===
# Trades: 1102 | Total PnL: $-16.55 | Win%: 46.46% | Profit Factor: 0.984
# Saved trades → C:\Users\pcagm\orb_trades_ABNB_one_share_RR1to2.csv
# === ORB 15m Retest — ABT (1 share, RR 1:2) ===
# Trades: 2227 | Total PnL: $-40.87 | Win%: 43.42% | Profit Factor: 0.938
# Saved trades → C:\Users\pcagm\orb_trades_ABT_one_share_RR1to2.csv
# === ORB 15m Retest — ACMR (1 share, RR 1:2) ===
# Trades: 1 | Total PnL: $0.38 | Win%: 100.00% | Profit Factor: inf
# Saved trades → C:\Users\pcagm\orb_trades_ACMR_one_share_RR1to2.csv
# === ORB 15m Retest — ACN (1 share, RR 1:2) ===
# Trades: 2236 | Total PnL: $-72.84 | Win%: 45.08% | Profit Factor: 0.957
# Saved trades → C:\Users\pcagm\orb_trades_ACN_one_share_RR1to2.csv
# === ORB 15m Retest — ACWX (1 share, RR 1:2) ===
# Trades: 1 | Total PnL: $-0.10 | Win%: 0.00% | Profit Factor: 0.000
# Saved trades → C:\Users\pcagm\orb_trades_ACWX_one_share_RR1to2.csv
# === ORB 15m Retest — ADBE (1 share, RR 1:2) ===
# Trades: 2222 | Total PnL: $-211.69 | Win%: 44.10% | Profit Factor: 0.939
# Saved trades → C:\Users\pcagm\orb_trades_ADBE_one_share_RR1to2.csv
# === ORB 15m Retest — ADI (1 share, RR 1:2) ===
# Trades: 2224 | Total PnL: $-34.24 | Win%: 45.14% | Profit Factor: 0.974
# Saved trades → C:\Users\pcagm\orb_trades_ADI_one_share_RR1to2.csv
# === ORB 15m Retest — ADP (1 share, RR 1:2) ===
# Trades: 2208 | Total PnL: $39.13 | Win%: 45.79% | Profit Factor: 1.032
# Saved trades → C:\Users\pcagm\orb_trades_ADP_one_share_RR1to2.csv
# === ORB 15m Retest — ADSK (1 share, RR 1:2) ===
# Trades: 2190 | Total PnL: $-15.95 | Win%: 43.97% | Profit Factor: 0.992
# Saved trades → C:\Users\pcagm\orb_trades_ADSK_one_share_RR1to2.csv
#
# === Batch 2/15 (20 symbols) ===
# === ORB 15m Retest — AEP (1 share, RR 1:2) ===
# Trades: 2240 | Total PnL: $33.85 | Win%: 46.12% | Profit Factor: 1.059
# Saved trades → C:\Users\pcagm\orb_trades_AEP_one_share_RR1to2.csv
# === ORB 15m Retest — AFL (1 share, RR 1:2) ===
# Trades: 2201 | Total PnL: $-63.18 | Win%: 43.43% | Profit Factor: 0.857
# Saved trades → C:\Users\pcagm\orb_trades_AFL_one_share_RR1to2.csv
# === ORB 15m Retest — AG (1 share, RR 1:2) ===
# Trades: 2185 | Total PnL: $18.83 | Win%: 47.37% | Profit Factor: 1.124
# Saved trades → C:\Users\pcagm\orb_trades_AG_one_share_RR1to2.csv
# === ORB 15m Retest — AIG (1 share, RR 1:2) ===
# Trades: 2222 | Total PnL: $-30.34 | Win%: 43.20% | Profit Factor: 0.936
# Saved trades → C:\Users\pcagm\orb_trades_AIG_one_share_RR1to2.csv
# === ORB 15m Retest — ALL (1 share, RR 1:2) ===
# Trades: 2214 | Total PnL: $5.67 | Win%: 45.17% | Profit Factor: 1.006
# Saved trades → C:\Users\pcagm\orb_trades_ALL_one_share_RR1to2.csv
# === ORB 15m Retest — AMAT (1 share, RR 1:2) ===
# Trades: 2204 | Total PnL: $50.53 | Win%: 46.01% | Profit Factor: 1.046
# Saved trades → C:\Users\pcagm\orb_trades_AMAT_one_share_RR1to2.csv
# === ORB 15m Retest — AMD (1 share, RR 1:2) ===
# Trades: 2207 | Total PnL: $15.09 | Win%: 48.39% | Profit Factor: 1.014
# Saved trades → C:\Users\pcagm\orb_trades_AMD_one_share_RR1to2.csv
# === ORB 15m Retest — AME (1 share, RR 1:2) ===
# Trades: 2194 | Total PnL: $-50.22 | Win%: 42.43% | Profit Factor: 0.934
# Saved trades → C:\Users\pcagm\orb_trades_AME_one_share_RR1to2.csv
# === ORB 15m Retest — AMGN (1 share, RR 1:2) ===
# Trades: 2199 | Total PnL: $-309.19 | Win%: 42.70% | Profit Factor: 0.834
# Saved trades → C:\Users\pcagm\orb_trades_AMGN_one_share_RR1to2.csv
# === ORB 15m Retest — AMP (1 share, RR 1:2) ===
# Trades: 2123 | Total PnL: $-88.35 | Win%: 44.65% | Profit Factor: 0.953
# Saved trades → C:\Users\pcagm\orb_trades_AMP_one_share_RR1to2.csv
# === ORB 15m Retest — AMT (1 share, RR 1:2) ===
# Trades: 2199 | Total PnL: $-43.45 | Win%: 45.98% | Profit Factor: 0.972
# Saved trades → C:\Users\pcagm\orb_trades_AMT_one_share_RR1to2.csv
# === ORB 15m Retest — AMZN (1 share, RR 1:2) ===
# Trades: 2244 | Total PnL: $2,889.27 | Win%: 48.13% | Profit Factor: 1.256
# Saved trades → C:\Users\pcagm\orb_trades_AMZN_one_share_RR1to2.csv
# === ORB 15m Retest — ANET (1 share, RR 1:2) ===
# Trades: 2148 | Total PnL: $-92.30 | Win%: 44.18% | Profit Factor: 0.958
# Saved trades → C:\Users\pcagm\orb_trades_ANET_one_share_RR1to2.csv
# === ORB 15m Retest — AON (1 share, RR 1:2) ===
# Trades: 2168 | Total PnL: $-68.45 | Win%: 44.60% | Profit Factor: 0.957
# Saved trades → C:\Users\pcagm\orb_trades_AON_one_share_RR1to2.csv
# === ORB 15m Retest — APD (1 share, RR 1:2) ===
# Trades: 2188 | Total PnL: $-145.69 | Win%: 43.37% | Profit Factor: 0.914
# Saved trades → C:\Users\pcagm\orb_trades_APD_one_share_RR1to2.csv
# === ORB 15m Retest — APH (1 share, RR 1:2) ===
# Trades: 2220 | Total PnL: $14.43 | Win%: 43.96% | Profit Factor: 1.024
# Saved trades → C:\Users\pcagm\orb_trades_APH_one_share_RR1to2.csv
# === ORB 15m Retest — APO (1 share, RR 1:2) ===
# Trades: 2197 | Total PnL: $19.19 | Win%: 45.33% | Profit Factor: 1.031
# Saved trades → C:\Users\pcagm\orb_trades_APO_one_share_RR1to2.csv
# === ORB 15m Retest — AVGO (1 share, RR 1:2) ===
# Trades: 2228 | Total PnL: $813.10 | Win%: 45.56% | Profit Factor: 1.199
# Saved trades → C:\Users\pcagm\orb_trades_AVGO_one_share_RR1to2.csv
# === ORB 15m Retest — AXON (1 share, RR 1:2) ===
# Trades: 2093 | Total PnL: $182.38 | Win%: 45.77% | Profit Factor: 1.104
# Saved trades → C:\Users\pcagm\orb_trades_AXON_one_share_RR1to2.csv
# === ORB 15m Retest — AXP (1 share, RR 1:2) ===
# Trades: 2253 | Total PnL: $62.06 | Win%: 45.54% | Profit Factor: 1.053
# Saved trades → C:\Users\pcagm\orb_trades_AXP_one_share_RR1to2.csv
#
# === Batch 3/15 (20 symbols) ===
# === ORB 15m Retest — AZO (1 share, RR 1:2) ===
# Trades: 1799 | Total PnL: $91.97 | Win%: 44.25% | Profit Factor: 1.011
# Saved trades → C:\Users\pcagm\orb_trades_AZO_one_share_RR1to2.csv
# === ORB 15m Retest — BA (1 share, RR 1:2) ===
# Trades: 2246 | Total PnL: $71.03 | Win%: 45.86% | Profit Factor: 1.031
# Saved trades → C:\Users\pcagm\orb_trades_BA_one_share_RR1to2.csv
# === ORB 15m Retest — BAC (1 share, RR 1:2) ===
# Trades: 2227 | Total PnL: $-10.87 | Win%: 46.39% | Profit Factor: 0.960
# Saved trades → C:\Users\pcagm\orb_trades_BAC_one_share_RR1to2.csv
# === ORB 15m Retest — BDX (1 share, RR 1:2) ===
# Trades: 2182 | Total PnL: $-85.15 | Win%: 44.73% | Profit Factor: 0.948
# Saved trades → C:\Users\pcagm\orb_trades_BDX_one_share_RR1to2.csv
# === ORB 15m Retest — BK (1 share, RR 1:2) ===
# Trades: 2230 | Total PnL: $-16.99 | Win%: 43.77% | Profit Factor: 0.958
# Saved trades → C:\Users\pcagm\orb_trades_BK_one_share_RR1to2.csv
# === ORB 15m Retest — BKNG (1 share, RR 1:2) ===
# Trades: 2021 | Total PnL: $884.66 | Win%: 46.51% | Profit Factor: 1.050
# Saved trades → C:\Users\pcagm\orb_trades_BKNG_one_share_RR1to2.csv
# === ORB 15m Retest — BKR (1 share, RR 1:2) ===
# Trades: 1861 | Total PnL: $-1.67 | Win%: 45.14% | Profit Factor: 0.994
# Saved trades → C:\Users\pcagm\orb_trades_BKR_one_share_RR1to2.csv
# === ORB 15m Retest — BLK (1 share, RR 1:2) ===
# Trades: 2136 | Total PnL: $130.28 | Win%: 44.48% | Profit Factor: 1.029
# Saved trades → C:\Users\pcagm\orb_trades_BLK_one_share_RR1to2.csv
# === ORB 15m Retest — BMY (1 share, RR 1:2) ===
# Trades: 2208 | Total PnL: $-18.62 | Win%: 44.97% | Profit Factor: 0.959
# Saved trades → C:\Users\pcagm\orb_trades_BMY_one_share_RR1to2.csv
# === ORB 15m Retest — BRK.B (1 share, RR 1:2) ===
# Trades: 2255 | Total PnL: $-121.49 | Win%: 43.95% | Profit Factor: 0.924
# Saved trades → C:\Users\pcagm\orb_trades_BRK.B_one_share_RR1to2.csv
# === ORB 15m Retest — BSX (1 share, RR 1:2) ===
# Trades: 2198 | Total PnL: $-35.09 | Win%: 45.40% | Profit Factor: 0.899
# Saved trades → C:\Users\pcagm\orb_trades_BSX_one_share_RR1to2.csv
# === ORB 15m Retest — BX (1 share, RR 1:2) ===
# Trades: 2217 | Total PnL: $95.38 | Win%: 43.93% | Profit Factor: 1.119
# Saved trades → C:\Users\pcagm\orb_trades_BX_one_share_RR1to2.csv
# === ORB 15m Retest — C (1 share, RR 1:2) ===
# Trades: 2266 | Total PnL: $-29.62 | Win%: 44.40% | Profit Factor: 0.946
# Saved trades → C:\Users\pcagm\orb_trades_C_one_share_RR1to2.csv
# === ORB 15m Retest — CAH (1 share, RR 1:2) ===
# Trades: 2196 | Total PnL: $-50.29 | Win%: 43.26% | Profit Factor: 0.919
# Saved trades → C:\Users\pcagm\orb_trades_CAH_one_share_RR1to2.csv
# === ORB 15m Retest — CARR (1 share, RR 1:2) ===
# Trades: 1247 | Total PnL: $2.17 | Win%: 45.63% | Profit Factor: 1.008
# Saved trades → C:\Users\pcagm\orb_trades_CARR_one_share_RR1to2.csv
# === ORB 15m Retest — CAT (1 share, RR 1:2) ===
# Trades: 2221 | Total PnL: $-143.49 | Win%: 44.93% | Profit Factor: 0.916
# Saved trades → C:\Users\pcagm\orb_trades_CAT_one_share_RR1to2.csv
# === ORB 15m Retest — CB (1 share, RR 1:2) ===
# Trades: 2207 | Total PnL: $35.00 | Win%: 46.49% | Profit Factor: 1.029
# Saved trades → C:\Users\pcagm\orb_trades_CB_one_share_RR1to2.csv
# === ORB 15m Retest — CBRE (1 share, RR 1:2) ===
# Trades: 2164 | Total PnL: $7.57 | Win%: 45.29% | Profit Factor: 1.013
# Saved trades → C:\Users\pcagm\orb_trades_CBRE_one_share_RR1to2.csv
# === ORB 15m Retest — CCI (1 share, RR 1:2) ===
# Trades: 2179 | Total PnL: $81.37 | Win%: 46.72% | Profit Factor: 1.085
# Saved trades → C:\Users\pcagm\orb_trades_CCI_one_share_RR1to2.csv
# === ORB 15m Retest — CCL (1 share, RR 1:2) ===
# Trades: 2237 | Total PnL: $41.48 | Win%: 48.73% | Profit Factor: 1.121
# Saved trades → C:\Users\pcagm\orb_trades_CCL_one_share_RR1to2.csv
#
# === Batch 4/15 (20 symbols) ===
# === ORB 15m Retest — CDNS (1 share, RR 1:2) ===
# Trades: 2155 | Total PnL: $79.05 | Win%: 45.99% | Profit Factor: 1.060
# Saved trades → C:\Users\pcagm\orb_trades_CDNS_one_share_RR1to2.csv
# === ORB 15m Retest — CEG (1 share, RR 1:2) ===
# Trades: 797 | Total PnL: $30.90 | Win%: 47.30% | Profit Factor: 1.040
# Saved trades → C:\Users\pcagm\orb_trades_CEG_one_share_RR1to2.csv
# === ORB 15m Retest — CFG (1 share, RR 1:2) ===
# Trades: 2 | Total PnL: $-0.63 | Win%: 0.00% | Profit Factor: 0.000
# Saved trades → C:\Users\pcagm\orb_trades_CFG_one_share_RR1to2.csv
# === ORB 15m Retest — CFLT (1 share, RR 1:2) ===
# Trades: 2 | Total PnL: $0.16 | Win%: 100.00% | Profit Factor: inf
# Saved trades → C:\Users\pcagm\orb_trades_CFLT_one_share_RR1to2.csv
# === ORB 15m Retest — CHRW (1 share, RR 1:2) ===
# Trades: 2 | Total PnL: $-0.25 | Win%: 50.00% | Profit Factor: 0.545
# Saved trades → C:\Users\pcagm\orb_trades_CHRW_one_share_RR1to2.csv
# === ORB 15m Retest — CHWY (1 share, RR 1:2) ===
# Trades: 1413 | Total PnL: $62.32 | Win%: 46.00% | Profit Factor: 1.119
# Saved trades → C:\Users\pcagm\orb_trades_CHWY_one_share_RR1to2.csv
# === ORB 15m Retest — CI (1 share, RR 1:2) ===
# Trades: 2189 | Total PnL: $-23.07 | Win%: 44.91% | Profit Factor: 0.988
# Saved trades → C:\Users\pcagm\orb_trades_CI_one_share_RR1to2.csv
# === ORB 15m Retest — CMCSA (1 share, RR 1:2) ===
# Trades: 2199 | Total PnL: $-15.60 | Win%: 45.52% | Profit Factor: 0.954
# Saved trades → C:\Users\pcagm\orb_trades_CMCSA_one_share_RR1to2.csv
# === ORB 15m Retest — CME (1 share, RR 1:2) ===
# Trades: 2167 | Total PnL: $-96.02 | Win%: 44.85% | Profit Factor: 0.929
# Saved trades → C:\Users\pcagm\orb_trades_CME_one_share_RR1to2.csv
# === ORB 15m Retest — CMI (1 share, RR 1:2) ===
# Trades: 2186 | Total PnL: $-60.33 | Win%: 43.78% | Profit Factor: 0.965
# Saved trades → C:\Users\pcagm\orb_trades_CMI_one_share_RR1to2.csv
# === ORB 15m Retest — COF (1 share, RR 1:2) ===
# Trades: 2210 | Total PnL: $-4.25 | Win%: 44.84% | Profit Factor: 0.996
# Saved trades → C:\Users\pcagm\orb_trades_COF_one_share_RR1to2.csv
# === ORB 15m Retest — COIN (1 share, RR 1:2) ===
# Trades: 1027 | Total PnL: $82.17 | Win%: 46.54% | Profit Factor: 1.043
# Saved trades → C:\Users\pcagm\orb_trades_COIN_one_share_RR1to2.csv
# === ORB 15m Retest — COP (1 share, RR 1:2) ===
# Trades: 2243 | Total PnL: $-6.27 | Win%: 44.90% | Profit Factor: 0.992
# Saved trades → C:\Users\pcagm\orb_trades_COP_one_share_RR1to2.csv
# === ORB 15m Retest — COR (1 share, RR 1:2) ===
# Trades: 2186 | Total PnL: $-154.60 | Win%: 42.86% | Profit Factor: 0.858
# Saved trades → C:\Users\pcagm\orb_trades_COR_one_share_RR1to2.csv
# === ORB 15m Retest — COST (1 share, RR 1:2) ===
# Trades: 2226 | Total PnL: $54.45 | Win%: 46.14% | Profit Factor: 1.019
# Saved trades → C:\Users\pcagm\orb_trades_COST_one_share_RR1to2.csv
# === ORB 15m Retest — CPRT (1 share, RR 1:2) ===
# Trades: 2136 | Total PnL: $-50.02 | Win%: 43.63% | Profit Factor: 0.919
# Saved trades → C:\Users\pcagm\orb_trades_CPRT_one_share_RR1to2.csv
# === ORB 15m Retest — CRM (1 share, RR 1:2) ===
# Trades: 2222 | Total PnL: $-129.87 | Win%: 43.61% | Profit Factor: 0.930
# Saved trades → C:\Users\pcagm\orb_trades_CRM_one_share_RR1to2.csv
# === ORB 15m Retest — CSCO (1 share, RR 1:2) ===
# Trades: 2249 | Total PnL: $-42.90 | Win%: 42.95% | Profit Factor: 0.876
# Saved trades → C:\Users\pcagm\orb_trades_CSCO_one_share_RR1to2.csv
# === ORB 15m Retest — CSGP (1 share, RR 1:2) ===
# Trades: 2000 | Total PnL: $-119.70 | Win%: 44.25% | Profit Factor: 0.950
# Saved trades → C:\Users\pcagm\orb_trades_CSGP_one_share_RR1to2.csv
# === ORB 15m Retest — CSX (1 share, RR 1:2) ===
# Trades: 2215 | Total PnL: $4.67 | Win%: 46.55% | Profit Factor: 1.012
# Saved trades → C:\Users\pcagm\orb_trades_CSX_one_share_RR1to2.csv
#
# === Batch 5/15 (20 symbols) ===
# === ORB 15m Retest — CTAS (1 share, RR 1:2) ===
# Trades: 2051 | Total PnL: $42.56 | Win%: 46.71% | Profit Factor: 1.023
# Saved trades → C:\Users\pcagm\orb_trades_CTAS_one_share_RR1to2.csv
# === ORB 15m Retest — CTSH (1 share, RR 1:2) ===
# Trades: 2204 | Total PnL: $-32.48 | Win%: 45.19% | Profit Factor: 0.939
# Saved trades → C:\Users\pcagm\orb_trades_CTSH_one_share_RR1to2.csv
# === ORB 15m Retest — CVNA (1 share, RR 1:2) ===
# Trades: 1880 | Total PnL: $30.28 | Win%: 42.98% | Profit Factor: 1.014
# Saved trades → C:\Users\pcagm\orb_trades_CVNA_one_share_RR1to2.csv
# === ORB 15m Retest — CVS (1 share, RR 1:2) ===
# Trades: 2210 | Total PnL: $33.07 | Win%: 47.24% | Profit Factor: 1.057
# Saved trades → C:\Users\pcagm\orb_trades_CVS_one_share_RR1to2.csv
# === ORB 15m Retest — CVX (1 share, RR 1:2) ===
# Trades: 2270 | Total PnL: $-109.33 | Win%: 42.91% | Profit Factor: 0.894
# Saved trades → C:\Users\pcagm\orb_trades_CVX_one_share_RR1to2.csv
# === ORB 15m Retest — D (1 share, RR 1:2) ===
# Trades: 2228 | Total PnL: $35.34 | Win%: 45.87% | Profit Factor: 1.073
# Saved trades → C:\Users\pcagm\orb_trades_D_one_share_RR1to2.csv
# === ORB 15m Retest — DAL (1 share, RR 1:2) ===
# Trades: 2232 | Total PnL: $-23.76 | Win%: 44.53% | Profit Factor: 0.953
# Saved trades → C:\Users\pcagm\orb_trades_DAL_one_share_RR1to2.csv
# === ORB 15m Retest — DASH (1 share, RR 1:2) ===
# Trades: 1077 | Total PnL: $80.84 | Win%: 45.50% | Profit Factor: 1.076
# Saved trades → C:\Users\pcagm\orb_trades_DASH_one_share_RR1to2.csv
# === ORB 15m Retest — DDOG (1 share, RR 1:2) ===
# Trades: 1348 | Total PnL: $-92.37 | Win%: 45.77% | Profit Factor: 0.917
# Saved trades → C:\Users\pcagm\orb_trades_DDOG_one_share_RR1to2.csv
# === ORB 15m Retest — DELL (1 share, RR 1:2) ===
# Trades: 1546 | Total PnL: $19.74 | Win%: 45.15% | Profit Factor: 1.034
# Saved trades → C:\Users\pcagm\orb_trades_DELL_one_share_RR1to2.csv
# === ORB 15m Retest — DHI (1 share, RR 1:2) ===
# Trades: 2225 | Total PnL: $13.51 | Win%: 46.11% | Profit Factor: 1.017
# Saved trades → C:\Users\pcagm\orb_trades_DHI_one_share_RR1to2.csv
# === ORB 15m Retest — DHR (1 share, RR 1:2) ===
# Trades: 2170 | Total PnL: $-0.17 | Win%: 45.58% | Profit Factor: 1.000
# Saved trades → C:\Users\pcagm\orb_trades_DHR_one_share_RR1to2.csv
# === ORB 15m Retest — DIS (1 share, RR 1:2) ===
# Trades: 2231 | Total PnL: $-68.61 | Win%: 42.99% | Profit Factor: 0.925
# Saved trades → C:\Users\pcagm\orb_trades_DIS_one_share_RR1to2.csv
# === ORB 15m Retest — DLR (1 share, RR 1:2) ===
# Trades: 2209 | Total PnL: $19.99 | Win%: 45.99% | Profit Factor: 1.018
# Saved trades → C:\Users\pcagm\orb_trades_DLR_one_share_RR1to2.csv
# === ORB 15m Retest — DUK (1 share, RR 1:2) ===
# Trades: 2243 | Total PnL: $22.30 | Win%: 45.07% | Profit Factor: 1.036
# Saved trades → C:\Users\pcagm\orb_trades_DUK_one_share_RR1to2.csv
# === ORB 15m Retest — EA (1 share, RR 1:2) ===
# Trades: 2201 | Total PnL: $-65.21 | Win%: 44.62% | Profit Factor: 0.935
# Saved trades → C:\Users\pcagm\orb_trades_EA_one_share_RR1to2.csv
# === ORB 15m Retest — EBAY (1 share, RR 1:2) ===
# Trades: 2188 | Total PnL: $19.96 | Win%: 45.61% | Profit Factor: 1.047
# Saved trades → C:\Users\pcagm\orb_trades_EBAY_one_share_RR1to2.csv
# === ORB 15m Retest — ECL (1 share, RR 1:2) ===
# Trades: 2208 | Total PnL: $106.99 | Win%: 47.10% | Profit Factor: 1.091
# Saved trades → C:\Users\pcagm\orb_trades_ECL_one_share_RR1to2.csv
# === ORB 15m Retest — ED (1 share, RR 1:2) ===
# Trades: 2244 | Total PnL: $5.88 | Win%: 45.05% | Profit Factor: 1.010
# Saved trades → C:\Users\pcagm\orb_trades_ED_one_share_RR1to2.csv
# === ORB 15m Retest — EMR (1 share, RR 1:2) ===
# Trades: 2260 | Total PnL: $-12.05 | Win%: 45.75% | Profit Factor: 0.981
# Saved trades → C:\Users\pcagm\orb_trades_EMR_one_share_RR1to2.csv
#
# === Batch 6/15 (20 symbols) ===
# === ORB 15m Retest — EOG (1 share, RR 1:2) ===
# Trades: 2259 | Total PnL: $-28.14 | Win%: 46.48% | Profit Factor: 0.974
# Saved trades → C:\Users\pcagm\orb_trades_EOG_one_share_RR1to2.csv
# === ORB 15m Retest — EQIX (1 share, RR 1:2) ===
# Trades: 2061 | Total PnL: $102.74 | Win%: 45.85% | Profit Factor: 1.021
# Saved trades → C:\Users\pcagm\orb_trades_EQIX_one_share_RR1to2.csv
# === ORB 15m Retest — ES (1 share, RR 1:2) ===
# Trades: 3609 | Total PnL: $652.50 | Win%: 38.99% | Profit Factor: 1.037
# Saved trades → C:\Users\pcagm\orb_trades_ES_one_share_RR1to2.csv
# === ORB 15m Retest — ETN (1 share, RR 1:2) ===
# Trades: 2197 | Total PnL: $-15.57 | Win%: 44.65% | Profit Factor: 0.987
# Saved trades → C:\Users\pcagm\orb_trades_ETN_one_share_RR1to2.csv
# === ORB 15m Retest — ETR (1 share, RR 1:2) ===
# Trades: 2198 | Total PnL: $-12.67 | Win%: 43.99% | Profit Factor: 0.982
# Saved trades → C:\Users\pcagm\orb_trades_ETR_one_share_RR1to2.csv
# === ORB 15m Retest — EW (1 share, RR 1:2) ===
# Trades: 2194 | Total PnL: $-2.80 | Win%: 45.49% | Profit Factor: 0.997
# Saved trades → C:\Users\pcagm\orb_trades_EW_one_share_RR1to2.csv
# === ORB 15m Retest — EXC (1 share, RR 1:2) ===
# Trades: 2246 | Total PnL: $0.11 | Win%: 45.68% | Profit Factor: 1.000
# Saved trades → C:\Users\pcagm\orb_trades_EXC_one_share_RR1to2.csv
# === ORB 15m Retest — F (1 share, RR 1:2) ===
# Trades: 2164 | Total PnL: $5.37 | Win%: 47.41% | Profit Factor: 1.047
# Saved trades → C:\Users\pcagm\orb_trades_F_one_share_RR1to2.csv
# === ORB 15m Retest — FANG (1 share, RR 1:2) ===
# Trades: 2234 | Total PnL: $-82.36 | Win%: 44.58% | Profit Factor: 0.944
# Saved trades → C:\Users\pcagm\orb_trades_FANG_one_share_RR1to2.csv
# === ORB 15m Retest — FAST (1 share, RR 1:2) ===
# Trades: 2174 | Total PnL: $-66.98 | Win%: 41.90% | Profit Factor: 0.851
# Saved trades → C:\Users\pcagm\orb_trades_FAST_one_share_RR1to2.csv
# === ORB 15m Retest — FCX (1 share, RR 1:2) ===
# Trades: 2216 | Total PnL: $-52.68 | Win%: 43.46% | Profit Factor: 0.855
# Saved trades → C:\Users\pcagm\orb_trades_FCX_one_share_RR1to2.csv
# === ORB 15m Retest — FDX (1 share, RR 1:2) ===
# Trades: 2221 | Total PnL: $-50.51 | Win%: 45.29% | Profit Factor: 0.972
# Saved trades → C:\Users\pcagm\orb_trades_FDX_one_share_RR1to2.csv
# === ORB 15m Retest — FI (1 share, RR 1:2) ===
# Trades: 2202 | Total PnL: $42.59 | Win%: 47.32% | Profit Factor: 1.050
# Saved trades → C:\Users\pcagm\orb_trades_FI_one_share_RR1to2.csv
# === ORB 15m Retest — FICO (1 share, RR 1:2) ===
# Trades: 1781 | Total PnL: $-214.42 | Win%: 43.68% | Profit Factor: 0.948
# Saved trades → C:\Users\pcagm\orb_trades_FICO_one_share_RR1to2.csv
# === ORB 15m Retest — FIS (1 share, RR 1:2) ===
# Trades: 2202 | Total PnL: $12.76 | Win%: 44.91% | Profit Factor: 1.017
# Saved trades → C:\Users\pcagm\orb_trades_FIS_one_share_RR1to2.csv
# === ORB 15m Retest — GD (1 share, RR 1:2) ===
# Trades: 2211 | Total PnL: $-26.45 | Win%: 44.14% | Profit Factor: 0.981
# Saved trades → C:\Users\pcagm\orb_trades_GD_one_share_RR1to2.csv
# === ORB 15m Retest — GE (1 share, RR 1:2) ===
# Trades: 2189 | Total PnL: $36.52 | Win%: 47.24% | Profit Factor: 1.065
# Saved trades → C:\Users\pcagm\orb_trades_GE_one_share_RR1to2.csv
# === ORB 15m Retest — GEHC (1 share, RR 1:2) ===
# Trades: 623 | Total PnL: $12.81 | Win%: 45.10% | Profit Factor: 1.068
# Saved trades → C:\Users\pcagm\orb_trades_GEHC_one_share_RR1to2.csv
# === ORB 15m Retest — GEV (1 share, RR 1:2) ===
# Trades: 327 | Total PnL: $43.13 | Win%: 47.71% | Profit Factor: 1.058
# Saved trades → C:\Users\pcagm\orb_trades_GEV_one_share_RR1to2.csv
# === ORB 15m Retest — GILD (1 share, RR 1:2) ===
# Trades: 2186 | Total PnL: $-56.21 | Win%: 44.46% | Profit Factor: 0.907
# Saved trades → C:\Users\pcagm\orb_trades_GILD_one_share_RR1to2.csv
#
# === Batch 7/15 (20 symbols) ===
# === ORB 15m Retest — GLD (1 share, RR 1:2) ===
# Trades: 2270 | Total PnL: $45.16 | Win%: 41.85% | Profit Factor: 1.092
# Saved trades → C:\Users\pcagm\orb_trades_GLD_one_share_RR1to2.csv
# === ORB 15m Retest — GLW (1 share, RR 1:2) ===
# Trades: 2194 | Total PnL: $-16.53 | Win%: 43.16% | Profit Factor: 0.940
# Saved trades → C:\Users\pcagm\orb_trades_GLW_one_share_RR1to2.csv
# === ORB 15m Retest — GM (1 share, RR 1:2) ===
# Trades: 2197 | Total PnL: $2.25 | Win%: 45.84% | Profit Factor: 1.006
# Saved trades → C:\Users\pcagm\orb_trades_GM_one_share_RR1to2.csv
# === ORB 15m Retest — GOOG (1 share, RR 1:2) ===
# Trades: 2242 | Total PnL: $39.33 | Win%: 44.92% | Profit Factor: 1.005
# Saved trades → C:\Users\pcagm\orb_trades_GOOG_one_share_RR1to2.csv
# === ORB 15m Retest — GOOGL (1 share, RR 1:2) ===
# Trades: 2235 | Total PnL: $-86.07 | Win%: 45.23% | Profit Factor: 0.990
# Saved trades → C:\Users\pcagm\orb_trades_GOOGL_one_share_RR1to2.csv
# === ORB 15m Retest — GRMN (1 share, RR 1:2) ===
# Trades: 2119 | Total PnL: $3.30 | Win%: 44.31% | Profit Factor: 1.004
# Saved trades → C:\Users\pcagm\orb_trades_GRMN_one_share_RR1to2.csv
# === ORB 15m Retest — GS (1 share, RR 1:2) ===
# Trades: 2231 | Total PnL: $-263.30 | Win%: 43.66% | Profit Factor: 0.902
# Saved trades → C:\Users\pcagm\orb_trades_GS_one_share_RR1to2.csv
# === ORB 15m Retest — GWW (1 share, RR 1:2) ===
# Trades: 1983 | Total PnL: $-51.49 | Win%: 43.77% | Profit Factor: 0.983
# Saved trades → C:\Users\pcagm\orb_trades_GWW_one_share_RR1to2.csv
# === ORB 15m Retest — HCA (1 share, RR 1:2) ===
# Trades: 2181 | Total PnL: $-126.45 | Win%: 44.38% | Profit Factor: 0.925
# Saved trades → C:\Users\pcagm\orb_trades_HCA_one_share_RR1to2.csv
# === ORB 15m Retest — HD (1 share, RR 1:2) ===
# Trades: 2235 | Total PnL: $-8.60 | Win%: 46.35% | Profit Factor: 0.996
# Saved trades → C:\Users\pcagm\orb_trades_HD_one_share_RR1to2.csv
# === ORB 15m Retest — HIG (1 share, RR 1:2) ===
# Trades: 2208 | Total PnL: $-23.58 | Win%: 43.70% | Profit Factor: 0.952
# Saved trades → C:\Users\pcagm\orb_trades_HIG_one_share_RR1to2.csv
# === ORB 15m Retest — HLT (1 share, RR 1:2) ===
# Trades: 2206 | Total PnL: $30.59 | Win%: 45.74% | Profit Factor: 1.032
# Saved trades → C:\Users\pcagm\orb_trades_HLT_one_share_RR1to2.csv
# === ORB 15m Retest — HON (1 share, RR 1:2) ===
# Trades: 2247 | Total PnL: $36.57 | Win%: 46.37% | Profit Factor: 1.032
# Saved trades → C:\Users\pcagm\orb_trades_HON_one_share_RR1to2.csv
# === ORB 15m Retest — HSY (1 share, RR 1:2) ===
# Trades: 2172 | Total PnL: $-27.55 | Win%: 44.75% | Profit Factor: 0.974
# Saved trades → C:\Users\pcagm\orb_trades_HSY_one_share_RR1to2.csv
# === ORB 15m Retest — HUM (1 share, RR 1:2) ===
# Trades: 2161 | Total PnL: $-87.02 | Win%: 44.56% | Profit Factor: 0.971
# Saved trades → C:\Users\pcagm\orb_trades_HUM_one_share_RR1to2.csv
# === ORB 15m Retest — HWM (1 share, RR 1:2) ===
# Trades: 1252 | Total PnL: $27.35 | Win%: 46.57% | Profit Factor: 1.090
# Saved trades → C:\Users\pcagm\orb_trades_HWM_one_share_RR1to2.csv
# === ORB 15m Retest — IBM (1 share, RR 1:2) ===
# Trades: 2225 | Total PnL: $23.15 | Win%: 45.21% | Profit Factor: 1.023
# Saved trades → C:\Users\pcagm\orb_trades_IBM_one_share_RR1to2.csv
# === ORB 15m Retest — ICE (1 share, RR 1:2) ===
# Trades: 2209 | Total PnL: $-52.21 | Win%: 45.41% | Profit Factor: 0.936
# Saved trades → C:\Users\pcagm\orb_trades_ICE_one_share_RR1to2.csv
# === ORB 15m Retest — IDXX (1 share, RR 1:2) ===
# Trades: 2058 | Total PnL: $-315.14 | Win%: 43.93% | Profit Factor: 0.903
# Saved trades → C:\Users\pcagm\orb_trades_IDXX_one_share_RR1to2.csv
# === ORB 15m Retest — INTC (1 share, RR 1:2) ===
# Trades: 2229 | Total PnL: $37.24 | Win%: 46.30% | Profit Factor: 1.095
# Saved trades → C:\Users\pcagm\orb_trades_INTC_one_share_RR1to2.csv
#
# === Batch 8/15 (20 symbols) ===
# === ORB 15m Retest — INTU (1 share, RR 1:2) ===
# Trades: 2180 | Total PnL: $80.90 | Win%: 46.24% | Profit Factor: 1.024
# Saved trades → C:\Users\pcagm\orb_trades_INTU_one_share_RR1to2.csv
# === ORB 15m Retest — ISRG (1 share, RR 1:2) ===
# Trades: 2155 | Total PnL: $-368.14 | Win%: 43.85% | Profit Factor: 0.918
# Saved trades → C:\Users\pcagm\orb_trades_ISRG_one_share_RR1to2.csv
# === ORB 15m Retest — ITW (1 share, RR 1:2) ===
# Trades: 2208 | Total PnL: $-119.84 | Win%: 42.93% | Profit Factor: 0.911
# Saved trades → C:\Users\pcagm\orb_trades_ITW_one_share_RR1to2.csv
# === ORB 15m Retest — JCI (1 share, RR 1:2) ===
# Trades: 2244 | Total PnL: $42.06 | Win%: 46.03% | Profit Factor: 1.102
# Saved trades → C:\Users\pcagm\orb_trades_JCI_one_share_RR1to2.csv
# === ORB 15m Retest — JNJ (1 share, RR 1:2) ===
# Trades: 2210 | Total PnL: $-76.43 | Win%: 44.48% | Profit Factor: 0.912
# Saved trades → C:\Users\pcagm\orb_trades_JNJ_one_share_RR1to2.csv
# === ORB 15m Retest — JPM (1 share, RR 1:2) ===
# Trades: 2269 | Total PnL: $-88.62 | Win%: 43.32% | Profit Factor: 0.915
# Saved trades → C:\Users\pcagm\orb_trades_JPM_one_share_RR1to2.csv
# === ORB 15m Retest — KDP (1 share, RR 1:2) ===
# Trades: 2179 | Total PnL: $-14.81 | Win%: 44.52% | Profit Factor: 0.948
# Saved trades → C:\Users\pcagm\orb_trades_KDP_one_share_RR1to2.csv
# === ORB 15m Retest — KKR (1 share, RR 1:2) ===
# Trades: 2195 | Total PnL: $83.08 | Win%: 46.38% | Profit Factor: 1.167
# Saved trades → C:\Users\pcagm\orb_trades_KKR_one_share_RR1to2.csv
# === ORB 15m Retest — KLAC (1 share, RR 1:2) ===
# Trades: 2165 | Total PnL: $355.34 | Win%: 46.42% | Profit Factor: 1.109
# Saved trades → C:\Users\pcagm\orb_trades_KLAC_one_share_RR1to2.csv
# === ORB 15m Retest — KMB (1 share, RR 1:2) ===
# Trades: 2211 | Total PnL: $-38.59 | Win%: 44.37% | Profit Factor: 0.954
# Saved trades → C:\Users\pcagm\orb_trades_KMB_one_share_RR1to2.csv
# === ORB 15m Retest — KMI (1 share, RR 1:2) ===
# Trades: 2227 | Total PnL: $-11.87 | Win%: 43.65% | Profit Factor: 0.932
# Saved trades → C:\Users\pcagm\orb_trades_KMI_one_share_RR1to2.csv
# === ORB 15m Retest — KO (1 share, RR 1:2) ===
# Trades: 2226 | Total PnL: $-18.95 | Win%: 43.31% | Profit Factor: 0.938
# Saved trades → C:\Users\pcagm\orb_trades_KO_one_share_RR1to2.csv
# === ORB 15m Retest — KR (1 share, RR 1:2) ===
# Trades: 2170 | Total PnL: $28.74 | Win%: 47.37% | Profit Factor: 1.093
# Saved trades → C:\Users\pcagm\orb_trades_KR_one_share_RR1to2.csv
# === ORB 15m Retest — KVUE (1 share, RR 1:2) ===
# Trades: 545 | Total PnL: $-8.73 | Win%: 42.20% | Profit Factor: 0.825
# Saved trades → C:\Users\pcagm\orb_trades_KVUE_one_share_RR1to2.csv
# === ORB 15m Retest — LEN (1 share, RR 1:2) ===
# Trades: 2210 | Total PnL: $-84.62 | Win%: 44.39% | Profit Factor: 0.909
# Saved trades → C:\Users\pcagm\orb_trades_LEN_one_share_RR1to2.csv
# === ORB 15m Retest — LHX (1 share, RR 1:2) ===
# Trades: 2178 | Total PnL: $45.01 | Win%: 44.63% | Profit Factor: 1.033
# Saved trades → C:\Users\pcagm\orb_trades_LHX_one_share_RR1to2.csv
# === ORB 15m Retest — LIN (1 share, RR 1:2) ===
# Trades: 1578 | Total PnL: $-63.32 | Win%: 41.95% | Profit Factor: 0.955
# Saved trades → C:\Users\pcagm\orb_trades_LIN_one_share_RR1to2.csv
# === ORB 15m Retest — LLY (1 share, RR 1:2) ===
# Trades: 2212 | Total PnL: $-297.26 | Win%: 45.34% | Profit Factor: 0.893
# Saved trades → C:\Users\pcagm\orb_trades_LLY_one_share_RR1to2.csv
# === ORB 15m Retest — LMT (1 share, RR 1:2) ===
# Trades: 2221 | Total PnL: $-69.02 | Win%: 44.57% | Profit Factor: 0.973
# Saved trades → C:\Users\pcagm\orb_trades_LMT_one_share_RR1to2.csv
# === ORB 15m Retest — LRCX (1 share, RR 1:2) ===
# Trades: 2200 | Total PnL: $233.49 | Win%: 45.59% | Profit Factor: 1.055
# Saved trades → C:\Users\pcagm\orb_trades_LRCX_one_share_RR1to2.csv
#
# === Batch 9/15 (20 symbols) ===
# === ORB 15m Retest — LYV (1 share, RR 1:2) ===
# Trades: 2226 | Total PnL: $13.54 | Win%: 44.16% | Profit Factor: 1.017
# Saved trades → C:\Users\pcagm\orb_trades_LYV_one_share_RR1to2.csv
# === ORB 15m Retest — MA (1 share, RR 1:2) ===
# Trades: 2230 | Total PnL: $-218.61 | Win%: 43.50% | Profit Factor: 0.909
# Saved trades → C:\Users\pcagm\orb_trades_MA_one_share_RR1to2.csv
# === ORB 15m Retest — MAR (1 share, RR 1:2) ===
# Trades: 2183 | Total PnL: $61.94 | Win%: 45.90% | Profit Factor: 1.049
# Saved trades → C:\Users\pcagm\orb_trades_MAR_one_share_RR1to2.csv
# === ORB 15m Retest — MCD (1 share, RR 1:2) ===
# Trades: 2231 | Total PnL: $48.04 | Win%: 45.09% | Profit Factor: 1.038
# Saved trades → C:\Users\pcagm\orb_trades_MCD_one_share_RR1to2.csv
# === ORB 15m Retest — MCHP (1 share, RR 1:2) ===
# Trades: 2230 | Total PnL: $100.71 | Win%: 45.96% | Profit Factor: 1.112
# Saved trades → C:\Users\pcagm\orb_trades_MCHP_one_share_RR1to2.csv
# === ORB 15m Retest — MCK (1 share, RR 1:2) ===
# Trades: 2152 | Total PnL: $-279.71 | Win%: 43.54% | Profit Factor: 0.875
# Saved trades → C:\Users\pcagm\orb_trades_MCK_one_share_RR1to2.csv
# === ORB 15m Retest — MDLZ (1 share, RR 1:2) ===
# Trades: 2205 | Total PnL: $-37.42 | Win%: 44.17% | Profit Factor: 0.903
# Saved trades → C:\Users\pcagm\orb_trades_MDLZ_one_share_RR1to2.csv
# === ORB 15m Retest — MDT (1 share, RR 1:2) ===
# Trades: 2206 | Total PnL: $13.79 | Win%: 45.56% | Profit Factor: 1.022
# Saved trades → C:\Users\pcagm\orb_trades_MDT_one_share_RR1to2.csv
# === ORB 15m Retest — MET (1 share, RR 1:2) ===
# Trades: 2242 | Total PnL: $-85.82 | Win%: 42.11% | Profit Factor: 0.832
# Saved trades → C:\Users\pcagm\orb_trades_MET_one_share_RR1to2.csv
# === ORB 15m Retest — META (1 share, RR 1:2) ===
# Trades: 2257 | Total PnL: $90.42 | Win%: 46.43% | Profit Factor: 1.034
# Saved trades → C:\Users\pcagm\orb_trades_META_one_share_RR1to2.csv
# === ORB 15m Retest — MLM (1 share, RR 1:2) ===
# Trades: 2119 | Total PnL: $-102.52 | Win%: 43.70% | Profit Factor: 0.962
# Saved trades → C:\Users\pcagm\orb_trades_MLM_one_share_RR1to2.csv
# === ORB 15m Retest — MMC (1 share, RR 1:2) ===
# Trades: 2237 | Total PnL: $-87.72 | Win%: 43.59% | Profit Factor: 0.898
# Saved trades → C:\Users\pcagm\orb_trades_MMC_one_share_RR1to2.csv
# === ORB 15m Retest — MMM (1 share, RR 1:2) ===
# Trades: 2226 | Total PnL: $-36.32 | Win%: 44.88% | Profit Factor: 0.968
# Saved trades → C:\Users\pcagm\orb_trades_MMM_one_share_RR1to2.csv
# === ORB 15m Retest — MNST (1 share, RR 1:2) ===
# Trades: 2200 | Total PnL: $-16.91 | Win%: 44.91% | Profit Factor: 0.970
# Saved trades → C:\Users\pcagm\orb_trades_MNST_one_share_RR1to2.csv
# === ORB 15m Retest — MO (1 share, RR 1:2) ===
# Trades: 2208 | Total PnL: $26.57 | Win%: 46.20% | Profit Factor: 1.079
# Saved trades → C:\Users\pcagm\orb_trades_MO_one_share_RR1to2.csv
# === ORB 15m Retest — MPC (1 share, RR 1:2) ===
# Trades: 2233 | Total PnL: $65.33 | Win%: 47.20% | Profit Factor: 1.070
# Saved trades → C:\Users\pcagm\orb_trades_MPC_one_share_RR1to2.csv
# === ORB 15m Retest — MPWR (1 share, RR 1:2) ===
# Trades: 2018 | Total PnL: $949.12 | Win%: 47.18% | Profit Factor: 1.254
# Saved trades → C:\Users\pcagm\orb_trades_MPWR_one_share_RR1to2.csv
# === ORB 15m Retest — MRK (1 share, RR 1:2) ===
# Trades: 2200 | Total PnL: $-99.46 | Win%: 42.50% | Profit Factor: 0.840
# Saved trades → C:\Users\pcagm\orb_trades_MRK_one_share_RR1to2.csv
# === ORB 15m Retest — MS (1 share, RR 1:2) ===
# Trades: 2248 | Total PnL: $-16.37 | Win%: 44.35% | Profit Factor: 0.974
# Saved trades → C:\Users\pcagm\orb_trades_MS_one_share_RR1to2.csv
# === ORB 15m Retest — MSCI (1 share, RR 1:2) ===
# Trades: 2051 | Total PnL: $216.48 | Win%: 44.03% | Profit Factor: 1.076
# Saved trades → C:\Users\pcagm\orb_trades_MSCI_one_share_RR1to2.csv
#
# === Batch 10/15 (20 symbols) ===
# === ORB 15m Retest — MSFT (1 share, RR 1:2) ===
# Trades: 2268 | Total PnL: $11.65 | Win%: 44.40% | Profit Factor: 1.007
# Saved trades → C:\Users\pcagm\orb_trades_MSFT_one_share_RR1to2.csv
# === ORB 15m Retest — MSI (1 share, RR 1:2) ===
# Trades: 2135 | Total PnL: $-92.01 | Win%: 44.36% | Profit Factor: 0.935
# Saved trades → C:\Users\pcagm\orb_trades_MSI_one_share_RR1to2.csv
# === ORB 15m Retest — MU (1 share, RR 1:2) ===
# Trades: 2219 | Total PnL: $-21.51 | Win%: 46.06% | Profit Factor: 0.974
# Saved trades → C:\Users\pcagm\orb_trades_MU_one_share_RR1to2.csv
# === ORB 15m Retest — NDAQ (1 share, RR 1:2) ===
# Trades: 2200 | Total PnL: $-27.21 | Win%: 44.55% | Profit Factor: 0.960
# Saved trades → C:\Users\pcagm\orb_trades_NDAQ_one_share_RR1to2.csv
# === ORB 15m Retest — NEE (1 share, RR 1:2) ===
# Trades: 2226 | Total PnL: $87.00 | Win%: 45.87% | Profit Factor: 1.096
# Saved trades → C:\Users\pcagm\orb_trades_NEE_one_share_RR1to2.csv
# === ORB 15m Retest — NEM (1 share, RR 1:2) ===
# Trades: 2214 | Total PnL: $36.67 | Win%: 46.12% | Profit Factor: 1.081
# Saved trades → C:\Users\pcagm\orb_trades_NEM_one_share_RR1to2.csv
# === ORB 15m Retest — NET (1 share, RR 1:2) ===
# Trades: 1362 | Total PnL: $85.92 | Win%: 46.40% | Profit Factor: 1.090
# Saved trades → C:\Users\pcagm\orb_trades_NET_one_share_RR1to2.csv
# === ORB 15m Retest — NFLX (1 share, RR 1:2) ===
# Trades: 2250 | Total PnL: $648.58 | Win%: 47.20% | Profit Factor: 1.147
# Saved trades → C:\Users\pcagm\orb_trades_NFLX_one_share_RR1to2.csv
# === ORB 15m Retest — NKE (1 share, RR 1:2) ===
# Trades: 2234 | Total PnL: $10.84 | Win%: 46.96% | Profit Factor: 1.014
# Saved trades → C:\Users\pcagm\orb_trades_NKE_one_share_RR1to2.csv
# === ORB 15m Retest — NOC (1 share, RR 1:2) ===
# Trades: 2141 | Total PnL: $66.36 | Win%: 46.19% | Profit Factor: 1.026
# Saved trades → C:\Users\pcagm\orb_trades_NOC_one_share_RR1to2.csv
# === ORB 15m Retest — NOW (1 share, RR 1:2) ===
# Trades: 2200 | Total PnL: $11.33 | Win%: 45.18% | Profit Factor: 1.002
# Saved trades → C:\Users\pcagm\orb_trades_NOW_one_share_RR1to2.csv
# === ORB 15m Retest — NQ (1 share, RR 1:2) ===
# Trades: 3574 | Total PnL: $1,678.75 | Win%: 40.49% | Profit Factor: 1.023
# Saved trades → C:\Users\pcagm\orb_trades_NQ_one_share_RR1to2.csv
# === ORB 15m Retest — NSC (1 share, RR 1:2) ===
# Trades: 2192 | Total PnL: $-90.40 | Win%: 44.71% | Profit Factor: 0.944
# Saved trades → C:\Users\pcagm\orb_trades_NSC_one_share_RR1to2.csv
# === ORB 15m Retest — NVDA (1 share, RR 1:2) ===
# Trades: 2234 | Total PnL: $391.13 | Win%: 47.45% | Profit Factor: 1.110
# Saved trades → C:\Users\pcagm\orb_trades_NVDA_one_share_RR1to2.csv
# === ORB 15m Retest — NXPI (1 share, RR 1:2) ===
# Trades: 2203 | Total PnL: $75.36 | Win%: 45.62% | Profit Factor: 1.046
# Saved trades → C:\Users\pcagm\orb_trades_NXPI_one_share_RR1to2.csv
# === ORB 15m Retest — O (1 share, RR 1:2) ===
# Trades: 2230 | Total PnL: $-30.54 | Win%: 44.62% | Profit Factor: 0.934
# Saved trades → C:\Users\pcagm\orb_trades_O_one_share_RR1to2.csv
# === ORB 15m Retest — OKE (1 share, RR 1:2) ===
# Trades: 2227 | Total PnL: $-36.88 | Win%: 43.20% | Profit Factor: 0.938
# Saved trades → C:\Users\pcagm\orb_trades_OKE_one_share_RR1to2.csv
# === ORB 15m Retest — ORCL (1 share, RR 1:2) ===
# Trades: 2199 | Total PnL: $-1.90 | Win%: 44.75% | Profit Factor: 0.997
# Saved trades → C:\Users\pcagm\orb_trades_ORCL_one_share_RR1to2.csv
# === ORB 15m Retest — ORLY (1 share, RR 1:2) ===
# Trades: 2083 | Total PnL: $-9.92 | Win%: 46.04% | Profit Factor: 0.997
# Saved trades → C:\Users\pcagm\orb_trades_ORLY_one_share_RR1to2.csv
# === ORB 15m Retest — OXY (1 share, RR 1:2) ===
# Trades: 2219 | Total PnL: $-3.28 | Win%: 45.25% | Profit Factor: 0.994
# Saved trades → C:\Users\pcagm\orb_trades_OXY_one_share_RR1to2.csv
#
# === Batch 11/15 (20 symbols) ===
# === ORB 15m Retest — PANW (1 share, RR 1:2) ===
# Trades: 2191 | Total PnL: $-228.59 | Win%: 45.87% | Profit Factor: 0.922
# Saved trades → C:\Users\pcagm\orb_trades_PANW_one_share_RR1to2.csv
# === ORB 15m Retest — PAYX (1 share, RR 1:2) ===
# Trades: 2211 | Total PnL: $19.66 | Win%: 45.59% | Profit Factor: 1.028
# Saved trades → C:\Users\pcagm\orb_trades_PAYX_one_share_RR1to2.csv
# === ORB 15m Retest — PCAR (1 share, RR 1:2) ===
# Trades: 2167 | Total PnL: $-126.43 | Win%: 43.05% | Profit Factor: 0.819
# Saved trades → C:\Users\pcagm\orb_trades_PCAR_one_share_RR1to2.csv
# === ORB 15m Retest — PEG (1 share, RR 1:2) ===
# Trades: 2211 | Total PnL: $-9.93 | Win%: 45.05% | Profit Factor: 0.977
# Saved trades → C:\Users\pcagm\orb_trades_PEG_one_share_RR1to2.csv
# === ORB 15m Retest — PEP (1 share, RR 1:2) ===
# Trades: 2229 | Total PnL: $-86.04 | Win%: 43.74% | Profit Factor: 0.901
# Saved trades → C:\Users\pcagm\orb_trades_PEP_one_share_RR1to2.csv
# === ORB 15m Retest — PFE (1 share, RR 1:2) ===
# Trades: 2208 | Total PnL: $-9.19 | Win%: 45.34% | Profit Factor: 0.966
# Saved trades → C:\Users\pcagm\orb_trades_PFE_one_share_RR1to2.csv
# === ORB 15m Retest — PG (1 share, RR 1:2) ===
# Trades: 2231 | Total PnL: $-0.27 | Win%: 45.94% | Profit Factor: 1.000
# Saved trades → C:\Users\pcagm\orb_trades_PG_one_share_RR1to2.csv
# === ORB 15m Retest — PGR (1 share, RR 1:2) ===
# Trades: 2183 | Total PnL: $44.09 | Win%: 47.27% | Profit Factor: 1.057
# Saved trades → C:\Users\pcagm\orb_trades_PGR_one_share_RR1to2.csv
# === ORB 15m Retest — PH (1 share, RR 1:2) ===
# Trades: 2166 | Total PnL: $45.84 | Win%: 44.00% | Profit Factor: 1.019
# Saved trades → C:\Users\pcagm\orb_trades_PH_one_share_RR1to2.csv
# === ORB 15m Retest — PLD (1 share, RR 1:2) ===
# Trades: 2227 | Total PnL: $93.73 | Win%: 47.19% | Profit Factor: 1.119
# Saved trades → C:\Users\pcagm\orb_trades_PLD_one_share_RR1to2.csv
# === ORB 15m Retest — PLTR (1 share, RR 1:2) ===
# Trades: 1130 | Total PnL: $72.12 | Win%: 48.50% | Profit Factor: 1.222
# Saved trades → C:\Users\pcagm\orb_trades_PLTR_one_share_RR1to2.csv
# === ORB 15m Retest — PM (1 share, RR 1:2) ===
# Trades: 2227 | Total PnL: $34.51 | Win%: 46.48% | Profit Factor: 1.054
# Saved trades → C:\Users\pcagm\orb_trades_PM_one_share_RR1to2.csv
# === ORB 15m Retest — PNC (1 share, RR 1:2) ===
# Trades: 2224 | Total PnL: $-8.62 | Win%: 44.56% | Profit Factor: 0.993
# Saved trades → C:\Users\pcagm\orb_trades_PNC_one_share_RR1to2.csv
# === ORB 15m Retest — PRU (1 share, RR 1:2) ===
# Trades: 2215 | Total PnL: $-55.51 | Win%: 44.38% | Profit Factor: 0.930
# Saved trades → C:\Users\pcagm\orb_trades_PRU_one_share_RR1to2.csv
# === ORB 15m Retest — PSA (1 share, RR 1:2) ===
# Trades: 2143 | Total PnL: $-0.72 | Win%: 45.50% | Profit Factor: 1.000
# Saved trades → C:\Users\pcagm\orb_trades_PSA_one_share_RR1to2.csv
# === ORB 15m Retest — PSX (1 share, RR 1:2) ===
# Trades: 2234 | Total PnL: $-78.10 | Win%: 43.87% | Profit Factor: 0.921
# Saved trades → C:\Users\pcagm\orb_trades_PSX_one_share_RR1to2.csv
# === ORB 15m Retest — PWR (1 share, RR 1:2) ===
# Trades: 2177 | Total PnL: $-45.77 | Win%: 44.42% | Profit Factor: 0.958
# Saved trades → C:\Users\pcagm\orb_trades_PWR_one_share_RR1to2.csv
# === ORB 15m Retest — PYPL (1 share, RR 1:2) ===
# Trades: 2217 | Total PnL: $99.03 | Win%: 47.95% | Profit Factor: 1.089
# Saved trades → C:\Users\pcagm\orb_trades_PYPL_one_share_RR1to2.csv
# === ORB 15m Retest — QCOM (1 share, RR 1:2) ===
# Trades: 2230 | Total PnL: $85.79 | Win%: 44.66% | Profit Factor: 1.078
# Saved trades → C:\Users\pcagm\orb_trades_QCOM_one_share_RR1to2.csv
# === ORB 15m Retest — QQQ (1 share, RR 1:2) ===
# Trades: 2309 | Total PnL: $97.26 | Win%: 41.01% | Profit Factor: 1.058
# Saved trades → C:\Users\pcagm\orb_trades_QQQ_one_share_RR1to2.csv
#
# === Batch 12/15 (20 symbols) ===
# === ORB 15m Retest — RCL (1 share, RR 1:2) ===
# Trades: 2195 | Total PnL: $77.78 | Win%: 47.11% | Profit Factor: 1.064
# Saved trades → C:\Users\pcagm\orb_trades_RCL_one_share_RR1to2.csv
# === ORB 15m Retest — REGN (1 share, RR 1:2) ===
# Trades: 2176 | Total PnL: $-42.38 | Win%: 45.96% | Profit Factor: 0.992
# Saved trades → C:\Users\pcagm\orb_trades_REGN_one_share_RR1to2.csv
# === ORB 15m Retest — RMD (1 share, RR 1:2) ===
# Trades: 2095 | Total PnL: $-238.30 | Win%: 42.86% | Profit Factor: 0.825
# Saved trades → C:\Users\pcagm\orb_trades_RMD_one_share_RR1to2.csv
# === ORB 15m Retest — ROK (1 share, RR 1:2) ===
# Trades: 2142 | Total PnL: $-211.80 | Win%: 41.83% | Profit Factor: 0.891
# Saved trades → C:\Users\pcagm\orb_trades_ROK_one_share_RR1to2.csv
# === ORB 15m Retest — ROP (1 share, RR 1:2) ===
# Trades: 2077 | Total PnL: $-68.61 | Win%: 43.86% | Profit Factor: 0.971
# Saved trades → C:\Users\pcagm\orb_trades_ROP_one_share_RR1to2.csv
# === ORB 15m Retest — ROST (1 share, RR 1:2) ===
# Trades: 2189 | Total PnL: $-21.37 | Win%: 44.91% | Profit Factor: 0.975
# Saved trades → C:\Users\pcagm\orb_trades_ROST_one_share_RR1to2.csv
# === ORB 15m Retest — RSG (1 share, RR 1:2) ===
# Trades: 2175 | Total PnL: $22.98 | Win%: 45.43% | Profit Factor: 1.035
# Saved trades → C:\Users\pcagm\orb_trades_RSG_one_share_RR1to2.csv
# === ORB 15m Retest — RTX (1 share, RR 1:2) ===
# Trades: 2250 | Total PnL: $-65.62 | Win%: 44.53% | Profit Factor: 0.917
# Saved trades → C:\Users\pcagm\orb_trades_RTX_one_share_RR1to2.csv
# === ORB 15m Retest — RTY (1 share, RR 1:2) ===
# Trades: 1837 | Total PnL: $54.60 | Win%: 42.68% | Profit Factor: 1.005
# Saved trades → C:\Users\pcagm\orb_trades_RTY_one_share_RR1to2.csv
# === ORB 15m Retest — RVX (1 share, RR 1:2) ===
# Trades: 3832 | Total PnL: $-33.07 | Win%: 37.34% | Profit Factor: 0.972
# Saved trades → C:\Users\pcagm\orb_trades_RVX_one_share_RR1to2.csv
# === ORB 15m Retest — SBUX (1 share, RR 1:2) ===
# Trades: 2213 | Total PnL: $-31.94 | Win%: 45.37% | Profit Factor: 0.949
# Saved trades → C:\Users\pcagm\orb_trades_SBUX_one_share_RR1to2.csv
# === ORB 15m Retest — SCHW (1 share, RR 1:2) ===
# Trades: 2221 | Total PnL: $29.67 | Win%: 45.07% | Profit Factor: 1.058
# Saved trades → C:\Users\pcagm\orb_trades_SCHW_one_share_RR1to2.csv
# === ORB 15m Retest — SE (1 share, RR 1:2) ===
# Trades: 2009 | Total PnL: $87.14 | Win%: 48.98% | Profit Factor: 1.064
# Saved trades → C:\Users\pcagm\orb_trades_SE_one_share_RR1to2.csv
# === ORB 15m Retest — SHW (1 share, RR 1:2) ===
# Trades: 2167 | Total PnL: $-63.73 | Win%: 45.18% | Profit Factor: 0.978
# Saved trades → C:\Users\pcagm\orb_trades_SHW_one_share_RR1to2.csv
# === ORB 15m Retest — SLB (1 share, RR 1:2) ===
# Trades: 2238 | Total PnL: $-29.76 | Win%: 45.31% | Profit Factor: 0.942
# Saved trades → C:\Users\pcagm\orb_trades_SLB_one_share_RR1to2.csv
# === ORB 15m Retest — SNPS (1 share, RR 1:2) ===
# Trades: 2119 | Total PnL: $207.96 | Win%: 45.92% | Profit Factor: 1.089
# Saved trades → C:\Users\pcagm\orb_trades_SNPS_one_share_RR1to2.csv
# === ORB 15m Retest — SO (1 share, RR 1:2) ===
# Trades: 2242 | Total PnL: $49.80 | Win%: 46.74% | Profit Factor: 1.123
# Saved trades → C:\Users\pcagm\orb_trades_SO_one_share_RR1to2.csv
# === ORB 15m Retest — SPG (1 share, RR 1:2) ===
# Trades: 2202 | Total PnL: $-172.23 | Win%: 42.69% | Profit Factor: 0.870
# Saved trades → C:\Users\pcagm\orb_trades_SPG_one_share_RR1to2.csv
# === ORB 15m Retest — SPGI (1 share, RR 1:2) ===
# Trades: 2189 | Total PnL: $-23.43 | Win%: 45.55% | Profit Factor: 0.989
# Saved trades → C:\Users\pcagm\orb_trades_SPGI_one_share_RR1to2.csv
# === ORB 15m Retest — SPY (1 share, RR 1:2) ===
# Trades: 2319 | Total PnL: $102.11 | Win%: 39.11% | Profit Factor: 1.068
# Saved trades → C:\Users\pcagm\orb_trades_SPY_one_share_RR1to2.csv
#
# === Batch 13/15 (20 symbols) ===
# === ORB 15m Retest — SRE (1 share, RR 1:2) ===
# Trades: 2205 | Total PnL: $58.09 | Win%: 44.90% | Profit Factor: 1.072
# Saved trades → C:\Users\pcagm\orb_trades_SRE_one_share_RR1to2.csv
# === ORB 15m Retest — STX (1 share, RR 1:2) ===
# Trades: 2199 | Total PnL: $0.25 | Win%: 45.16% | Profit Factor: 1.000
# Saved trades → C:\Users\pcagm\orb_trades_STX_one_share_RR1to2.csv
# === ORB 15m Retest — SYK (1 share, RR 1:2) ===
# Trades: 2189 | Total PnL: $-106.22 | Win%: 45.55% | Profit Factor: 0.939
# Saved trades → C:\Users\pcagm\orb_trades_SYK_one_share_RR1to2.csv
# === ORB 15m Retest — SYY (1 share, RR 1:2) ===
# Trades: 2220 | Total PnL: $33.38 | Win%: 45.95% | Profit Factor: 1.067
# Saved trades → C:\Users\pcagm\orb_trades_SYY_one_share_RR1to2.csv
# === ORB 15m Retest — T (1 share, RR 1:2) ===
# Trades: 2196 | Total PnL: $2.28 | Win%: 46.86% | Profit Factor: 1.013
# Saved trades → C:\Users\pcagm\orb_trades_T_one_share_RR1to2.csv
# === ORB 15m Retest — TDG (1 share, RR 1:2) ===
# Trades: 1918 | Total PnL: $-59.15 | Win%: 43.12% | Profit Factor: 0.986
# Saved trades → C:\Users\pcagm\orb_trades_TDG_one_share_RR1to2.csv
# === ORB 15m Retest — TEL (1 share, RR 1:2) ===
# Trades: 2199 | Total PnL: $12.59 | Win%: 46.52% | Profit Factor: 1.015
# Saved trades → C:\Users\pcagm\orb_trades_TEL_one_share_RR1to2.csv
# === ORB 15m Retest — TEM (1 share, RR 1:2) ===
# Trades: 271 | Total PnL: $9.96 | Win%: 47.23% | Profit Factor: 1.044
# Saved trades → C:\Users\pcagm\orb_trades_TEM_one_share_RR1to2.csv
# === ORB 15m Retest — TFC (1 share, RR 1:2) ===
# Trades: 2214 | Total PnL: $-25.23 | Win%: 44.44% | Profit Factor: 0.940
# Saved trades → C:\Users\pcagm\orb_trades_TFC_one_share_RR1to2.csv
# === ORB 15m Retest — TGT (1 share, RR 1:2) ===
# Trades: 2225 | Total PnL: $20.11 | Win%: 46.52% | Profit Factor: 1.020
# Saved trades → C:\Users\pcagm\orb_trades_TGT_one_share_RR1to2.csv
# === ORB 15m Retest — TJX (1 share, RR 1:2) ===
# Trades: 2241 | Total PnL: $-73.34 | Win%: 45.34% | Profit Factor: 0.882
# Saved trades → C:\Users\pcagm\orb_trades_TJX_one_share_RR1to2.csv
# === ORB 15m Retest — TKO (1 share, RR 1:2) ===
# Trades: 2149 | Total PnL: $-41.38 | Win%: 43.14% | Profit Factor: 0.943
# Saved trades → C:\Users\pcagm\orb_trades_TKO_one_share_RR1to2.csv
# === ORB 15m Retest — TMO (1 share, RR 1:2) ===
# Trades: 2193 | Total PnL: $-403.80 | Win%: 43.32% | Profit Factor: 0.876
# Saved trades → C:\Users\pcagm\orb_trades_TMO_one_share_RR1to2.csv
# === ORB 15m Retest — TMUS (1 share, RR 1:2) ===
# Trades: 2198 | Total PnL: $-73.16 | Win%: 45.50% | Profit Factor: 0.920
# Saved trades → C:\Users\pcagm\orb_trades_TMUS_one_share_RR1to2.csv
# === ORB 15m Retest — TRGP (1 share, RR 1:2) ===
# Trades: 2222 | Total PnL: $-19.45 | Win%: 44.69% | Profit Factor: 0.974
# Saved trades → C:\Users\pcagm\orb_trades_TRGP_one_share_RR1to2.csv
# === ORB 15m Retest — TRV (1 share, RR 1:2) ===
# Trades: 2168 | Total PnL: $-25.83 | Win%: 45.16% | Profit Factor: 0.976
# Saved trades → C:\Users\pcagm\orb_trades_TRV_one_share_RR1to2.csv
# === ORB 15m Retest — TSLA (1 share, RR 1:2) ===
# Trades: 2255 | Total PnL: $1,309.23 | Win%: 48.65% | Profit Factor: 1.187
# Saved trades → C:\Users\pcagm\orb_trades_TSLA_one_share_RR1to2.csv
# === ORB 15m Retest — TSM (1 share, RR 1:2) ===
# Trades: 2215 | Total PnL: $53.75 | Win%: 48.08% | Profit Factor: 1.071
# Saved trades → C:\Users\pcagm\orb_trades_TSM_one_share_RR1to2.csv
# === ORB 15m Retest — TT (1 share, RR 1:2) ===
# Trades: 2179 | Total PnL: $-41.37 | Win%: 44.56% | Profit Factor: 0.969
# Saved trades → C:\Users\pcagm\orb_trades_TT_one_share_RR1to2.csv
# === ORB 15m Retest — TXN (1 share, RR 1:2) ===
# Trades: 2239 | Total PnL: $0.32 | Win%: 45.33% | Profit Factor: 1.000
# Saved trades → C:\Users\pcagm\orb_trades_TXN_one_share_RR1to2.csv
#
# === Batch 14/15 (20 symbols) ===
# === ORB 15m Retest — UAL (1 share, RR 1:2) ===
# Trades: 2203 | Total PnL: $-39.19 | Win%: 44.08% | Profit Factor: 0.948
# Saved trades → C:\Users\pcagm\orb_trades_UAL_one_share_RR1to2.csv
# === ORB 15m Retest — UBER (1 share, RR 1:2) ===
# Trades: 1455 | Total PnL: $17.49 | Win%: 46.19% | Profit Factor: 1.040
# Saved trades → C:\Users\pcagm\orb_trades_UBER_one_share_RR1to2.csv
# === ORB 15m Retest — UNH (1 share, RR 1:2) ===
# Trades: 2222 | Total PnL: $-211.37 | Win%: 44.06% | Profit Factor: 0.924
# Saved trades → C:\Users\pcagm\orb_trades_UNH_one_share_RR1to2.csv
# === ORB 15m Retest — UNP (1 share, RR 1:2) ===
# Trades: 2211 | Total PnL: $-70.61 | Win%: 45.59% | Profit Factor: 0.948
# Saved trades → C:\Users\pcagm\orb_trades_UNP_one_share_RR1to2.csv
# === ORB 15m Retest — UPS (1 share, RR 1:2) ===
# Trades: 1450 | Total PnL: $-50.30 | Win%: 43.17% | Profit Factor: 0.921
# Saved trades → C:\Users\pcagm\orb_trades_UPS_one_share_RR1to2.csv
# === ORB 15m Retest — URI (1 share, RR 1:2) ===
# Trades: 2143 | Total PnL: $74.12 | Win%: 45.68% | Profit Factor: 1.023
# Saved trades → C:\Users\pcagm\orb_trades_URI_one_share_RR1to2.csv
# === ORB 15m Retest — USB (1 share, RR 1:2) ===
# Trades: 2220 | Total PnL: $-18.06 | Win%: 44.46% | Profit Factor: 0.954
# Saved trades → C:\Users\pcagm\orb_trades_USB_one_share_RR1to2.csv
# === ORB 15m Retest — V (1 share, RR 1:2) ===
# Trades: 2239 | Total PnL: $-60.94 | Win%: 45.02% | Profit Factor: 0.955
# Saved trades → C:\Users\pcagm\orb_trades_V_one_share_RR1to2.csv
# === ORB 15m Retest — VICI (1 share, RR 1:2) ===
# Trades: 1740 | Total PnL: $9.74 | Win%: 44.71% | Profit Factor: 1.058
# Saved trades → C:\Users\pcagm\orb_trades_VICI_one_share_RR1to2.csv
# === ORB 15m Retest — VIX (1 share, RR 1:2) ===
# Trades: 3910 | Total PnL: $-119.71 | Win%: 35.83% | Profit Factor: 0.886
# Saved trades → C:\Users\pcagm\orb_trades_VIX_one_share_RR1to2.csv
# === ORB 15m Retest — VLO (1 share, RR 1:2) ===
# Trades: 2225 | Total PnL: $47.91 | Win%: 46.88% | Profit Factor: 1.044
# Saved trades → C:\Users\pcagm\orb_trades_VLO_one_share_RR1to2.csv
# === ORB 15m Retest — VMC (1 share, RR 1:2) ===
# Trades: 2148 | Total PnL: $-34.90 | Win%: 44.97% | Profit Factor: 0.975
# Saved trades → C:\Users\pcagm\orb_trades_VMC_one_share_RR1to2.csv
# === ORB 15m Retest — VRSK (1 share, RR 1:2) ===
# Trades: 2114 | Total PnL: $-30.16 | Win%: 45.84% | Profit Factor: 0.973
# Saved trades → C:\Users\pcagm\orb_trades_VRSK_one_share_RR1to2.csv
# === ORB 15m Retest — VRTX (1 share, RR 1:2) ===
# Trades: 2182 | Total PnL: $53.40 | Win%: 46.52% | Profit Factor: 1.023
# Saved trades → C:\Users\pcagm\orb_trades_VRTX_one_share_RR1to2.csv
# === ORB 15m Retest — VST (1 share, RR 1:2) ===
# Trades: 1889 | Total PnL: $31.60 | Win%: 44.10% | Profit Factor: 1.063
# Saved trades → C:\Users\pcagm\orb_trades_VST_one_share_RR1to2.csv
# === ORB 15m Retest — VXD (1 share, RR 1:2) ===
# Trades: 3594 | Total PnL: $-1,007.50 | Win%: 36.34% | Profit Factor: 0.549
# Saved trades → C:\Users\pcagm\orb_trades_VXD_one_share_RR1to2.csv
# === ORB 15m Retest — VXN (1 share, RR 1:2) ===
# Trades: 3725 | Total PnL: $-64.63 | Win%: 40.19% | Profit Factor: 0.942
# Saved trades → C:\Users\pcagm\orb_trades_VXN_one_share_RR1to2.csv
# === ORB 15m Retest — WDAY (1 share, RR 1:2) ===
# Trades: 2198 | Total PnL: $-40.77 | Win%: 45.50% | Profit Factor: 0.980
# Saved trades → C:\Users\pcagm\orb_trades_WDAY_one_share_RR1to2.csv
# === ORB 15m Retest — WEC (1 share, RR 1:2) ===
# Trades: 2181 | Total PnL: $-0.03 | Win%: 46.13% | Profit Factor: 1.000
# Saved trades → C:\Users\pcagm\orb_trades_WEC_one_share_RR1to2.csv
# === ORB 15m Retest — WELL (1 share, RR 1:2) ===
# Trades: 2189 | Total PnL: $3.22 | Win%: 46.09% | Profit Factor: 1.005
# Saved trades → C:\Users\pcagm\orb_trades_WELL_one_share_RR1to2.csv
#
# === Batch 15/15 (11 symbols) ===
# === ORB 15m Retest — WFC (1 share, RR 1:2) ===
# Trades: 2227 | Total PnL: $-0.53 | Win%: 45.44% | Profit Factor: 0.999
# Saved trades → C:\Users\pcagm\orb_trades_WFC_one_share_RR1to2.csv
# === ORB 15m Retest — WM (1 share, RR 1:2) ===
# Trades: 2201 | Total PnL: $69.75 | Win%: 47.07% | Profit Factor: 1.097
# Saved trades → C:\Users\pcagm\orb_trades_WM_one_share_RR1to2.csv
# === ORB 15m Retest — WMB (1 share, RR 1:2) ===
# Trades: 2210 | Total PnL: $2.11 | Win%: 45.43% | Profit Factor: 1.007
# Saved trades → C:\Users\pcagm\orb_trades_WMB_one_share_RR1to2.csv
# === ORB 15m Retest — WMT (1 share, RR 1:2) ===
# Trades: 2206 | Total PnL: $62.31 | Win%: 47.28% | Profit Factor: 1.097
# Saved trades → C:\Users\pcagm\orb_trades_WMT_one_share_RR1to2.csv
# === ORB 15m Retest — XEL (1 share, RR 1:2) ===
# Trades: 2233 | Total PnL: $32.77 | Win%: 46.93% | Profit Factor: 1.080
# Saved trades → C:\Users\pcagm\orb_trades_XEL_one_share_RR1to2.csv
# === ORB 15m Retest — XOM (1 share, RR 1:2) ===
# Trades: 2254 | Total PnL: $-23.39 | Win%: 45.21% | Profit Factor: 0.964
# Saved trades → C:\Users\pcagm\orb_trades_XOM_one_share_RR1to2.csv
# === ORB 15m Retest — XYL (1 share, RR 1:2) ===
# Trades: 2179 | Total PnL: $-117.33 | Win%: 43.00% | Profit Factor: 0.839
# Saved trades → C:\Users\pcagm\orb_trades_XYL_one_share_RR1to2.csv
# === ORB 15m Retest — YM (1 share, RR 1:2) ===
# Trades: 3609 | Total PnL: $-350.89 | Win%: 40.18% | Profit Factor: 0.998
# Saved trades → C:\Users\pcagm\orb_trades_YM_one_share_RR1to2.csv
# === ORB 15m Retest — YUM (1 share, RR 1:2) ===
# Trades: 2180 | Total PnL: $16.38 | Win%: 46.28% | Profit Factor: 1.024
# Saved trades → C:\Users\pcagm\orb_trades_YUM_one_share_RR1to2.csv
# === ORB 15m Retest — ZTS (1 share, RR 1:2) ===
# Trades: 2201 | Total PnL: $11.80 | Win%: 47.66% | Profit Factor: 1.011
# Saved trades → C:\Users\pcagm\orb_trades_ZTS_one_share_RR1to2.csv
# === ORB 15m Retest — ZWS (1 share, RR 1:2) ===
# Trades: 2107 | Total PnL: $-14.97 | Win%: 44.00% | Profit Factor: 0.947
# Saved trades → C:\Users\pcagm\orb_trades_ZWS_one_share_RR1to2.csv
#
# === ORB 15m Retest — OVERALL (1 share, RR 1:2) ===
# Trades: 624261 | Total PnL: $5,080.08 | Win%: 44.53% | Profit Factor: 1.006
# Saved trades → C:\Users\pcagm\orb_trades_ALL_one_share_RR1to2.csv
